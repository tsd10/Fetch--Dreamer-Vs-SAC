# %%
import gymnasium_robotics
import gymnasium as gym
from stable_baselines3 import SAC, HerReplayBuffer # Import HerReplayBuffer
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import EvalCallback
# Removed StopTrainingOnRewardThreshold for simplicity unless needed
import os
import numpy as np # Needed for success rate calculation in custom callback if desired
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# --- Configuration ---
env_id = "FetchReach-v3" # Or FetchPickAndPlace-v3, etc.
# Define path for saving the best model (EvalCallback needs this)
save_dir = f"./her_sac_{env_id}_results/"
best_model_save_path = os.path.join(save_dir, "best_model")
final_model_save_path = os.path.join(save_dir, f"her_sac_{env_id}_final")

# Create directories if they don't exist
os.makedirs(save_dir, exist_ok=True)

# --- Environment Setup ---
# IMPORTANT: For HER, use the non-vectorized environment
env = gym.make(env_id, reward_type='dense')  # Normal gym env
env = DummyVecEnv([lambda: env])             # Make it a VecEnv
env = VecNormalize(env, norm_obs=True, norm_reward=False)  # Now normalize it
# Optional: Check the environment
# check_env(env)

# --- Callbacks for Evaluation ---
# EvalCallback logs evaluation results to the console and saves the best model.
eval_callback = EvalCallback(env, # Use a separate eval env (or the same, just resets)
                             best_model_save_path=best_model_save_path,
                             log_path=save_dir, # Logs eval results (like eval_success.npy) here
                             eval_freq=5000,    # Evaluate every N environment steps
                             n_eval_episodes=10, # Number of episodes for evaluation
                             deterministic=True, # Use deterministic actions for evaluation
                             render=False,
                             verbose=1)         # Print eval results to console

# --- Agent Definition (SAC + HER) ---
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=8,
        goal_selection_strategy='future',
    ),
    verbose=1,            # Set to 1 to print info (like episode stats) to console
    # tensorboard_log=None, # Explicitly None or just remove the parameter
    buffer_size=int(1e6),
    learning_starts=1000,
    batch_size=512,      # Larger batch size often good for HER
    learning_rate=1e-4,   # Tunable - may need adjustment
    gamma=0.99,           # Tunable for goal-based tasks
    tau=0.005,             # Tunable
    # ent_coef='auto' is the default for automatic alpha tuning
)

# --- Training ---
print(f"Starting training SAC + HER on {env_id}...")
print(f"Results and best model will be saved in: {save_dir}")

# Train the agent
# log_interval controls how often training episode stats (mean reward/length) are printed.
# For Fetch (50 steps/ep), log_interval=50 means stats every ~50 episodes.
model.learn(
    total_timesteps=1000000, # Adjust total steps as needed
    log_interval=50,        # Print training stats avg over last 50 episodes
    callback=eval_callback  # Run evaluation periodically and save best model
)

# --- Save Final Model ---
model.save(final_model_save_path)
print(f"Training finished. Final model saved to {final_model_save_path}")
print(f"Best model during training saved in {best_model_save_path}.zip")

# --- Save the VecNormalize wrapper ---
env.save(os.path.join(save_dir, "vecnormalize.pkl"))  # <--- Add this here AFTER training
print(f"Saved VecNormalize statistics to {save_dir}/vecnormalize.pkl")

env.close()
# Out:
# 2025-04-27 15:24:07.661848: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-27 15:24:07.663551: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-27 15:24:07.697122: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-27 15:24:09.912645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using cuda device
# Starting training SAC + HER on FetchReach-v3...
# Results and best model will be saved in: ./her_sac_FetchReach-v3_results/
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 183      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | -18.7    |
# |    critic_loss     | 0.0951   |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -0.997   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1499     |
# ---------------------------------
# /home/tushard/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=5000, episode_reward=-20.13 +/- 4.48
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -20.1    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -36.5    |
# |    critic_loss     | 0.0791   |
# |    ent_coef        | 0.671    |
# |    ent_coef_loss   | -2.62    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 145      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 137      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | -47.4    |
# |    critic_loss     | 0.0793   |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -4.13    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6499     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-13.53 +/- 2.07
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -13.5    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -53.1    |
# |    critic_loss     | 0.0668   |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | -5.69    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 132      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 130      |
# |    time_elapsed    | 95       |
# |    total_timesteps | 12500    |
# | train/             |          |
# |    actor_loss      | -55.7    |
# |    critic_loss     | 0.0514   |
# |    ent_coef        | 0.319    |
# |    ent_coef_loss   | -7.07    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11499    |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-9.57 +/- 3.69
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.57    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -56.1    |
# |    critic_loss     | 0.044    |
# |    ent_coef        | 0.249    |
# |    ent_coef_loss   | -8.61    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 128      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 15000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 127      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 17500    |
# | train/             |          |
# |    actor_loss      | -54.6    |
# |    critic_loss     | 0.0305   |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16499    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=-12.49 +/- 2.29
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -12.5    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -50.9    |
# |    critic_loss     | 0.0174   |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 126      |
# |    time_elapsed    | 157      |
# |    total_timesteps | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 126      |
# |    time_elapsed    | 177      |
# |    total_timesteps | 22500    |
# | train/             |          |
# |    actor_loss      | -46.9    |
# |    critic_loss     | 0.0156   |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21499    |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=-9.18 +/- 3.23
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.18    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -43.5    |
# |    critic_loss     | 0.0112   |
# |    ent_coef        | 0.0919   |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 125      |
# |    time_elapsed    | 198      |
# |    total_timesteps | 25000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 125      |
# |    time_elapsed    | 218      |
# |    total_timesteps | 27500    |
# | train/             |          |
# |    actor_loss      | -38.9    |
# |    critic_loss     | 0.00716  |
# |    ent_coef        | 0.0717   |
# |    ent_coef_loss   | -15.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26499    |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=-8.83 +/- 2.09
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.83    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -35      |
# |    critic_loss     | 0.00573  |
# |    ent_coef        | 0.056    |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 125      |
# |    time_elapsed    | 239      |
# |    total_timesteps | 30000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 125      |
# |    time_elapsed    | 259      |
# |    total_timesteps | 32500    |
# | train/             |          |
# |    actor_loss      | -31.1    |
# |    critic_loss     | 0.00468  |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -16.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31499    |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=-8.00 +/- 2.73
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8       |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | -27      |
# |    critic_loss     | 0.0048   |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | -17      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 124      |
# |    time_elapsed    | 280      |
# |    total_timesteps | 35000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 124      |
# |    time_elapsed    | 300      |
# |    total_timesteps | 37500    |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 0.00304  |
# |    ent_coef        | 0.0268   |
# |    ent_coef_loss   | -17.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36499    |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=-6.38 +/- 2.82
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.38    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -21.1    |
# |    critic_loss     | 0.00301  |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 124      |
# |    time_elapsed    | 321      |
# |    total_timesteps | 40000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 124      |
# |    time_elapsed    | 341      |
# |    total_timesteps | 42500    |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.00249  |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 41499    |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=-6.80 +/- 3.98
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.8     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.00206  |
# |    ent_coef        | 0.0129   |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 124      |
# |    time_elapsed    | 362      |
# |    total_timesteps | 45000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 950      |
# |    fps             | 124      |
# |    time_elapsed    | 382      |
# |    total_timesteps | 47500    |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.00168  |
# |    ent_coef        | 0.0101   |
# |    ent_coef_loss   | -16.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 46499    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-7.07 +/- 3.07
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.07    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.00143  |
# |    ent_coef        | 0.00795  |
# |    ent_coef_loss   | -16.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 48999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 123      |
# |    time_elapsed    | 403      |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 1050     |
# |    fps             | 123      |
# |    time_elapsed    | 423      |
# |    total_timesteps | 52500    |
# | train/             |          |
# |    actor_loss      | -9.63    |
# |    critic_loss     | 0.00123  |
# |    ent_coef        | 0.00626  |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51499    |
# ---------------------------------
# Eval num_timesteps=55000, episode_reward=-8.04 +/- 4.04
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.04    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | -8.02    |
# |    critic_loss     | 0.00108  |
# |    ent_coef        | 0.00494  |
# |    ent_coef_loss   | -14.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 123      |
# |    time_elapsed    | 445      |
# |    total_timesteps | 55000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 1150     |
# |    fps             | 123      |
# |    time_elapsed    | 465      |
# |    total_timesteps | 57500    |
# | train/             |          |
# |    actor_loss      | -6.63    |
# |    critic_loss     | 0.00101  |
# |    ent_coef        | 0.0039   |
# |    ent_coef_loss   | -13.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 56499    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=-7.85 +/- 2.99
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.85    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -5.3     |
# |    critic_loss     | 0.000916 |
# |    ent_coef        | 0.0031   |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 58999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 123      |
# |    time_elapsed    | 486      |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 1250     |
# |    fps             | 123      |
# |    time_elapsed    | 506      |
# |    total_timesteps | 62500    |
# | train/             |          |
# |    actor_loss      | -4.35    |
# |    critic_loss     | 0.000913 |
# |    ent_coef        | 0.00247  |
# |    ent_coef_loss   | -8.62    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61499    |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=-8.23 +/- 3.09
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.23    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | -3.54    |
# |    critic_loss     | 0.000825 |
# |    ent_coef        | 0.00198  |
# |    ent_coef_loss   | -6.93    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 63999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 123      |
# |    time_elapsed    | 527      |
# |    total_timesteps | 65000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1350     |
# |    fps             | 123      |
# |    time_elapsed    | 548      |
# |    total_timesteps | 67500    |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.000643 |
# |    ent_coef        | 0.00161  |
# |    ent_coef_loss   | -3.96    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 66499    |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=-8.05 +/- 3.55
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.05    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | -2.22    |
# |    critic_loss     | 0.000602 |
# |    ent_coef        | 0.00135  |
# |    ent_coef_loss   | -1.36    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 68999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 122      |
# |    time_elapsed    | 569      |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1450     |
# |    fps             | 122      |
# |    time_elapsed    | 589      |
# |    total_timesteps | 72500    |
# | train/             |          |
# |    actor_loss      | -1.7     |
# |    critic_loss     | 0.000558 |
# |    ent_coef        | 0.0012   |
# |    ent_coef_loss   | -1.18    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 71499    |
# ---------------------------------
# Eval num_timesteps=75000, episode_reward=-10.40 +/- 2.88
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.4    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | -1.33    |
# |    critic_loss     | 0.000465 |
# |    ent_coef        | 0.00117  |
# |    ent_coef_loss   | -0.426   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 73999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 122      |
# |    time_elapsed    | 611      |
# |    total_timesteps | 75000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1550     |
# |    fps             | 122      |
# |    time_elapsed    | 631      |
# |    total_timesteps | 77500    |
# | train/             |          |
# |    actor_loss      | -0.878   |
# |    critic_loss     | 0.000491 |
# |    ent_coef        | 0.00117  |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 76499    |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=-7.24 +/- 3.15
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.24    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -0.0142  |
# |    critic_loss     | 0.000467 |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | 1.25     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 78999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 122      |
# |    time_elapsed    | 652      |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1650     |
# |    fps             | 122      |
# |    time_elapsed    | 673      |
# |    total_timesteps | 82500    |
# | train/             |          |
# |    actor_loss      | 0.236    |
# |    critic_loss     | 0.000418 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | 0.384    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 81499    |
# ---------------------------------
# Eval num_timesteps=85000, episode_reward=-7.25 +/- 2.64
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.25    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 85000    |
# | train/             |          |
# |    actor_loss      | 0.306    |
# |    critic_loss     | 0.000594 |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | 0.227    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 83999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 122      |
# |    time_elapsed    | 694      |
# |    total_timesteps | 85000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1750     |
# |    fps             | 122      |
# |    time_elapsed    | 714      |
# |    total_timesteps | 87500    |
# | train/             |          |
# |    actor_loss      | 0.63     |
# |    critic_loss     | 0.000344 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | -0.349   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 86499    |
# ---------------------------------
# Eval num_timesteps=90000, episode_reward=-6.59 +/- 2.88
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.59    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | 0.964    |
# |    critic_loss     | 0.000344 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | 0.727    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 88999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.48     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 122      |
# |    time_elapsed    | 735      |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.49     |
# | time/              |          |
# |    episodes        | 1850     |
# |    fps             | 122      |
# |    time_elapsed    | 756      |
# |    total_timesteps | 92500    |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 0.000443 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.879    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91499    |
# ---------------------------------
# Eval num_timesteps=95000, episode_reward=-6.83 +/- 3.02
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.83    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 95000    |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 0.00026  |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -1.22    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 122      |
# |    time_elapsed    | 777      |
# |    total_timesteps | 95000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1950     |
# |    fps             | 122      |
# |    time_elapsed    | 798      |
# |    total_timesteps | 97500    |
# | train/             |          |
# |    actor_loss      | 1.24     |
# |    critic_loss     | 0.000236 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 0.632    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 96499    |
# ---------------------------------
# Eval num_timesteps=100000, episode_reward=-7.58 +/- 2.72
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.58    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.000266 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 1.74     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 98999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 122      |
# |    time_elapsed    | 819      |
# |    total_timesteps | 100000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2050     |
# |    fps             | 122      |
# |    time_elapsed    | 839      |
# |    total_timesteps | 102500   |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.000229 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.507   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 101499   |
# ---------------------------------
# Eval num_timesteps=105000, episode_reward=-6.18 +/- 2.34
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.18    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 105000   |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.000326 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | -0.606   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 103999   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 122      |
# |    time_elapsed    | 860      |
# |    total_timesteps | 105000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 2150     |
# |    fps             | 122      |
# |    time_elapsed    | 879      |
# |    total_timesteps | 107500   |
# | train/             |          |
# |    actor_loss      | 1.75     |
# |    critic_loss     | 0.000254 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.0535  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 106499   |
# ---------------------------------
# Eval num_timesteps=110000, episode_reward=-6.20 +/- 1.68
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.2     |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 110000   |
# | train/             |          |
# |    actor_loss      | 1.95     |
# |    critic_loss     | 0.000221 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.953    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 108999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 122      |
# |    time_elapsed    | 900      |
# |    total_timesteps | 110000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 2250     |
# |    fps             | 122      |
# |    time_elapsed    | 920      |
# |    total_timesteps | 112500   |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.00021  |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | -0.556   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 111499   |
# ---------------------------------
# Eval num_timesteps=115000, episode_reward=-6.25 +/- 2.29
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.25    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 115000   |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 0.000171 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 1.51     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 113999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 122      |
# |    time_elapsed    | 941      |
# |    total_timesteps | 115000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 2350     |
# |    fps             | 122      |
# |    time_elapsed    | 961      |
# |    total_timesteps | 117500   |
# | train/             |          |
# |    actor_loss      | 1.84     |
# |    critic_loss     | 0.000364 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 116499   |
# ---------------------------------
# Eval num_timesteps=120000, episode_reward=-7.76 +/- 3.61
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.76    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 0.000139 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | -0.537   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 118999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 122      |
# |    time_elapsed    | 982      |
# |    total_timesteps | 120000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2450     |
# |    fps             | 122      |
# |    time_elapsed    | 1001     |
# |    total_timesteps | 122500   |
# | train/             |          |
# |    actor_loss      | 1.9      |
# |    critic_loss     | 0.000324 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 121499   |
# ---------------------------------
# Eval num_timesteps=125000, episode_reward=-6.75 +/- 2.09
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.75    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 125000   |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.000205 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -0.297   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 123999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 122      |
# |    time_elapsed    | 1022     |
# |    total_timesteps | 125000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2550     |
# |    fps             | 122      |
# |    time_elapsed    | 1042     |
# |    total_timesteps | 127500   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.000214 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | -1.07    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 126499   |
# ---------------------------------
# Eval num_timesteps=130000, episode_reward=-9.06 +/- 3.63
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.06    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 130000   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.000143 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -0.0719  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 128999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 122      |
# |    time_elapsed    | 1063     |
# |    total_timesteps | 130000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2650     |
# |    fps             | 122      |
# |    time_elapsed    | 1082     |
# |    total_timesteps | 132500   |
# | train/             |          |
# |    actor_loss      | 2.19     |
# |    critic_loss     | 0.000102 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -0.636   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 131499   |
# ---------------------------------
# Eval num_timesteps=135000, episode_reward=-6.97 +/- 2.49
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.97    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 135000   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 0.000164 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 0.398    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 133999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 122      |
# |    time_elapsed    | 1103     |
# |    total_timesteps | 135000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2750     |
# |    fps             | 122      |
# |    time_elapsed    | 1123     |
# |    total_timesteps | 137500   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.000126 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 2        |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 136499   |
# ---------------------------------
# Eval num_timesteps=140000, episode_reward=-6.60 +/- 2.80
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.6     |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.000122 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | -0.428   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 138999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 122      |
# |    time_elapsed    | 1144     |
# |    total_timesteps | 140000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2850     |
# |    fps             | 122      |
# |    time_elapsed    | 1163     |
# |    total_timesteps | 142500   |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 0.000135 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | -0.81    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 141499   |
# ---------------------------------
# Eval num_timesteps=145000, episode_reward=-6.88 +/- 3.95
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.88    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 145000   |
# | train/             |          |
# |    actor_loss      | 2.25     |
# |    critic_loss     | 0.000137 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 0.701    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 143999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 122      |
# |    time_elapsed    | 1184     |
# |    total_timesteps | 145000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2950     |
# |    fps             | 122      |
# |    time_elapsed    | 1204     |
# |    total_timesteps | 147500   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 0.000256 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | 0.182    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 146499   |
# ---------------------------------
# Eval num_timesteps=150000, episode_reward=-8.34 +/- 3.07
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.34    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 150000   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.00015  |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | 0.518    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 148999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 122      |
# |    time_elapsed    | 1225     |
# |    total_timesteps | 150000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 3050     |
# |    fps             | 122      |
# |    time_elapsed    | 1245     |
# |    total_timesteps | 152500   |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 0.000124 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.745   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 151499   |
# ---------------------------------
# Eval num_timesteps=155000, episode_reward=-8.15 +/- 3.82
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.15    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 155000   |
# | train/             |          |
# |    actor_loss      | 2.06     |
# |    critic_loss     | 0.000117 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.593    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 153999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 122      |
# |    time_elapsed    | 1265     |
# |    total_timesteps | 155000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 3150     |
# |    fps             | 122      |
# |    time_elapsed    | 1285     |
# |    total_timesteps | 157500   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.000106 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.084   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 156499   |
# ---------------------------------
# Eval num_timesteps=160000, episode_reward=-7.42 +/- 2.88
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.42    |
# |    success_rate    | 0.3      |
# ...
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.436    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 946499   |
# ---------------------------------
# Eval num_timesteps=950000, episode_reward=-7.19 +/- 3.94
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.19    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 950000   |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 3.37e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 948999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19000    |
# |    fps             | 120      |
# |    time_elapsed    | 7863     |
# |    total_timesteps | 950000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19050    |
# |    fps             | 120      |
# |    time_elapsed    | 7884     |
# |    total_timesteps | 952500   |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 1.8e-05  |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.302   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 951499   |
# ---------------------------------
# Eval num_timesteps=955000, episode_reward=-6.32 +/- 4.17
# Episode length: 50.00 +/- 0.00
# Success rate: 70.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.32    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    total_timesteps | 955000   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 1.82e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 953999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 19100    |
# |    fps             | 120      |
# |    time_elapsed    | 7906     |
# |    total_timesteps | 955000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 19150    |
# |    fps             | 120      |
# |    time_elapsed    | 7927     |
# |    total_timesteps | 957500   |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 1.9e-05  |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.537   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 956499   |
# ---------------------------------
# Eval num_timesteps=960000, episode_reward=-6.08 +/- 3.16
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.08    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 960000   |
# | train/             |          |
# |    actor_loss      | 2.21     |
# |    critic_loss     | 1.67e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.526    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 958999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 19200    |
# |    fps             | 120      |
# |    time_elapsed    | 7949     |
# |    total_timesteps | 960000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 19250    |
# |    fps             | 120      |
# |    time_elapsed    | 7970     |
# |    total_timesteps | 962500   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 9.46e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.289    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 961499   |
# ---------------------------------
# Eval num_timesteps=965000, episode_reward=-7.58 +/- 3.51
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.58    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 965000   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 1.87e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.434    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 963999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 19300    |
# |    fps             | 120      |
# |    time_elapsed    | 7992     |
# |    total_timesteps | 965000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 19350    |
# |    fps             | 120      |
# |    time_elapsed    | 8013     |
# |    total_timesteps | 967500   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 2.17e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 1.45     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 966499   |
# ---------------------------------
# Eval num_timesteps=970000, episode_reward=-5.38 +/- 2.97
# Episode length: 50.00 +/- 0.00
# Success rate: 70.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.38    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    total_timesteps | 970000   |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 1.79e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 1.55     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 968999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 19400    |
# |    fps             | 120      |
# |    time_elapsed    | 8035     |
# |    total_timesteps | 970000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19450    |
# |    fps             | 120      |
# |    time_elapsed    | 8056     |
# |    total_timesteps | 972500   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 2.09e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.475   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 971499   |
# ---------------------------------
# Eval num_timesteps=975000, episode_reward=-8.35 +/- 3.33
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.35    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 975000   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 1.88e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.295    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 973999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 19500    |
# |    fps             | 120      |
# |    time_elapsed    | 8078     |
# |    total_timesteps | 975000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 19550    |
# |    fps             | 120      |
# |    time_elapsed    | 8099     |
# |    total_timesteps | 977500   |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 1.43e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.601    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 976499   |
# ---------------------------------
# Eval num_timesteps=980000, episode_reward=-6.07 +/- 2.99
# Episode length: 50.00 +/- 0.00
# Success rate: 70.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.07    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | 1.99     |
# |    critic_loss     | 7.18e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.133    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 978999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19600    |
# |    fps             | 120      |
# |    time_elapsed    | 8121     |
# |    total_timesteps | 980000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 19650    |
# |    fps             | 120      |
# |    time_elapsed    | 8142     |
# |    total_timesteps | 982500   |
# | train/             |          |
# |    actor_loss      | 2.04     |
# |    critic_loss     | 2.55e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.182   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 981499   |
# ---------------------------------
# Eval num_timesteps=985000, episode_reward=-7.39 +/- 4.03
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.39    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 985000   |
# | train/             |          |
# |    actor_loss      | 1.96     |
# |    critic_loss     | 1.93e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.823   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 983999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 19700    |
# |    fps             | 120      |
# |    time_elapsed    | 8164     |
# |    total_timesteps | 985000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 19750    |
# |    fps             | 120      |
# |    time_elapsed    | 8185     |
# |    total_timesteps | 987500   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 1.47e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.624    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 986499   |
# ---------------------------------
# Eval num_timesteps=990000, episode_reward=-6.05 +/- 2.57
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.05    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 990000   |
# | train/             |          |
# |    actor_loss      | 2.03     |
# |    critic_loss     | 2.16e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.42     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 988999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 19800    |
# |    fps             | 120      |
# |    time_elapsed    | 8207     |
# |    total_timesteps | 990000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19850    |
# |    fps             | 120      |
# |    time_elapsed    | 8228     |
# |    total_timesteps | 992500   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 2.33e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.592   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 991499   |
# ---------------------------------
# Eval num_timesteps=995000, episode_reward=-7.47 +/- 2.35
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.47    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 995000   |
# | train/             |          |
# |    actor_loss      | 2.04     |
# |    critic_loss     | 2.64e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.365   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 993999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 19900    |
# |    fps             | 120      |
# |    time_elapsed    | 8250     |
# |    total_timesteps | 995000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19950    |
# |    fps             | 120      |
# |    time_elapsed    | 8271     |
# |    total_timesteps | 997500   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 2.64e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | 0.568    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 996499   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=-7.31 +/- 3.19
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.31    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 1.99e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | 0.383    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 998999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 20000    |
# |    fps             | 120      |
# |    time_elapsed    | 8292     |
# |    total_timesteps | 1000000  |
# ---------------------------------
# Training finished. Final model saved to ./her_sac_FetchReach-v3_results/her_sac_FetchReach-v3_final
# Best model during training saved in ./her_sac_FetchReach-v3_results/best_model.zip

# %%
env.save("./her_sac_FetchReach-v3_results/vecnormalize.pkl")
print("✅ VecNormalize saved successfully!")
# Out:
# ✅ VecNormalize saved successfully!

# %% [markdown]
# NEW BASE MODEL CODE:

# %%
import gymnasium_robotics
import gymnasium as gym
from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import os
import numpy as np

# --- Configuration ---
env_id = "FetchReach-v3"
save_dir = f"./her_sac_{env_id}_results/"
best_model_save_path = os.path.join(save_dir, "best_model")
final_model_save_path = os.path.join(save_dir, f"her_sac_{env_id}_final")

os.makedirs(save_dir, exist_ok=True)

# --- Environment Setup ---
env = gym.make(env_id, reward_type='dense')
env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=False)

# --- Agent Definition (SAC + HER) ---
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=8,
        goal_selection_strategy='future',
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_starts=1000,
    batch_size=512,
    learning_rate=1e-4,
    gamma=0.99,
    tau=0.005,
)

# --- Callbacks ---

# Stop criteria: if mean reward > -5 (which roughly means success in FetchReach dense reward)
success_stop_callback = StopTrainingOnRewardThreshold(
    reward_threshold=-5,  # Reward close to 0 means successful reach
    verbose=1
)

# EvalCallback with embedded stop callback
eval_callback = EvalCallback(
    env,
    best_model_save_path=best_model_save_path,
    log_path=save_dir,
    eval_freq=5000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
    callback_on_new_best=success_stop_callback,
    verbose=1,
)

# --- Training ---
print(f"🚀 Starting training SAC + HER on {env_id}...")
print(f"📂 Results and best model will be saved in: {save_dir}")

model.learn(
    total_timesteps=1_000_000,
    log_interval=50,
    callback=eval_callback
)

# --- Save Final Model ---
model.save(final_model_save_path)
print(f"✅ Training finished. Final model saved to {final_model_save_path}")
print(f"✅ Best model during training saved in {best_model_save_path}.zip")

# --- Save VecNormalize statistics ---
env.save(os.path.join(save_dir, "vecnormalize.pkl"))
print(f"✅ Saved VecNormalize statistics to {save_dir}/vecnormalize.pkl")

env.close()

# --- Final 1000 Episode Evaluation ---

print("\n🎯 Starting final evaluation over 1000 episodes...")

# Reload environment with saved normalization
eval_env = gym.make(env_id, reward_type='dense')
eval_env = DummyVecEnv([lambda: eval_env])
eval_env = VecNormalize.load(os.path.join(save_dir, "vecnormalize.pkl"), eval_env)
eval_env.training = False
eval_env.norm_reward = False

# Reload best model
model = SAC.load(best_model_save_path, env=eval_env)

successes = []

for _ in range(1000):
    obs = eval_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = eval_env.step(action)
        done = done[0]  # DummyVecEnv
        info = info[0]
    successes.append(info['is_success'])

success_rate = np.mean(successes) * 100.0
print(f"\n✅ Final Evaluation: Success Rate = {success_rate:.2f}% over 1000 episodes.")

if success_rate >= 90.0:
    print("🏆 Problem Solved! ✅ (Success > 90%)")
else:
    print("⚡ Problem Not Fully Solved. (Success < 90%)")
# Out:
# Using cuda device
# 🚀 Starting training SAC + HER on FetchReach-v3...
# 📂 Results and best model will be saved in: ./her_sac_FetchReach-v3_results/
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 192      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 0.113    |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -0.996   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1499     |
# ---------------------------------
# /home/tushard/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=5000, episode_reward=-20.14 +/- 7.42
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -20.1    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -36      |
# |    critic_loss     | 0.0929   |
# |    ent_coef        | 0.671    |
# |    ent_coef_loss   | -2.62    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 150      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 143      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | -47      |
# |    critic_loss     | 0.0896   |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -4.18    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6499     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-14.46 +/- 1.23
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -14.5    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -52.7    |
# |    critic_loss     | 0.0723   |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | -5.67    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 138      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 137      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 12500    |
# | train/             |          |
# |    actor_loss      | -55      |
# |    critic_loss     | 0.0575   |
# |    ent_coef        | 0.319    |
# |    ent_coef_loss   | -7       |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11499    |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-10.11 +/- 2.44
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.1    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -54.7    |
# |    critic_loss     | 0.0395   |
# |    ent_coef        | 0.249    |
# |    ent_coef_loss   | -8.47    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 134      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 15000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 134      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 17500    |
# | train/             |          |
# |    actor_loss      | -53.1    |
# |    critic_loss     | 0.0318   |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -9.97    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16499    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=-10.84 +/- 3.23
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.8    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -50.1    |
# |    critic_loss     | 0.0217   |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 133      |
# |    time_elapsed    | 150      |
# |    total_timesteps | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 132      |
# |    time_elapsed    | 169      |
# |    total_timesteps | 22500    |
# | train/             |          |
# |    actor_loss      | -46.3    |
# |    critic_loss     | 0.0181   |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -12.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21499    |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=-8.27 +/- 2.62
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.27    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -42.3    |
# |    critic_loss     | 0.0122   |
# |    ent_coef        | 0.0919   |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 132      |
# |    time_elapsed    | 189      |
# |    total_timesteps | 25000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 131      |
# |    time_elapsed    | 208      |
# |    total_timesteps | 27500    |
# | train/             |          |
# |    actor_loss      | -38.4    |
# |    critic_loss     | 0.00982  |
# |    ent_coef        | 0.0717   |
# |    ent_coef_loss   | -14.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26499    |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=-7.09 +/- 2.82
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.09    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 0.00732  |
# |    ent_coef        | 0.056    |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 131      |
# |    time_elapsed    | 228      |
# |    total_timesteps | 30000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 131      |
# |    time_elapsed    | 247      |
# |    total_timesteps | 32500    |
# | train/             |          |
# |    actor_loss      | -30.3    |
# |    critic_loss     | 0.00596  |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -16.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31499    |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=-8.95 +/- 2.72
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.95    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | -27.2    |
# |    critic_loss     | 0.00396  |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | -17.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 130      |
# |    time_elapsed    | 267      |
# |    total_timesteps | 35000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 130      |
# |    time_elapsed    | 286      |
# |    total_timesteps | 37500    |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 0.00372  |
# |    ent_coef        | 0.0268   |
# |    ent_coef_loss   | -17.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36499    |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=-8.05 +/- 3.68
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.05    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 0.00272  |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -17.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 130      |
# |    time_elapsed    | 307      |
# |    total_timesteps | 40000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 130      |
# |    time_elapsed    | 326      |
# |    total_timesteps | 42500    |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.00216  |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 41499    |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=-8.00 +/- 4.34
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8       |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 0.00222  |
# |    ent_coef        | 0.0129   |
# |    ent_coef_loss   | -17.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 129      |
# |    time_elapsed    | 346      |
# |    total_timesteps | 45000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 950      |
# |    fps             | 129      |
# |    time_elapsed    | 365      |
# |    total_timesteps | 47500    |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.00185  |
# |    ent_coef        | 0.0101   |
# |    ent_coef_loss   | -16.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 46499    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-7.67 +/- 4.05
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.67    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.00128  |
# |    ent_coef        | 0.00797  |
# |    ent_coef_loss   | -16.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 48999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 129      |
# |    time_elapsed    | 386      |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 1050     |
# |    fps             | 129      |
# |    time_elapsed    | 405      |
# |    total_timesteps | 52500    |
# | train/             |          |
# |    actor_loss      | -9.27    |
# |    critic_loss     | 0.00132  |
# |    ent_coef        | 0.00628  |
# |    ent_coef_loss   | -14.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51499    |
# ---------------------------------
# Eval num_timesteps=55000, episode_reward=-5.84 +/- 3.75
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.84    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | -7.96    |
# |    critic_loss     | 0.000938 |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -13.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 129      |
# |    time_elapsed    | 426      |
# |    total_timesteps | 55000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 1150     |
# |    fps             | 129      |
# |    time_elapsed    | 445      |
# |    total_timesteps | 57500    |
# | train/             |          |
# |    actor_loss      | -6.32    |
# |    critic_loss     | 0.000834 |
# |    ent_coef        | 0.00391  |
# |    ent_coef_loss   | -12.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 56499    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=-7.83 +/- 4.01
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.83    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -5.42    |
# |    critic_loss     | 0.000946 |
# |    ent_coef        | 0.0031   |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 58999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 128      |
# |    time_elapsed    | 465      |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 1250     |
# |    fps             | 128      |
# |    time_elapsed    | 485      |
# |    total_timesteps | 62500    |
# | train/             |          |
# |    actor_loss      | -4.39    |
# |    critic_loss     | 0.000687 |
# |    ent_coef        | 0.00247  |
# |    ent_coef_loss   | -7.94    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61499    |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=-7.25 +/- 3.16
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.25    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | -3.44    |
# |    critic_loss     | 0.000639 |
# |    ent_coef        | 0.00198  |
# |    ent_coef_loss   | -5.96    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 63999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 128      |
# |    time_elapsed    | 505      |
# |    total_timesteps | 65000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1350     |
# |    fps             | 128      |
# |    time_elapsed    | 525      |
# |    total_timesteps | 67500    |
# | train/             |          |
# |    actor_loss      | -2.67    |
# |    critic_loss     | 0.00077  |
# |    ent_coef        | 0.00161  |
# |    ent_coef_loss   | -2.9     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 66499    |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=-9.10 +/- 3.43
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.1     |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | -2.08    |
# |    critic_loss     | 0.000513 |
# |    ent_coef        | 0.00134  |
# |    ent_coef_loss   | -1.93    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 68999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 128      |
# |    time_elapsed    | 545      |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1450     |
# |    fps             | 128      |
# |    time_elapsed    | 565      |
# |    total_timesteps | 72500    |
# | train/             |          |
# |    actor_loss      | -1.56    |
# |    critic_loss     | 0.000489 |
# |    ent_coef        | 0.00119  |
# |    ent_coef_loss   | 0.972    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 71499    |
# ---------------------------------
# Eval num_timesteps=75000, episode_reward=-6.98 +/- 3.31
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.98    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | -1.05    |
# |    critic_loss     | 0.000515 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.381   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 73999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 128      |
# |    time_elapsed    | 585      |
# |    total_timesteps | 75000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1550     |
# |    fps             | 128      |
# |    time_elapsed    | 605      |
# |    total_timesteps | 77500    |
# | train/             |          |
# |    actor_loss      | -0.648   |
# |    critic_loss     | 0.000475 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | 0.681    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 76499    |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=-6.24 +/- 2.70
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.24    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -0.181   |
# |    critic_loss     | 0.000357 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | 0.39     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 78999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 127      |
# |    time_elapsed    | 625      |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 1650     |
# |    fps             | 127      |
# |    time_elapsed    | 645      |
# |    total_timesteps | 82500    |
# | train/             |          |
# |    actor_loss      | -0.0657  |
# |    critic_loss     | 0.000363 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.878   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 81499    |
# ---------------------------------
# Eval num_timesteps=85000, episode_reward=-8.22 +/- 4.82
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.22    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 85000    |
# | train/             |          |
# |    actor_loss      | 0.219    |
# |    critic_loss     | 0.000366 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -0.303   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 83999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 127      |
# |    time_elapsed    | 665      |
# |    total_timesteps | 85000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1750     |
# |    fps             | 127      |
# |    time_elapsed    | 685      |
# |    total_timesteps | 87500    |
# | train/             |          |
# |    actor_loss      | 0.599    |
# |    critic_loss     | 0.000294 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 0.465    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 86499    |
# ---------------------------------
# Eval num_timesteps=90000, episode_reward=-10.13 +/- 1.96
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.1    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | 1.07     |
# |    critic_loss     | 0.000448 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 1.87     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 88999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 127      |
# |    time_elapsed    | 706      |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 1850     |
# |    fps             | 127      |
# |    time_elapsed    | 725      |
# |    total_timesteps | 92500    |
# | train/             |          |
# |    actor_loss      | 1.12     |
# |    critic_loss     | 0.000357 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -0.343   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91499    |
# ---------------------------------
# Eval num_timesteps=95000, episode_reward=-7.50 +/- 3.70
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.5     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 95000    |
# | train/             |          |
# |    actor_loss      | 0.864    |
# |    critic_loss     | 0.000254 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 127      |
# |    time_elapsed    | 746      |
# |    total_timesteps | 95000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 1950     |
# |    fps             | 127      |
# |    time_elapsed    | 766      |
# |    total_timesteps | 97500    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.000263 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.618    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 96499    |
# ---------------------------------
# Eval num_timesteps=100000, episode_reward=-7.73 +/- 3.14
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.73    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | 1.44     |
# |    critic_loss     | 0.000196 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.726   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 98999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 127      |
# |    time_elapsed    | 786      |
# |    total_timesteps | 100000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 2050     |
# |    fps             | 127      |
# |    time_elapsed    | 806      |
# |    total_timesteps | 102500   |
# | train/             |          |
# |    actor_loss      | 1.44     |
# |    critic_loss     | 0.000229 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -1.73    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 101499   |
# ---------------------------------
# Eval num_timesteps=105000, episode_reward=-7.13 +/- 3.96
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.13    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 105000   |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.000256 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -0.728   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 103999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 127      |
# |    time_elapsed    | 826      |
# |    total_timesteps | 105000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2150     |
# |    fps             | 127      |
# |    time_elapsed    | 845      |
# |    total_timesteps | 107500   |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.000195 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 0.435    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 106499   |
# ---------------------------------
# Eval num_timesteps=110000, episode_reward=-5.62 +/- 2.41
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.62    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 110000   |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 0.000239 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -0.341   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 108999   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 127      |
# |    time_elapsed    | 865      |
# |    total_timesteps | 110000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2250     |
# |    fps             | 127      |
# |    time_elapsed    | 884      |
# |    total_timesteps | 112500   |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 0.000259 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.5      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 111499   |
# ---------------------------------
# Eval num_timesteps=115000, episode_reward=-7.82 +/- 3.89
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.82    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 115000   |
# | train/             |          |
# |    actor_loss      | 1.95     |
# |    critic_loss     | 0.000195 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.551   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 113999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 127      |
# |    time_elapsed    | 905      |
# |    total_timesteps | 115000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2350     |
# |    fps             | 127      |
# |    time_elapsed    | 924      |
# |    total_timesteps | 117500   |
# | train/             |          |
# |    actor_loss      | 1.93     |
# |    critic_loss     | 0.000159 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.493   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 116499   |
# ---------------------------------
# Eval num_timesteps=120000, episode_reward=-6.39 +/- 3.24
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.39    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | 2.03     |
# |    critic_loss     | 0.000172 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.00518 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 118999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 127      |
# |    time_elapsed    | 944      |
# |    total_timesteps | 120000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 2450     |
# |    fps             | 127      |
# |    time_elapsed    | 964      |
# |    total_timesteps | 122500   |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 0.000162 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -1.59    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 121499   |
# ---------------------------------
# Eval num_timesteps=125000, episode_reward=-7.73 +/- 2.51
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.73    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 125000   |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 0.000179 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.178   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 123999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 126      |
# |    time_elapsed    | 984      |
# |    total_timesteps | 125000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2550     |
# |    fps             | 127      |
# |    time_elapsed    | 1003     |
# |    total_timesteps | 127500   |
# | train/             |          |
# |    actor_loss      | 1.93     |
# |    critic_loss     | 0.000126 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -0.347   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 126499   |
# ---------------------------------
# Eval num_timesteps=130000, episode_reward=-7.55 +/- 4.01
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.55    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 130000   |
# | train/             |          |
# |    actor_loss      | 1.95     |
# |    critic_loss     | 0.000135 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -0.991   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 128999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 126      |
# |    time_elapsed    | 1024     |
# |    total_timesteps | 130000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2650     |
# |    fps             | 126      |
# |    time_elapsed    | 1043     |
# |    total_timesteps | 132500   |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.000129 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.266    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 131499   |
# ---------------------------------
# Eval num_timesteps=135000, episode_reward=-7.91 +/- 3.16
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.91    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 135000   |
# | train/             |          |
# |    actor_loss      | 2.06     |
# |    critic_loss     | 0.000182 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.425    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 133999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 126      |
# |    time_elapsed    | 1063     |
# |    total_timesteps | 135000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 2750     |
# |    fps             | 126      |
# |    time_elapsed    | 1083     |
# |    total_timesteps | 137500   |
# | train/             |          |
# |    actor_loss      | 2.3      |
# |    critic_loss     | 0.000108 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -1.25    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 136499   |
# ---------------------------------
# Eval num_timesteps=140000, episode_reward=-8.92 +/- 2.63
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.92    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | 2.01     |
# |    critic_loss     | 0.000169 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | 1.03     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 138999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 126      |
# |    time_elapsed    | 1103     |
# |    total_timesteps | 140000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 2850     |
# |    fps             | 126      |
# |    time_elapsed    | 1122     |
# |    total_timesteps | 142500   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.000115 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.785    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 141499   |
# ---------------------------------
# Eval num_timesteps=145000, episode_reward=-6.99 +/- 2.43
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.99    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 145000   |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 0.00017  |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -1.47    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 143999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 126      |
# |    time_elapsed    | 1143     |
# |    total_timesteps | 145000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2950     |
# |    fps             | 126      |
# |    time_elapsed    | 1162     |
# |    total_timesteps | 147500   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.000132 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.0182  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 146499   |
# ---------------------------------
# Eval num_timesteps=150000, episode_reward=-7.43 +/- 3.85
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.43    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 150000   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.000127 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -1.72    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 148999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 126      |
# |    time_elapsed    | 1183     |
# |    total_timesteps | 150000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 3050     |
# |    fps             | 126      |
# |    time_elapsed    | 1202     |
# |    total_timesteps | 152500   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 0.000171 |
# |    ent_coef        | 0.00103  |
# |    ent_coef_loss   | 0.424    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 151499   |
# ---------------------------------
# Eval num_timesteps=155000, episode_reward=-6.41 +/- 2.83
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.41    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 155000   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.000109 |
# |    ent_coef        | 0.00103  |
# |    ent_coef_loss   | -0.0999  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 153999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 126      |
# |    time_elapsed    | 1223     |
# |    total_timesteps | 155000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 3150     |
# |    fps             | 126      |
# |    time_elapsed    | 1242     |
# |    total_timesteps | 157500   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 0.0001   |
# |    ent_coef        | 0.00103  |
# |    ent_coef_loss   | -0.592   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 156499   |
# ---------------------------------
# Eval num_timesteps=160000, episode_reward=-7.47 +/- 4.40
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.47    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 160000   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.000133 |
# |    ent_coef        | 0.00103  |
# |    ent_coef_loss   | 0.148    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 158999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 126      |
# |    time_elapsed    | 1262     |
# |    total_timesteps | 160000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 3250     |
# |    fps             | 126      |
# |    time_elapsed    | 1282     |
# |    total_timesteps | 162500   |
# | train/             |          |
# ...
# |    mean_reward     | -7.93    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 960000   |
# | train/             |          |
# |    actor_loss      | 1.96     |
# |    critic_loss     | 1.87e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 958999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19200    |
# |    fps             | 122      |
# |    time_elapsed    | 7829     |
# |    total_timesteps | 960000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 19250    |
# |    fps             | 122      |
# |    time_elapsed    | 7850     |
# |    total_timesteps | 962500   |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 3.19e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -2.37    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 961499   |
# ---------------------------------
# Eval num_timesteps=965000, episode_reward=-8.54 +/- 3.94
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.54    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 965000   |
# | train/             |          |
# |    actor_loss      | 2.07     |
# |    critic_loss     | 3.12e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.13    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 963999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 19300    |
# |    fps             | 122      |
# |    time_elapsed    | 7871     |
# |    total_timesteps | 965000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 19350    |
# |    fps             | 122      |
# |    time_elapsed    | 7892     |
# |    total_timesteps | 967500   |
# | train/             |          |
# |    actor_loss      | 2.06     |
# |    critic_loss     | 2.81e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.179    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 966499   |
# ---------------------------------
# Eval num_timesteps=970000, episode_reward=-9.56 +/- 2.73
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.56    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 970000   |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 3.25e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.699   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 968999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 19400    |
# |    fps             | 122      |
# |    time_elapsed    | 7914     |
# |    total_timesteps | 970000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 19450    |
# |    fps             | 122      |
# |    time_elapsed    | 7934     |
# |    total_timesteps | 972500   |
# | train/             |          |
# |    actor_loss      | 1.9      |
# |    critic_loss     | 1.49e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.414    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 971499   |
# ---------------------------------
# Eval num_timesteps=975000, episode_reward=-6.74 +/- 3.21
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.74    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 975000   |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 3.08e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.301    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 973999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 19500    |
# |    fps             | 122      |
# |    time_elapsed    | 7956     |
# |    total_timesteps | 975000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 19550    |
# |    fps             | 122      |
# |    time_elapsed    | 7977     |
# |    total_timesteps | 977500   |
# | train/             |          |
# |    actor_loss      | 2.01     |
# |    critic_loss     | 3.76e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -1.54    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 976499   |
# ---------------------------------
# Eval num_timesteps=980000, episode_reward=-6.75 +/- 2.93
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.75    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | 2.01     |
# |    critic_loss     | 1.39e-05 |
# |    ent_coef        | 0.00103  |
# |    ent_coef_loss   | 0.466    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 978999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19600    |
# |    fps             | 122      |
# |    time_elapsed    | 7999     |
# |    total_timesteps | 980000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 19650    |
# |    fps             | 122      |
# |    time_elapsed    | 8020     |
# |    total_timesteps | 982500   |
# | train/             |          |
# |    actor_loss      | 2.04     |
# |    critic_loss     | 1.84e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 981499   |
# ---------------------------------
# Eval num_timesteps=985000, episode_reward=-9.66 +/- 4.58
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.66    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 985000   |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 2.14e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.087   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 983999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19700    |
# |    fps             | 122      |
# |    time_elapsed    | 8041     |
# |    total_timesteps | 985000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 19750    |
# |    fps             | 122      |
# |    time_elapsed    | 8062     |
# |    total_timesteps | 987500   |
# | train/             |          |
# |    actor_loss      | 2.23     |
# |    critic_loss     | 1.33e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.192    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 986499   |
# ---------------------------------
# Eval num_timesteps=990000, episode_reward=-7.62 +/- 4.34
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.62    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 990000   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 1.57e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.35    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 988999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 19800    |
# |    fps             | 122      |
# |    time_elapsed    | 8083     |
# |    total_timesteps | 990000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 19850    |
# |    fps             | 122      |
# |    time_elapsed    | 8104     |
# |    total_timesteps | 992500   |
# | train/             |          |
# |    actor_loss      | 1.94     |
# |    critic_loss     | 1.49e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.236    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 991499   |
# ---------------------------------
# Eval num_timesteps=995000, episode_reward=-7.84 +/- 3.46
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.84    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 995000   |
# | train/             |          |
# |    actor_loss      | 2.19     |
# |    critic_loss     | 2.83e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.654   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 993999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 19900    |
# |    fps             | 122      |
# |    time_elapsed    | 8126     |
# |    total_timesteps | 995000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 19950    |
# |    fps             | 122      |
# |    time_elapsed    | 8146     |
# |    total_timesteps | 997500   |
# | train/             |          |
# |    actor_loss      | 1.86     |
# |    critic_loss     | 2.21e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.442   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 996499   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=-4.99 +/- 2.73
# Episode length: 50.00 +/- 0.00
# Success rate: 80.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -4.99    |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 1.99     |
# |    critic_loss     | 2.88e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.214   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 998999   |
# ---------------------------------
# New best mean reward!
# Stopping training because the mean reward -4.99  is above the threshold -5
# ✅ Training finished. Final model saved to ./her_sac_FetchReach-v3_results/her_sac_FetchReach-v3_final
# ✅ Best model during training saved in ./her_sac_FetchReach-v3_results/best_model.zip
# ✅ Saved VecNormalize statistics to ./her_sac_FetchReach-v3_results//vecnormalize.pkl
#
# 🎯 Starting final evaluation over 1000 episodes...
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[21], line 95
#      92 eval_env.norm_reward = False
#      94 # Reload best model
# ---> 95 model = SAC.load(best_model_save_path, env=eval_env)
#      97 successes = []
#      99 for _ in range(1000):
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/common/base_class.py:680, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     677     print("== CURRENT SYSTEM INFO ==")
#     678     get_system_info()
# --> 680 data, params, pytorch_variables = load_from_zip_file(
#     681     path,
#     682     device=device,
#     683     custom_objects=custom_objects,
#     684     print_system_info=print_system_info,
#     685 )
#     687 assert data is not None, "No data found in the saved file"
#     688 assert params is not None, "No params found in the saved file"
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/common/save_util.py:403, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     376 def load_from_zip_file(
#     377     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     378     load_data: bool = True,
#    (...)
#     382     print_system_info: bool = False,
#     383 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     384     """
#     385     Load model data from a .zip archive
#     386
#    (...)
#     401         and dict of pytorch variables
#     402     """
# --> 403     file = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     405     # set device to cpu if cuda is not available
#     406     device = get_device(device=device)
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/functools.py:874, in singledispatch.<locals>.wrapper(*args, **kw)
#     870 if not args:
#     871     raise TypeError(f'{funcname} requires at least '
#     872                     '1 positional argument')
# --> 874 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/common/save_util.py:240, in open_path_str(path, mode, verbose, suffix)
#     225 @open_path.register(str)
#     226 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     227     """
#     228     Open a path given by a string. If writing to the path, the function ensures
#     229     that the path exists.
#    (...)
#     238     :return:
#     239     """
# --> 240     return open_path_pathlib(pathlib.Path(path), mode, verbose, suffix)
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/common/save_util.py:264, in open_path_pathlib(path, mode, verbose, suffix)
#     262 if mode == "r":
#     263     try:
# --> 264         return open_path(path.open("rb"), mode, verbose, suffix)
#     265     except FileNotFoundError as error:
#     266         if suffix is not None and suffix != "":
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/pathlib.py:1200, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1198 if self._closed:
#    1199     self._raise_closed()
# -> 1200 return io.open(self, mode, buffering, encoding, errors, newline,
#    1201                opener=self._opener)
#
# IsADirectoryError: [Errno 21] Is a directory: 'her_sac_FetchReach-v3_results/best_model'

# %%
# --- Final 1000 Episode Evaluation ---

print("\n🎯 Starting final evaluation over 1000 episodes...")

# Reload environment with saved normalization
eval_env = gym.make(env_id, reward_type='dense')
eval_env = DummyVecEnv([lambda: eval_env])
eval_env = VecNormalize.load(os.path.join(save_dir, "vecnormalize.pkl"), eval_env)
eval_env.training = False
eval_env.norm_reward = False

# Correct model load with .zip
model = SAC.load(os.path.join(best_model_save_path, "best_model.zip"), env=eval_env)

successes = []

for _ in range(1000):
    obs = eval_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = eval_env.step(action)
        done = done[0]  # DummyVecEnv
        info = info[0]
    successes.append(info['is_success'])

success_rate = np.mean(successes) * 100.0
print(f"\n✅ Final Evaluation: Success Rate = {success_rate:.2f}% over 1000 episodes.")

if success_rate >= 90.0:
    print("🏆 Problem Solved! ✅ (Success > 90%)")
else:
    print("⚡ Problem Not Fully Solved. (Success < 90%)")
# Out:
# 🎯 Starting final evaluation over 1000 episodes...
#
# ✅ Final Evaluation: Success Rate = 36.60% over 1000 episodes.
# ⚡ Problem Not Fully Solved. (Success < 90%)

# %% [markdown]
# NEW BASE MODEL -- OPTIMIZED

# %%
import gymnasium_robotics
import gymnasium as gym
from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.callbacks import EvalCallback, CallbackList, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import os
import numpy as np

# --- Custom Callback ---
class StopTrainingOnSuccessRate(BaseCallback):
    """
    Custom callback to stop training once success rate exceeds threshold.
    """
    def __init__(self, success_threshold=0.90, eval_freq=5000, verbose=1):
        super().__init__(verbose)
        self.success_threshold = success_threshold
        self.eval_freq = eval_freq

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0:
            successes = []
            for _ in range(10):  # 10 evaluation episodes
                obs = self.training_env.reset()
                done = False
                while not done:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, reward, done, infos = self.training_env.step(action)
                    done = done[0]
                    infos = infos[0]
                successes.append(infos['is_success'])

            success_rate = np.mean(successes)

            if self.verbose > 0:
                print(f"✅ [Success Monitor] Success rate over 10 episodes: {success_rate*100:.2f}%")

            if success_rate >= self.success_threshold:
                print(f"🏆 [Stopping Early] Success rate {success_rate*100:.2f}% exceeded threshold {self.success_threshold*100:.2f}%!")
                return False  # Stop training

        return True  # Continue training otherwise

# --- Configuration ---
env_id = "FetchReach-v3"
save_dir = f"./her_sac_{env_id}_results/"
best_model_save_path = os.path.join(save_dir, "best_model")
final_model_save_path = os.path.join(save_dir, f"her_sac_{env_id}_final")

os.makedirs(save_dir, exist_ok=True)

# --- Environment Setup ---
env = gym.make(env_id, reward_type='dense')
env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=False)

# --- Agent Definition (SAC + HER) ---
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=8,
        goal_selection_strategy='future',
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_starts=1000,
    batch_size=512,
    learning_rate=1e-4,
    gamma=0.99,
    tau=0.005,
)

# --- Callbacks ---

# 1. Eval callback to monitor reward
eval_callback = EvalCallback(
    env,
    best_model_save_path=best_model_save_path,
    log_path=save_dir,
    eval_freq=5000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
    verbose=1,
)

# 2. Custom stop callback (stop if real success >90%)
success_stop_callback = StopTrainingOnSuccessRate(
    success_threshold=0.90,  # 90% success required
    eval_freq=5000,
    verbose=1
)

# 3. Combine them
callback = CallbackList([eval_callback, success_stop_callback])

# --- Training ---
print(f"🚀 Starting training SAC + HER on {env_id} with success-rate-based stopping...")
print(f"📂 Results and best model will be saved in: {save_dir}")

model.learn(
    total_timesteps=1_000_000,
    log_interval=50,
    callback=callback
)

# --- Save Final Model ---
model.save(final_model_save_path)
print(f"✅ Training finished. Final model saved to {final_model_save_path}")
print(f"✅ Best model during training saved in {best_model_save_path}")

# --- Save VecNormalize statistics ---
env.save(os.path.join(save_dir, "vecnormalize.pkl"))
print(f"✅ Saved VecNormalize statistics to {save_dir}/vecnormalize.pkl")

env.close()

# --- Final 1000 Episode Evaluation ---

print("\n🎯 Starting final evaluation over 1000 episodes...")

# Reload environment with saved normalization
eval_env = gym.make(env_id, reward_type='dense')
eval_env = DummyVecEnv([lambda: eval_env])
eval_env = VecNormalize.load(os.path.join(save_dir, "vecnormalize.pkl"), eval_env)
eval_env.training = False
eval_env.norm_reward = False

# Correctly load model
model = SAC.load(os.path.join(best_model_save_path, "best_model.zip"), env=eval_env)

successes = []

for _ in range(1000):
    obs = eval_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, infos = eval_env.step(action)
        done = done[0]
        infos = infos[0]
    successes.append(infos['is_success'])

success_rate = np.mean(successes) * 100.0
print(f"\n✅ Final Evaluation: Success Rate = {success_rate:.2f}% over 1000 episodes.")

if success_rate >= 90.0:
    print("🏆 Problem Solved! ✅ (Success > 90%)")
else:
    print("⚡ Problem Not Fully Solved. (Success < 90%)")
# Out:
# Using cuda device
# 🚀 Starting training SAC + HER on FetchReach-v3 with success-rate-based stopping...
# 📂 Results and best model will be saved in: ./her_sac_FetchReach-v3_results/
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 191      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.127    |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -1       |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1499     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-20.08 +/- 5.24
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -20.1    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -37      |
# |    critic_loss     | 0.126    |
# |    ent_coef        | 0.671    |
# |    ent_coef_loss   | -2.62    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3999     |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 145      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 140      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | -47.1    |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -4.22    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6499     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-14.92 +/- 2.48
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -14.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -53.6    |
# |    critic_loss     | 0.0916   |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | -5.59    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8999     |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 133      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 132      |
# |    time_elapsed    | 94       |
# |    total_timesteps | 12500    |
# | train/             |          |
# |    actor_loss      | -55.6    |
# |    critic_loss     | 0.0729   |
# |    ent_coef        | 0.319    |
# |    ent_coef_loss   | -6.83    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11499    |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-9.83 +/- 2.82
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.83    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -56.5    |
# |    critic_loss     | 0.0478   |
# |    ent_coef        | 0.249    |
# |    ent_coef_loss   | -8.36    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 129      |
# |    time_elapsed    | 115      |
# |    total_timesteps | 15000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 129      |
# |    time_elapsed    | 134      |
# |    total_timesteps | 17500    |
# | train/             |          |
# |    actor_loss      | -54.3    |
# |    critic_loss     | 0.0361   |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -9.96    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16499    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=-9.95 +/- 3.42
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.95    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -51.7    |
# |    critic_loss     | 0.0247   |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 128      |
# |    time_elapsed    | 156      |
# |    total_timesteps | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 128      |
# |    time_elapsed    | 175      |
# |    total_timesteps | 22500    |
# | train/             |          |
# |    actor_loss      | -47      |
# |    critic_loss     | 0.0174   |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -12.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21499    |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=-8.71 +/- 3.76
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.71    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -42.9    |
# |    critic_loss     | 0.0135   |
# |    ent_coef        | 0.0919   |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 127      |
# |    time_elapsed    | 196      |
# |    total_timesteps | 25000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 127      |
# |    time_elapsed    | 216      |
# |    total_timesteps | 27500    |
# | train/             |          |
# |    actor_loss      | -38.8    |
# |    critic_loss     | 0.00894  |
# |    ent_coef        | 0.0717   |
# |    ent_coef_loss   | -15      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26499    |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=-7.94 +/- 2.97
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.94    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -34.6    |
# |    critic_loss     | 0.007    |
# |    ent_coef        | 0.056    |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 126      |
# |    time_elapsed    | 237      |
# |    total_timesteps | 30000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 126      |
# |    time_elapsed    | 256      |
# |    total_timesteps | 32500    |
# | train/             |          |
# |    actor_loss      | -30.9    |
# |    critic_loss     | 0.00599  |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -16.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31499    |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=-9.32 +/- 3.47
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.32    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 0.00513  |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | -16.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 125      |
# |    time_elapsed    | 278      |
# |    total_timesteps | 35000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 126      |
# |    time_elapsed    | 297      |
# |    total_timesteps | 37500    |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 0.00396  |
# |    ent_coef        | 0.0268   |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36499    |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=-9.58 +/- 3.62
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.58    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -21      |
# |    critic_loss     | 0.0034   |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 10.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 125      |
# |    time_elapsed    | 319      |
# |    total_timesteps | 40000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 125      |
# |    time_elapsed    | 338      |
# |    total_timesteps | 42500    |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 0.00237  |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 41499    |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=-8.67 +/- 3.39
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.67    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 0.00208  |
# |    ent_coef        | 0.0129   |
# |    ent_coef_loss   | -16.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 124      |
# |    time_elapsed    | 360      |
# |    total_timesteps | 45000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 950      |
# |    fps             | 125      |
# |    time_elapsed    | 379      |
# |    total_timesteps | 47500    |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.00195  |
# |    ent_coef        | 0.0101   |
# |    ent_coef_loss   | -16.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 46499    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-8.41 +/- 2.90
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.41    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 0.00157  |
# |    ent_coef        | 0.00796  |
# |    ent_coef_loss   | -15.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 48999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 124      |
# |    time_elapsed    | 401      |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 1050     |
# |    fps             | 124      |
# |    time_elapsed    | 420      |
# |    total_timesteps | 52500    |
# | train/             |          |
# |    actor_loss      | -9.23    |
# |    critic_loss     | 0.00109  |
# |    ent_coef        | 0.00627  |
# |    ent_coef_loss   | -14.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51499    |
# ---------------------------------
# Eval num_timesteps=55000, episode_reward=-7.98 +/- 2.89
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.98    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | -7.92    |
# |    critic_loss     | 0.00117  |
# |    ent_coef        | 0.00494  |
# |    ent_coef_loss   | -13.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 124      |
# |    time_elapsed    | 442      |
# |    total_timesteps | 55000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1150     |
# |    fps             | 124      |
# |    time_elapsed    | 461      |
# |    total_timesteps | 57500    |
# | train/             |          |
# |    actor_loss      | -6.57    |
# |    critic_loss     | 0.000937 |
# |    ent_coef        | 0.00391  |
# |    ent_coef_loss   | -12      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 56499    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=-10.24 +/- 1.94
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.2    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -5.69    |
# |    critic_loss     | 0.000998 |
# |    ent_coef        | 0.00311  |
# |    ent_coef_loss   | -10      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 58999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 124      |
# |    time_elapsed    | 483      |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 1250     |
# |    fps             | 124      |
# |    time_elapsed    | 503      |
# |    total_timesteps | 62500    |
# | train/             |          |
# |    actor_loss      | -4.44    |
# |    critic_loss     | 0.000646 |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | -7.7     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61499    |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=-7.42 +/- 3.05
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.42    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | -3.66    |
# |    critic_loss     | 0.000843 |
# |    ent_coef        | 0.002    |
# |    ent_coef_loss   | -8.13    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 63999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 123      |
# |    time_elapsed    | 524      |
# |    total_timesteps | 65000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1350     |
# |    fps             | 123      |
# |    time_elapsed    | 544      |
# |    total_timesteps | 67500    |
# | train/             |          |
# |    actor_loss      | -2.88    |
# |    critic_loss     | 0.000553 |
# |    ent_coef        | 0.00163  |
# |    ent_coef_loss   | -4.14    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 66499    |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=-7.68 +/- 2.74
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.68    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | -2.06    |
# |    critic_loss     | 0.000549 |
# |    ent_coef        | 0.00137  |
# |    ent_coef_loss   | -3.08    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 68999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 123      |
# |    time_elapsed    | 566      |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 1450     |
# |    fps             | 123      |
# |    time_elapsed    | 586      |
# |    total_timesteps | 72500    |
# | train/             |          |
# |    actor_loss      | -1.78    |
# |    critic_loss     | 0.000565 |
# |    ent_coef        | 0.00122  |
# |    ent_coef_loss   | 0.223    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 71499    |
# ---------------------------------
# Eval num_timesteps=75000, episode_reward=-8.71 +/- 1.53
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.71    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | -1.13    |
# |    critic_loss     | 0.000471 |
# |    ent_coef        | 0.00119  |
# |    ent_coef_loss   | 0.787    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 73999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 80.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 123      |
# |    time_elapsed    | 607      |
# |    total_timesteps | 75000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1550     |
# |    fps             | 123      |
# |    time_elapsed    | 627      |
# |    total_timesteps | 77500    |
# | train/             |          |
# |    actor_loss      | -0.761   |
# |    critic_loss     | 0.000385 |
# |    ent_coef        | 0.00117  |
# |    ent_coef_loss   | -1.45    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 76499    |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=-8.86 +/- 2.98
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.86    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -0.231   |
# |    critic_loss     | 0.00036  |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | -0.00561 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 78999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 123      |
# |    time_elapsed    | 649      |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1650     |
# |    fps             | 123      |
# |    time_elapsed    | 669      |
# |    total_timesteps | 82500    |
# | train/             |          |
# |    actor_loss      | -0.0385  |
# |    critic_loss     | 0.000351 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -0.508   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 81499    |
# ---------------------------------
# Eval num_timesteps=85000, episode_reward=-6.47 +/- 2.89
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.47    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 85000    |
# | train/             |          |
# |    actor_loss      | 0.362    |
# |    critic_loss     | 0.000263 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | -0.758   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 83999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 123      |
# |    time_elapsed    | 691      |
# |    total_timesteps | 85000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 1750     |
# |    fps             | 123      |
# |    time_elapsed    | 710      |
# |    total_timesteps | 87500    |
# | train/             |          |
# |    actor_loss      | 0.518    |
# |    critic_loss     | 0.000269 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.321   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 86499    |
# ---------------------------------
# Eval num_timesteps=90000, episode_reward=-7.46 +/- 2.67
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.46    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | 0.78     |
# |    critic_loss     | 0.000298 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 88999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 10.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 122      |
# |    time_elapsed    | 732      |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1850     |
# |    fps             | 122      |
# |    time_elapsed    | 752      |
# |    total_timesteps | 92500    |
# | train/             |          |
# |    actor_loss      | 1.04     |
# |    critic_loss     | 0.000255 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -1.44    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91499    |
# ---------------------------------
# Eval num_timesteps=95000, episode_reward=-8.57 +/- 3.09
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.57    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 95000    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.000252 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 0.8      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 122      |
# |    time_elapsed    | 774      |
# |    total_timesteps | 95000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 1950     |
# |    fps             | 122      |
# |    time_elapsed    | 794      |
# |    total_timesteps | 97500    |
# | train/             |          |
# |    actor_loss      | 1.19     |
# |    critic_loss     | 0.000245 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.112   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 96499    |
# ---------------------------------
# Eval num_timesteps=100000, episode_reward=-8.20 +/- 3.49
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.2     |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | 1.23     |
# |    critic_loss     | 0.000231 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.00214 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 98999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.46     |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 122      |
# |    time_elapsed    | 816      |
# |    total_timesteps | 100000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 2050     |
# |    fps             | 122      |
# |    time_elapsed    | 835      |
# |    total_timesteps | 102500   |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00026  |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.835    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 101499   |
# ---------------------------------
# Eval num_timesteps=105000, episode_reward=-5.67 +/- 2.71
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.67    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 105000   |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.000183 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.281    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 103999   |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 122      |
# |    time_elapsed    | 856      |
# |    total_timesteps | 105000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2150     |
# |    fps             | 122      |
# |    time_elapsed    | 876      |
# |    total_timesteps | 107500   |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.000299 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.302    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 106499   |
# ---------------------------------
# Eval num_timesteps=110000, episode_reward=-6.83 +/- 3.51
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.83    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 110000   |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 0.000214 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.508    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 108999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 122      |
# |    time_elapsed    | 897      |
# |    total_timesteps | 110000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2250     |
# |    fps             | 122      |
# |    time_elapsed    | 917      |
# |    total_timesteps | 112500   |
# | train/             |          |
# |    actor_loss      | 1.8      |
# |    critic_loss     | 0.000181 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.629   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 111499   |
# ---------------------------------
# Eval num_timesteps=115000, episode_reward=-7.87 +/- 2.08
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.87    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 115000   |
# | train/             |          |
# |    actor_loss      | 1.9      |
# |    critic_loss     | 0.000185 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | 0.0827   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 113999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 122      |
# |    time_elapsed    | 938      |
# |    total_timesteps | 115000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2350     |
# |    fps             | 122      |
# |    time_elapsed    | 958      |
# |    total_timesteps | 117500   |
# | train/             |          |
# |    actor_loss      | 1.9      |
# |    critic_loss     | 0.000139 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.263   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 116499   |
# ---------------------------------
# Eval num_timesteps=120000, episode_reward=-9.08 +/- 3.88
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.08    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 0.00017  |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.507   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 118999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 122      |
# |    time_elapsed    | 979      |
# |    total_timesteps | 120000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 2450     |
# |    fps             | 122      |
# |    time_elapsed    | 999      |
# |    total_timesteps | 122500   |
# | train/             |          |
# |    actor_loss      | 2.03     |
# |    critic_loss     | 0.000131 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.107   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 121499   |
# ---------------------------------
# Eval num_timesteps=125000, episode_reward=-5.29 +/- 2.36
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.29    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 125000   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 0.000124 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.0966  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 123999   |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 122      |
# |    time_elapsed    | 1020     |
# |    total_timesteps | 125000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2550     |
# |    fps             | 122      |
# |    time_elapsed    | 1040     |
# |    total_timesteps | 127500   |
# | train/             |          |
# |    actor_loss      | 1.84     |
# |    critic_loss     | 0.000132 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.255   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 126499   |
# ---------------------------------
# Eval num_timesteps=130000, episode_reward=-8.57 +/- 3.57
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.57    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 130000   |
# | train/             |          |
# |    actor_loss      | 2.23     |
# |    critic_loss     | 0.000167 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | 0.153    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 128999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 122      |
# |    time_elapsed    | 1061     |
# |    total_timesteps | 130000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 2650     |
# |    fps             | 122      |
# |    time_elapsed    | 1081     |
# |    total_timesteps | 132500   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.000191 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.26    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 131499   |
# ---------------------------------
# Eval num_timesteps=135000, episode_reward=-6.56 +/- 3.78
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.56    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 135000   |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 0.000121 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.28     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 133999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 122      |
# |    time_elapsed    | 1102     |
# |    total_timesteps | 135000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 2750     |
# |    fps             | 122      |
# |    time_elapsed    | 1122     |
# |    total_timesteps | 137500   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.000123 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -1.54    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 136499   |
# ---------------------------------
# Eval num_timesteps=140000, episode_reward=-6.34 +/- 2.81
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.34    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.000149 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.072   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 138999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 122      |
# |    time_elapsed    | 1143     |
# |    total_timesteps | 140000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 2850     |
# |    fps             | 122      |
# |    time_elapsed    | 1163     |
# |    total_timesteps | 142500   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.000112 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.0138  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 141499   |
# ---------------------------------
# Eval num_timesteps=145000, episode_reward=-5.70 +/- 2.97
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.7     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 145000   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 7.81e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.745   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 143999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 122      |
# |    time_elapsed    | 1184     |
# |    total_timesteps | 145000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 2950     |
# |    fps             | 122      |
# |    time_elapsed    | 1204     |
# |    total_timesteps | 147500   |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 0.000172 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 2.01     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 146499   |
# ---------------------------------
# Eval num_timesteps=150000, episode_reward=-9.19 +/- 2.37
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.19    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 150000   |
# | train/             |          |
# |    actor_loss      | 2.28     |
# |    critic_loss     | 0.000113 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.555   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 148999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 70.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 122      |
# |    time_elapsed    | 1226     |
# |    total_timesteps | 150000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 3050     |
# |    fps             | 122      |
# |    time_elapsed    | 1245     |
# |    total_timesteps | 152500   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.000216 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | 0.897    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 151499   |
# ---------------------------------
# Eval num_timesteps=155000, episode_reward=-6.45 +/- 3.06
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.45    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 155000   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 9.34e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | 0.0442   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 153999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 122      |
# |    time_elapsed    | 1267     |
# |    total_timesteps | 155000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 3150     |
# |    fps             | 122      |
# |    time_elapsed    | 1286     |
# |    total_timesteps | 157500   |
# | train/             |          |
# ...
# |    fps             | 121      |
# |    time_elapsed    | 1804     |
# |    total_timesteps | 220000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 4450     |
# |    fps             | 121      |
# |    time_elapsed    | 1824     |
# |    total_timesteps | 222500   |
# | train/             |          |
# |    actor_loss      | 2.3      |
# |    critic_loss     | 9.34e-05 |
# |    ent_coef        | 0.00102  |
# |    ent_coef_loss   | 0.475    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 221499   |
# ---------------------------------
# Eval num_timesteps=225000, episode_reward=-8.96 +/- 2.48
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.96    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 225000   |
# | train/             |          |
# |    actor_loss      | 2.34     |
# |    critic_loss     | 0.000108 |
# |    ent_coef        | 0.00102  |
# |    ent_coef_loss   | 0.159    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 223999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 4500     |
# |    fps             | 121      |
# |    time_elapsed    | 1846     |
# |    total_timesteps | 225000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 4550     |
# |    fps             | 121      |
# |    time_elapsed    | 1866     |
# |    total_timesteps | 227500   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 0.0001   |
# |    ent_coef        | 0.00102  |
# |    ent_coef_loss   | 0.259    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 226499   |
# ---------------------------------
# Eval num_timesteps=230000, episode_reward=-8.62 +/- 2.90
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.62    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 230000   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 7.56e-05 |
# |    ent_coef        | 0.00103  |
# |    ent_coef_loss   | 0.719    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 228999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 4600     |
# |    fps             | 121      |
# |    time_elapsed    | 1887     |
# |    total_timesteps | 230000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 4650     |
# |    fps             | 121      |
# |    time_elapsed    | 1907     |
# |    total_timesteps | 232500   |
# | train/             |          |
# |    actor_loss      | 2.22     |
# |    critic_loss     | 7.38e-05 |
# |    ent_coef        | 0.00103  |
# |    ent_coef_loss   | 0.438    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 231499   |
# ---------------------------------
# Eval num_timesteps=235000, episode_reward=-7.70 +/- 2.86
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.7     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 235000   |
# | train/             |          |
# |    actor_loss      | 2.04     |
# |    critic_loss     | 6.93e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.34     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 233999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 4700     |
# |    fps             | 121      |
# |    time_elapsed    | 1929     |
# |    total_timesteps | 235000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 4750     |
# |    fps             | 121      |
# |    time_elapsed    | 1949     |
# |    total_timesteps | 237500   |
# | train/             |          |
# |    actor_loss      | 2.23     |
# |    critic_loss     | 0.000119 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.315    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 236499   |
# ---------------------------------
# Eval num_timesteps=240000, episode_reward=-9.33 +/- 3.33
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.33    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 240000   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 7.12e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 1.56     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 238999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 4800     |
# |    fps             | 121      |
# |    time_elapsed    | 1971     |
# |    total_timesteps | 240000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 4850     |
# |    fps             | 121      |
# |    time_elapsed    | 1990     |
# |    total_timesteps | 242500   |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 8.91e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.0899   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 241499   |
# ---------------------------------
# Eval num_timesteps=245000, episode_reward=-8.76 +/- 2.70
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.76    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 245000   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 9.18e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.194    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 243999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 4900     |
# |    fps             | 121      |
# |    time_elapsed    | 2012     |
# |    total_timesteps | 245000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 4950     |
# |    fps             | 121      |
# |    time_elapsed    | 2032     |
# |    total_timesteps | 247500   |
# | train/             |          |
# |    actor_loss      | 2.04     |
# |    critic_loss     | 8.23e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 246499   |
# ---------------------------------
# Eval num_timesteps=250000, episode_reward=-6.60 +/- 3.66
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.6     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 250000   |
# | train/             |          |
# |    actor_loss      | 2.01     |
# |    critic_loss     | 5.81e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | 0.217    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 248999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 5000     |
# |    fps             | 121      |
# |    time_elapsed    | 2053     |
# |    total_timesteps | 250000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 5050     |
# |    fps             | 121      |
# |    time_elapsed    | 2073     |
# |    total_timesteps | 252500   |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 5.01e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.228   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 251499   |
# ---------------------------------
# Eval num_timesteps=255000, episode_reward=-6.91 +/- 3.56
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.91    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 255000   |
# | train/             |          |
# |    actor_loss      | 1.95     |
# |    critic_loss     | 5.58e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 253999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 5100     |
# |    fps             | 121      |
# |    time_elapsed    | 2095     |
# |    total_timesteps | 255000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 5150     |
# |    fps             | 121      |
# |    time_elapsed    | 2114     |
# |    total_timesteps | 257500   |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 5.39e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 256499   |
# ---------------------------------
# Eval num_timesteps=260000, episode_reward=-7.01 +/- 2.52
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.01    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 260000   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 6.47e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | 0.0616   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 258999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 5200     |
# |    fps             | 121      |
# |    time_elapsed    | 2136     |
# |    total_timesteps | 260000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 5250     |
# |    fps             | 121      |
# |    time_elapsed    | 2156     |
# |    total_timesteps | 262500   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 6.43e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -0.476   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 261499   |
# ---------------------------------
# Eval num_timesteps=265000, episode_reward=-7.89 +/- 2.65
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.89    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 265000   |
# | train/             |          |
# |    actor_loss      | 2.36     |
# |    critic_loss     | 7.62e-05 |
# |    ent_coef        | 0.00105  |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 263999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 5300     |
# |    fps             | 121      |
# |    time_elapsed    | 2177     |
# |    total_timesteps | 265000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 5350     |
# |    fps             | 121      |
# |    time_elapsed    | 2197     |
# |    total_timesteps | 267500   |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 4.21e-05 |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.621   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 266499   |
# ---------------------------------
# Eval num_timesteps=270000, episode_reward=-5.21 +/- 2.85
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.21    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 270000   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.00011  |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.686   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 268999   |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 5400     |
# |    fps             | 121      |
# |    time_elapsed    | 2219     |
# |    total_timesteps | 270000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 5450     |
# |    fps             | 121      |
# |    time_elapsed    | 2239     |
# |    total_timesteps | 272500   |
# | train/             |          |
# |    actor_loss      | 2.19     |
# |    critic_loss     | 6.2e-05  |
# |    ent_coef        | 0.00104  |
# |    ent_coef_loss   | -0.327   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 271499   |
# ---------------------------------

# %%
import gymnasium as gym
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import os

# --- Paths ---
save_dir = "./her_sac_FetchReach-v3_results/"
model_path = os.path.join(save_dir, "finetuned_model_v2.zip")  # Your latest fine-tuned model
vecnormalize_path = os.path.join(save_dir, "vecnormalize.pkl")

# --- Load environment ---
env = gym.make("FetchReach-v3", reward_type='dense')
env = DummyVecEnv([lambda: env])
env = VecNormalize.load(vecnormalize_path, env)
env.training = True

# --- Load model ---
model = SAC.load(model_path, env=env)

# --- Lower learning rate ---
model.learning_rate = 5e-5
model.actor.optimizer.param_groups[0]['lr'] = 5e-5
model.critic.optimizer.param_groups[0]['lr'] = 5e-5

# Increase HER aggressive sampling
if hasattr(model.replay_buffer, 'n_sampled_goal'):
    model.replay_buffer.n_sampled_goal = 16  # 🔥 More future goals per transition
    model.replay_buffer.goal_selection_strategy = 'future'
    print("✅ Aggressive HER sampling applied.")

# (❌ Skip clearing pos / full, don't reset manually!)

# Fine-tune
model.learn(
    total_timesteps=300_000,
    log_interval=50,
    # callback=eval_callback (optional)
)

# Save model
model.save(os.path.join(save_dir, "finetuned_model_v3_aggressive"))
env.save(os.path.join(save_dir, "vecnormalize.pkl"))

print("✅ Fine-tuning with aggressive HER sampling completed!")
# Out:
# ✅ Aggressive HER sampling applied.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 34
#      29     print("✅ Aggressive HER sampling applied.")
#      31 # (❌ Skip clearing pos / full, don't reset manually!)
#      32
#      33 # Fine-tune
# ---> 34 model.learn(
#      35     total_timesteps=300_000,
#      36     log_interval=50,
#      37     # callback=eval_callback (optional)
#      38 )
#      40 # Save model
#      41 model.save(os.path.join(save_dir, "finetuned_model_v3_aggressive"))
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/sac/sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/sac/sac.py:215, in SAC.train(self, gradient_steps, batch_size)
#     211 actor_losses, critic_losses = [], []
#     213 for gradient_step in range(gradient_steps):
#     214     # Sample replay buffer
# --> 215     replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)  # type: ignore[union-attr]
#     217     # We need to sample because `log_std` may have changed between two gradient steps
#     218     if self.use_sde:
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/her/her_replay_buffer.py:225, in HerReplayBuffer.sample(self, batch_size, env)
#     223 real_data = self._get_real_samples(real_batch_indices, real_env_indices, env)
#     224 # Create virtual transitions by sampling new desired goals and computing new rewards
# --> 225 virtual_data = self._get_virtual_samples(virtual_batch_indices, virtual_env_indices, env)
#     227 # Concatenate real and virtual data
#     228 observations = {
#     229     key: th.cat((real_data.observations[key], virtual_data.observations[key]))
#     230     for key in virtual_data.observations.keys()
#     231 }
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/her/her_replay_buffer.py:311, in HerReplayBuffer._get_virtual_samples(self, batch_indices, env_indices, env)
#     309     infos = [{} for _ in range(len(batch_indices))]
#     310 # Sample and set new goals
# --> 311 new_goals = self._sample_goals(batch_indices, env_indices)
#     312 obs["desired_goal"] = new_goals
#     313 # The desired goal for the next observation must be the same as the previous one
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/her/her_replay_buffer.py:381, in HerReplayBuffer._sample_goals(self, batch_indices, env_indices)
#     378     transition_indices_in_episode = np.random.randint(0, batch_ep_length)
#     380 else:
# --> 381     raise ValueError(f"Strategy {self.goal_selection_strategy} for sampling goals not supported!")
#     383 transition_indices = (transition_indices_in_episode + batch_ep_start) % self.buffer_size
#     384 return self.next_observations["achieved_goal"][transition_indices, env_indices]
#
# ValueError: Strategy future for sampling goals not supported!

# %%
import gymnasium_robotics
import gymnasium as gym
from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.callbacks import EvalCallback, CallbackList, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import os
import numpy as np

# --- Custom Callback ---
class StopTrainingOnSuccessRate(BaseCallback):
    """
    Custom callback to stop training once success rate exceeds threshold.
    """
    def __init__(self, success_threshold=0.90, eval_freq=5000, verbose=1):
        super().__init__(verbose)
        self.success_threshold = success_threshold
        self.eval_freq = eval_freq

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0:
            successes = []
            for _ in range(10):  # 10 evaluation episodes
                obs = self.training_env.reset()
                done = False
                while not done:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, reward, done, infos = self.training_env.step(action)
                    done = done[0]
                    infos = infos[0]
                successes.append(infos['is_success'])

            success_rate = np.mean(successes)

            if self.verbose > 0:
                print(f"✅ [Success Monitor] Success rate over 10 episodes: {success_rate*100:.2f}%")

            if success_rate >= self.success_threshold:
                print(f"🏆 [Stopping Early] Success rate {success_rate*100:.2f}% exceeded threshold {self.success_threshold*100:.2f}%!")
                return False  # Stop training

        return True  # Continue training otherwise

# --- Configuration ---
env_id = "FetchReach-v3"
save_dir = f"./her_sac_{env_id}_results/"
best_model_save_path = os.path.join(save_dir, "best_model")
final_model_save_path = os.path.join(save_dir, f"her_sac_{env_id}_final")

os.makedirs(save_dir, exist_ok=True)

# --- Environment Setup ---
env = gym.make(env_id, reward_type='dense')
env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=False)

# --- Agent Definition (SAC + HER) ---
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=8,
        goal_selection_strategy='future',
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_starts=1000,
    batch_size=512,
    learning_rate=1e-4,
    gamma=0.99,
    tau=0.005,
)

# --- Callbacks ---

# 1. Eval callback to monitor reward
eval_callback = EvalCallback(
    env,
    best_model_save_path=best_model_save_path,
    log_path=save_dir,
    eval_freq=5000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
    verbose=1,
)

# 2. Custom stop callback (stop if real success >90%)
success_stop_callback = StopTrainingOnSuccessRate(
    success_threshold=0.90,  # 90% success required
    eval_freq=5000,
    verbose=1
)

# 3. Combine them
callback = CallbackList([eval_callback, success_stop_callback])

# --- Training ---
print(f"🚀 Starting training SAC + HER on {env_id} with success-rate-based stopping...")
print(f"📂 Results and best model will be saved in: {save_dir}")

model.learn(
    total_timesteps=1_000_000,
    log_interval=50,
    callback=callback
)

# --- Save Final Model ---
model.save(final_model_save_path)
print(f"✅ Training finished. Final model saved to {final_model_save_path}")
print(f"✅ Best model during training saved in {best_model_save_path}")

# --- Save VecNormalize statistics ---
env.save(os.path.join(save_dir, "vecnormalize.pkl"))
print(f"✅ Saved VecNormalize statistics to {save_dir}/vecnormalize.pkl")

env.close()

# --- Final 1000 Episode Evaluation ---

print("\n🎯 Starting final evaluation over 1000 episodes...")

# Reload environment with saved normalization
eval_env = gym.make(env_id, reward_type='dense')
eval_env = DummyVecEnv([lambda: eval_env])
eval_env = VecNormalize.load(os.path.join(save_dir, "vecnormalize.pkl"), eval_env)
eval_env.training = False
eval_env.norm_reward = False

# Correctly load model
model = SAC.load(os.path.join(best_model_save_path, "best_model.zip"), env=eval_env)

successes = []

for _ in range(1000):
    obs = eval_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, infos = eval_env.step(action)
        done = done[0]
        infos = infos[0]
    successes.append(infos['is_success'])

success_rate = np.mean(successes) * 100.0
print(f"\n✅ Final Evaluation: Success Rate = {success_rate:.2f}% over 1000 episodes.")

if success_rate >= 90.0:
    print("🏆 Problem Solved! ✅ (Success > 90%)")
else:
    print("⚡ Problem Not Fully Solved. (Success < 90%)")
# Out:
# 2025-04-30 21:04:21.738511: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-30 21:04:22.035434: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-30 21:04:24.191089: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-30 21:04:28.871573: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using cuda device
# 🚀 Starting training SAC + HER on FetchReach-v3 with success-rate-based stopping...
# 📂 Results and best model will be saved in: ./her_sac_FetchReach-v3_results/
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 146      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -0.999   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1499     |
# ---------------------------------
# /home/tushard/miniconda3/envs/NLPproj/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=5000, episode_reward=-19.80 +/- 4.74
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -19.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 0.0934   |
# |    ent_coef        | 0.672    |
# |    ent_coef_loss   | -2.61    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3999     |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 126      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 126      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | -46.7    |
# |    critic_loss     | 0.0985   |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -4.12    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6499     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-15.55 +/- 3.95
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -15.6    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -53.6    |
# |    critic_loss     | 0.0807   |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | -5.56    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8999     |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 122      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 122      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 12500    |
# | train/             |          |
# |    actor_loss      | -56      |
# |    critic_loss     | 0.055    |
# |    ent_coef        | 0.319    |
# |    ent_coef_loss   | -6.93    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11499    |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-9.95 +/- 2.11
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.95    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -56.7    |
# |    critic_loss     | 0.0436   |
# |    ent_coef        | 0.249    |
# |    ent_coef_loss   | -8.52    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 120      |
# |    time_elapsed    | 124      |
# |    total_timesteps | 15000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 120      |
# |    time_elapsed    | 144      |
# |    total_timesteps | 17500    |
# | train/             |          |
# |    actor_loss      | -54.8    |
# |    critic_loss     | 0.0327   |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -9.84    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16499    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=-12.07 +/- 3.72
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -12.1    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -51.7    |
# |    critic_loss     | 0.019    |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 10.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 119      |
# |    time_elapsed    | 166      |
# |    total_timesteps | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 120      |
# |    time_elapsed    | 187      |
# |    total_timesteps | 22500    |
# | train/             |          |
# |    actor_loss      | -47.9    |
# |    critic_loss     | 0.0147   |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21499    |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=-6.53 +/- 1.54
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.53    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -44      |
# |    critic_loss     | 0.0108   |
# |    ent_coef        | 0.0919   |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 10.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 119      |
# |    time_elapsed    | 209      |
# |    total_timesteps | 25000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 119      |
# |    time_elapsed    | 229      |
# |    total_timesteps | 27500    |
# | train/             |          |
# |    actor_loss      | -39.4    |
# |    critic_loss     | 0.00836  |
# |    ent_coef        | 0.0718   |
# |    ent_coef_loss   | -14.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26499    |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=-8.42 +/- 3.28
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.42    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -35      |
# |    critic_loss     | 0.00726  |
# |    ent_coef        | 0.056    |
# |    ent_coef_loss   | -15.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 10.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 119      |
# |    time_elapsed    | 252      |
# |    total_timesteps | 30000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 119      |
# |    time_elapsed    | 272      |
# |    total_timesteps | 32500    |
# | train/             |          |
# |    actor_loss      | -31.1    |
# |    critic_loss     | 0.00594  |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31499    |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=-9.26 +/- 3.99
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.26    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 0.00379  |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | -17      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 118      |
# |    time_elapsed    | 294      |
# |    total_timesteps | 35000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 118      |
# |    time_elapsed    | 315      |
# |    total_timesteps | 37500    |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 0.00399  |
# |    ent_coef        | 0.0268   |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36499    |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=-7.99 +/- 3.20
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.99    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 0.00302  |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 118      |
# |    time_elapsed    | 337      |
# |    total_timesteps | 40000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 118      |
# |    time_elapsed    | 358      |
# |    total_timesteps | 42500    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.00248  |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -17.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 41499    |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=-7.05 +/- 2.95
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.05    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.00239  |
# |    ent_coef        | 0.0129   |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 118      |
# |    time_elapsed    | 380      |
# |    total_timesteps | 45000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 950      |
# |    fps             | 118      |
# |    time_elapsed    | 401      |
# |    total_timesteps | 47500    |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.00176  |
# |    ent_coef        | 0.0101   |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 46499    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-6.46 +/- 3.62
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.46    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.00153  |
# |    ent_coef        | 0.00797  |
# |    ent_coef_loss   | -16.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 48999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 118      |
# |    time_elapsed    | 423      |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 1050     |
# |    fps             | 118      |
# |    time_elapsed    | 444      |
# |    total_timesteps | 52500    |
# | train/             |          |
# |    actor_loss      | -9.36    |
# |    critic_loss     | 0.00146  |
# |    ent_coef        | 0.00627  |
# |    ent_coef_loss   | -15.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51499    |
# ---------------------------------
# Eval num_timesteps=55000, episode_reward=-8.34 +/- 3.61
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.34    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | -7.71    |
# |    critic_loss     | 0.000929 |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 117      |
# |    time_elapsed    | 466      |
# |    total_timesteps | 55000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1150     |
# |    fps             | 118      |
# |    time_elapsed    | 487      |
# |    total_timesteps | 57500    |
# | train/             |          |
# |    actor_loss      | -6.8     |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.00392  |
# |    ent_coef_loss   | -13.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 56499    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=-6.73 +/- 2.23
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.73    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -5.39    |
# |    critic_loss     | 0.00077  |
# |    ent_coef        | 0.00312  |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 58999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 80.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 117      |
# |    time_elapsed    | 509      |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1250     |
# |    fps             | 117      |
# |    time_elapsed    | 530      |
# |    total_timesteps | 62500    |
# | train/             |          |
# |    actor_loss      | -4.44    |
# |    critic_loss     | 0.000749 |
# |    ent_coef        | 0.00249  |
# |    ent_coef_loss   | -8.87    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61499    |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=-6.14 +/- 2.23
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.14    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | -3.58    |
# |    critic_loss     | 0.00068  |
# |    ent_coef        | 0.00201  |
# |    ent_coef_loss   | -5.09    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 63999    |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 117      |
# |    time_elapsed    | 552      |
# |    total_timesteps | 65000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1350     |
# |    fps             | 117      |
# |    time_elapsed    | 573      |
# |    total_timesteps | 67500    |
# | train/             |          |
# |    actor_loss      | -2.8     |
# |    critic_loss     | 0.000559 |
# |    ent_coef        | 0.00166  |
# |    ent_coef_loss   | -3.38    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 66499    |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=-8.26 +/- 2.82
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.26    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | -1.89    |
# |    critic_loss     | 0.000566 |
# |    ent_coef        | 0.00144  |
# |    ent_coef_loss   | -0.704   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 68999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 117      |
# |    time_elapsed    | 596      |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 1450     |
# |    fps             | 117      |
# |    time_elapsed    | 616      |
# |    total_timesteps | 72500    |
# | train/             |          |
# |    actor_loss      | -1.66    |
# |    critic_loss     | 0.000516 |
# |    ent_coef        | 0.00134  |
# |    ent_coef_loss   | -0.0328  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 71499    |
# ---------------------------------
# Eval num_timesteps=75000, episode_reward=-10.26 +/- 3.51
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.3    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | -1.18    |
# |    critic_loss     | 0.0005   |
# |    ent_coef        | 0.00131  |
# |    ent_coef_loss   | 0.555    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 73999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 117      |
# |    time_elapsed    | 639      |
# |    total_timesteps | 75000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 1550     |
# |    fps             | 117      |
# |    time_elapsed    | 659      |
# |    total_timesteps | 77500    |
# | train/             |          |
# |    actor_loss      | -0.772   |
# |    critic_loss     | 0.000396 |
# |    ent_coef        | 0.0013   |
# |    ent_coef_loss   | -0.56    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 76499    |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=-7.67 +/- 4.59
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.67    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -0.227   |
# |    critic_loss     | 0.000488 |
# |    ent_coef        | 0.00129  |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 78999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 117      |
# |    time_elapsed    | 682      |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1650     |
# |    fps             | 117      |
# |    time_elapsed    | 702      |
# |    total_timesteps | 82500    |
# | train/             |          |
# |    actor_loss      | -0.0553  |
# |    critic_loss     | 0.000347 |
# |    ent_coef        | 0.00126  |
# |    ent_coef_loss   | -1.22    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 81499    |
# ---------------------------------
# Eval num_timesteps=85000, episode_reward=-9.52 +/- 3.49
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.52    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 85000    |
# | train/             |          |
# |    actor_loss      | 0.467    |
# |    critic_loss     | 0.000326 |
# |    ent_coef        | 0.00123  |
# |    ent_coef_loss   | -0.881   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 83999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 117      |
# |    time_elapsed    | 725      |
# |    total_timesteps | 85000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1750     |
# |    fps             | 117      |
# |    time_elapsed    | 746      |
# |    total_timesteps | 87500    |
# | train/             |          |
# |    actor_loss      | 0.774    |
# |    critic_loss     | 0.000351 |
# |    ent_coef        | 0.00122  |
# |    ent_coef_loss   | -0.0487  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 86499    |
# ---------------------------------
# Eval num_timesteps=90000, episode_reward=-9.09 +/- 3.66
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.09    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | 0.747    |
# |    critic_loss     | 0.000351 |
# |    ent_coef        | 0.00121  |
# |    ent_coef_loss   | -0.733   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 88999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 117      |
# |    time_elapsed    | 769      |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1850     |
# |    fps             | 117      |
# |    time_elapsed    | 789      |
# |    total_timesteps | 92500    |
# | train/             |          |
# |    actor_loss      | 1.06     |
# |    critic_loss     | 0.000309 |
# |    ent_coef        | 0.0012   |
# |    ent_coef_loss   | 0.668    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91499    |
# ---------------------------------
# Eval num_timesteps=95000, episode_reward=-6.51 +/- 3.01
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.51    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 95000    |
# | train/             |          |
# |    actor_loss      | 1.39     |
# |    critic_loss     | 0.000302 |
# |    ent_coef        | 0.00119  |
# |    ent_coef_loss   | -0.159   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 116      |
# |    time_elapsed    | 812      |
# |    total_timesteps | 95000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 1950     |
# |    fps             | 117      |
# |    time_elapsed    | 833      |
# |    total_timesteps | 97500    |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 0.000263 |
# |    ent_coef        | 0.00118  |
# |    ent_coef_loss   | 0.796    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 96499    |
# ---------------------------------
# Eval num_timesteps=100000, episode_reward=-7.98 +/- 2.92
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.98    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.000273 |
# |    ent_coef        | 0.00119  |
# |    ent_coef_loss   | 0.492    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 98999    |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 116      |
# |    time_elapsed    | 855      |
# |    total_timesteps | 100000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2050     |
# |    fps             | 116      |
# |    time_elapsed    | 876      |
# |    total_timesteps | 102500   |
# | train/             |          |
# |    actor_loss      | 1.22     |
# |    critic_loss     | 0.000216 |
# |    ent_coef        | 0.00118  |
# |    ent_coef_loss   | -0.0421  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 101499   |
# ---------------------------------
# Eval num_timesteps=105000, episode_reward=-6.15 +/- 3.59
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.15    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 105000   |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.000287 |
# |    ent_coef        | 0.00118  |
# |    ent_coef_loss   | 0.0468   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 103999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 116      |
# |    time_elapsed    | 898      |
# |    total_timesteps | 105000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2150     |
# |    fps             | 117      |
# |    time_elapsed    | 918      |
# |    total_timesteps | 107500   |
# | train/             |          |
# |    actor_loss      | 1.83     |
# |    critic_loss     | 0.000254 |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | -0.432   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 106499   |
# ---------------------------------
# Eval num_timesteps=110000, episode_reward=-7.22 +/- 3.60
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.22    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 110000   |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 0.00023  |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | 0.305    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 108999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 116      |
# |    time_elapsed    | 940      |
# |    total_timesteps | 110000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2250     |
# |    fps             | 117      |
# |    time_elapsed    | 961      |
# |    total_timesteps | 112500   |
# | train/             |          |
# |    actor_loss      | 1.71     |
# |    critic_loss     | 0.00017  |
# |    ent_coef        | 0.00117  |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 111499   |
# ---------------------------------
# Eval num_timesteps=115000, episode_reward=-5.62 +/- 3.00
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.62    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 115000   |
# | train/             |          |
# |    actor_loss      | 2.03     |
# |    critic_loss     | 0.000192 |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | 0.242    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 113999   |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 116      |
# |    time_elapsed    | 983      |
# |    total_timesteps | 115000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2350     |
# |    fps             | 117      |
# |    time_elapsed    | 1004     |
# |    total_timesteps | 117500   |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.000215 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | 1.78     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 116499   |
# ---------------------------------
# Eval num_timesteps=120000, episode_reward=-7.79 +/- 4.28
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.79    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 0.000202 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | 0.872    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 118999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 116      |
# |    time_elapsed    | 1026     |
# |    total_timesteps | 120000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2450     |
# |    fps             | 117      |
# |    time_elapsed    | 1046     |
# |    total_timesteps | 122500   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.000153 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.611    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 121499   |
# ---------------------------------
# Eval num_timesteps=125000, episode_reward=-7.43 +/- 2.85
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.43    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 125000   |
# | train/             |          |
# |    actor_loss      | 2.3      |
# |    critic_loss     | 0.000406 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 1.07     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 123999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 116      |
# |    time_elapsed    | 1068     |
# |    total_timesteps | 125000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 2550     |
# |    fps             | 117      |
# |    time_elapsed    | 1089     |
# |    total_timesteps | 127500   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 0.000141 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 0.17     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 126499   |
# ---------------------------------
# Eval num_timesteps=130000, episode_reward=-8.37 +/- 3.85
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.37    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 130000   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.000165 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 0.672    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 128999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 116      |
# |    time_elapsed    | 1111     |
# |    total_timesteps | 130000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 2650     |
# |    fps             | 117      |
# |    time_elapsed    | 1131     |
# |    total_timesteps | 132500   |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 0.000172 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.877   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 131499   |
# ---------------------------------
# Eval num_timesteps=135000, episode_reward=-6.59 +/- 2.71
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.59    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 135000   |
# | train/             |          |
# |    actor_loss      | 2.4      |
# |    critic_loss     | 0.000141 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.572    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 133999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.48     |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 116      |
# |    time_elapsed    | 1154     |
# |    total_timesteps | 135000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2750     |
# |    fps             | 117      |
# |    time_elapsed    | 1174     |
# |    total_timesteps | 137500   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 0.000128 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.109   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 136499   |
# ---------------------------------
# Eval num_timesteps=140000, episode_reward=-8.23 +/- 2.04
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.23    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.000176 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.113    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 138999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 116      |
# |    time_elapsed    | 1196     |
# |    total_timesteps | 140000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2850     |
# |    fps             | 117      |
# |    time_elapsed    | 1217     |
# |    total_timesteps | 142500   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.000119 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -1.3     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 141499   |
# ---------------------------------
# Eval num_timesteps=145000, episode_reward=-7.86 +/- 4.17
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.86    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 145000   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.000174 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -1.75    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 143999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 116      |
# |    time_elapsed    | 1239     |
# |    total_timesteps | 145000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 2950     |
# |    fps             | 117      |
# |    time_elapsed    | 1259     |
# |    total_timesteps | 147500   |
# | train/             |          |
# |    actor_loss      | 2.21     |
# |    critic_loss     | 0.000115 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 0.935    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 146499   |
# ---------------------------------
# Eval num_timesteps=150000, episode_reward=-6.86 +/- 3.17
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.86    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 150000   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.000143 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | 0.0324   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 148999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 116      |
# |    time_elapsed    | 1282     |
# |    total_timesteps | 150000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 3050     |
# |    fps             | 117      |
# |    time_elapsed    | 1302     |
# |    total_timesteps | 152500   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 0.000125 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | 0.702    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 151499   |
# ---------------------------------
# ...
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 19000    |
# |    fps             | 113      |
# |    time_elapsed    | 8354     |
# |    total_timesteps | 950000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 19050    |
# |    fps             | 113      |
# |    time_elapsed    | 8376     |
# |    total_timesteps | 952500   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 1.49e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.127   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 951499   |
# ---------------------------------
# Eval num_timesteps=955000, episode_reward=-6.65 +/- 2.46
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.65    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 955000   |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 3.49e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.192    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 953999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 19100    |
# |    fps             | 113      |
# |    time_elapsed    | 8400     |
# |    total_timesteps | 955000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 19150    |
# |    fps             | 113      |
# |    time_elapsed    | 8422     |
# |    total_timesteps | 957500   |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 1.6e-05  |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.33     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 956499   |
# ---------------------------------
# Eval num_timesteps=960000, episode_reward=-6.76 +/- 3.63
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.76    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 960000   |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 1.89e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.754    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 958999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19200    |
# |    fps             | 113      |
# |    time_elapsed    | 8446     |
# |    total_timesteps | 960000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 19250    |
# |    fps             | 113      |
# |    time_elapsed    | 8468     |
# |    total_timesteps | 962500   |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 2.86e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.225   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 961499   |
# ---------------------------------
# Eval num_timesteps=965000, episode_reward=-7.40 +/- 3.82
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.4     |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 965000   |
# | train/             |          |
# |    actor_loss      | 2.38     |
# |    critic_loss     | 2.31e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 1.41     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 963999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19300    |
# |    fps             | 113      |
# |    time_elapsed    | 8492     |
# |    total_timesteps | 965000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.47     |
# | time/              |          |
# |    episodes        | 19350    |
# |    fps             | 113      |
# |    time_elapsed    | 8514     |
# |    total_timesteps | 967500   |
# | train/             |          |
# |    actor_loss      | 2.36     |
# |    critic_loss     | 2.38e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 1        |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 966499   |
# ---------------------------------
# Eval num_timesteps=970000, episode_reward=-6.60 +/- 3.55
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.6     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 970000   |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 1.8e-05  |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.488    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 968999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.48     |
# | time/              |          |
# |    episodes        | 19400    |
# |    fps             | 113      |
# |    time_elapsed    | 8538     |
# |    total_timesteps | 970000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19450    |
# |    fps             | 113      |
# |    time_elapsed    | 8559     |
# |    total_timesteps | 972500   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 2.63e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.375    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 971499   |
# ---------------------------------
# Eval num_timesteps=975000, episode_reward=-7.56 +/- 3.12
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.56    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 975000   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 2.58e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.569    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 973999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 19500    |
# |    fps             | 113      |
# |    time_elapsed    | 8583     |
# |    total_timesteps | 975000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 19550    |
# |    fps             | 113      |
# |    time_elapsed    | 8605     |
# |    total_timesteps | 977500   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 2.64e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.047    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 976499   |
# ---------------------------------
# Eval num_timesteps=980000, episode_reward=-7.06 +/- 3.09
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.06    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | 2.28     |
# |    critic_loss     | 1.58e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.299   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 978999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 19600    |
# |    fps             | 113      |
# |    time_elapsed    | 8629     |
# |    total_timesteps | 980000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 19650    |
# |    fps             | 113      |
# |    time_elapsed    | 8651     |
# |    total_timesteps | 982500   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 3.14e-05 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.89    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 981499   |
# ---------------------------------
# Eval num_timesteps=985000, episode_reward=-8.13 +/- 2.87
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.13    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 985000   |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 1.67e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.295    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 983999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19700    |
# |    fps             | 113      |
# |    time_elapsed    | 8676     |
# |    total_timesteps | 985000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 19750    |
# |    fps             | 113      |
# |    time_elapsed    | 8698     |
# |    total_timesteps | 987500   |
# | train/             |          |
# |    actor_loss      | 2.25     |
# |    critic_loss     | 4.06e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.78     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 986499   |
# ---------------------------------
# Eval num_timesteps=990000, episode_reward=-7.75 +/- 3.28
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.75    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 990000   |
# | train/             |          |
# |    actor_loss      | 1.91     |
# |    critic_loss     | 7.3e-05  |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.897   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 988999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 19800    |
# |    fps             | 113      |
# |    time_elapsed    | 8722     |
# |    total_timesteps | 990000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 19850    |
# |    fps             | 113      |
# |    time_elapsed    | 8744     |
# |    total_timesteps | 992500   |
# | train/             |          |
# |    actor_loss      | 2.06     |
# |    critic_loss     | 3.08e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.0689   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 991499   |
# ---------------------------------
# Eval num_timesteps=995000, episode_reward=-6.61 +/- 2.72
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.61    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 995000   |
# | train/             |          |
# |    actor_loss      | 1.91     |
# |    critic_loss     | 2.89e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 993999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 19900    |
# |    fps             | 113      |
# |    time_elapsed    | 8768     |
# |    total_timesteps | 995000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 19950    |
# |    fps             | 113      |
# |    time_elapsed    | 8790     |
# |    total_timesteps | 997500   |
# | train/             |          |
# |    actor_loss      | 1.9      |
# |    critic_loss     | 4.9e-05  |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 1.07     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 996499   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=-5.37 +/- 3.60
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.37    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 2.49e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -1.13    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 998999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate over 10 episodes: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 20000    |
# |    fps             | 113      |
# |    time_elapsed    | 8814     |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ✅ Training finished. Final model saved to ./her_sac_FetchReach-v3_results/her_sac_FetchReach-v3_final
# ✅ Best model during training saved in ./her_sac_FetchReach-v3_results/best_model
# ✅ Saved VecNormalize statistics to ./her_sac_FetchReach-v3_results//vecnormalize.pkl
#
# 🎯 Starting final evaluation over 1000 episodes...
#
# ✅ Final Evaluation: Success Rate = 35.60% over 1000 episodes.
# ⚡ Problem Not Fully Solved. (Success < 90%)

# %%
import gymnasium_robotics
import gymnasium as gym
from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.callbacks import EvalCallback, CallbackList, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import os
import numpy as np
import matplotlib.pyplot as plt

# --- Callback: Stop training if success > 90% ---
class StopTrainingOnSuccessRate(BaseCallback):
    def __init__(self, success_threshold=0.90, eval_freq=5000, verbose=1):
        super().__init__(verbose)
        self.success_threshold = success_threshold
        self.eval_freq = eval_freq

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0:
            successes = []
            for _ in range(10):
                obs = self.training_env.reset()
                done = False
                while not done:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, reward, done, infos = self.training_env.step(action)
                    done = done[0]
                    infos = infos[0]
                successes.append(infos['is_success'])
            success_rate = np.mean(successes)
            if self.verbose:
                print(f"✅ [Success Monitor] Success rate: {success_rate * 100:.2f}%")
            if success_rate >= self.success_threshold:
                print(f"🏆 [Early Stop] Success rate {success_rate * 100:.2f}% ≥ {self.success_threshold * 100:.2f}%")
                return False
        return True

# --- Callback: Save checkpoint if success > 80% ---
class CheckpointOnSuccessRate(BaseCallback):
    def __init__(self, save_path, success_threshold=0.80, eval_freq=5000, verbose=1):
        super().__init__(verbose)
        self.save_path = save_path
        self.success_threshold = success_threshold
        self.eval_freq = eval_freq
        self.saved = False

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0 and not self.saved:
            successes = []
            for _ in range(10):
                obs = self.training_env.reset()
                done = False
                while not done:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, reward, done, infos = self.training_env.step(action)
                    done = done[0]
                    infos = infos[0]
                successes.append(infos['is_success'])
            success_rate = np.mean(successes)
            if self.verbose:
                print(f"📦 [Checkpoint Check] Success rate: {success_rate * 100:.2f}%")
            if success_rate >= self.success_threshold:
                self.saved = True
                self.model.save(os.path.join(self.save_path, "checkpoint_model"))
                self.training_env.save(os.path.join(self.save_path, "checkpoint_vecnormalize.pkl"))
                print(f"✅ [Checkpoint Saved] at {success_rate * 100:.2f}% success rate")
        return True

# --- Configuration ---
env_id = "FetchReach-v3"
save_dir = f"./her_sac_{env_id}_results/"
best_model_save_path = os.path.join(save_dir, "best_model")
final_model_save_path = os.path.join(save_dir, f"her_sac_{env_id}_final")

os.makedirs(save_dir, exist_ok=True)

# --- Env Setup ---
env = gym.make(env_id, reward_type='dense')
env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=False)

# --- SAC + HER ---
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=8,
        goal_selection_strategy='future',
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_starts=1000,
    batch_size=512,
    learning_rate=1e-4,
    gamma=0.99,
    tau=0.005,
)

# --- Callbacks ---
eval_callback = EvalCallback(
    env,
    best_model_save_path=best_model_save_path,
    log_path=save_dir,
    eval_freq=5000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
    verbose=1,
)

stop_callback = StopTrainingOnSuccessRate(success_threshold=0.90, eval_freq=5000, verbose=1)
checkpoint_callback = CheckpointOnSuccessRate(save_path=save_dir, success_threshold=0.80, eval_freq=5000, verbose=1)

callback = CallbackList([eval_callback, checkpoint_callback, stop_callback])

# --- Training ---
print(f"🚀 Starting training SAC + HER on {env_id}...")
model.learn(
    total_timesteps=1_000_000,
    log_interval=50,
    callback=callback
)

# --- Save final model + VecNormalize ---
model.save(final_model_save_path)
env.save(os.path.join(save_dir, "vecnormalize.pkl"))
print("✅ Final model and VecNormalize saved.")

# --- Final 1000-episode eval ---
print("\n🎯 Running final 1000-episode evaluation...")
eval_env = gym.make(env_id, reward_type='dense')
eval_env = DummyVecEnv([lambda: eval_env])
eval_env = VecNormalize.load(os.path.join(save_dir, "vecnormalize.pkl"), eval_env)
eval_env.training = False
eval_env.norm_reward = False

model = SAC.load(os.path.join(best_model_save_path, "best_model.zip"), env=eval_env)

successes = []
for _ in range(1000):
    obs = eval_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, infos = eval_env.step(action)
        done = done[0]
        infos = infos[0]
    successes.append(infos['is_success'])

final_success = np.mean(successes) * 100.0
print(f"\n✅ Final Evaluation Success Rate: {final_success:.2f}%")
if final_success >= 90.0:
    print("🏆 Problem Solved!")
else:
    print("⚡ Not Fully Solved")

# --- Plot reward + success ---
print("\n📈 Plotting training curves...")
log_file = os.path.join(save_dir, "evaluations.npz")
if not os.path.exists(log_file):
    raise FileNotFoundError("No EvalCallback log file found!")

data = np.load(log_file)
timesteps = data["timesteps"]
results = data["results"]
mean_rewards = results.mean(axis=1)
success_rates = (results >= -1e-3).mean(axis=1) * 100

plt.figure(figsize=(10, 4))
plt.plot(timesteps, mean_rewards, label="Mean Eval Reward", color="blue")
plt.xlabel("Timesteps")
plt.ylabel("Mean Reward")
plt.title("Reward vs Timesteps")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(save_dir, "reward_plot.png"))
plt.close()

plt.figure(figsize=(10, 4))
plt.plot(timesteps, success_rates, label="Success Rate (%)", color="green")
plt.xlabel("Timesteps")
plt.ylabel("Success Rate (%)")
plt.title("Success Rate vs Timesteps")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(save_dir, "success_plot.png"))
plt.close()

print("✅ Plots saved: reward_plot.png & success_plot.png")
# Out:
# Using cuda device
# 🚀 Starting training SAC + HER on FetchReach-v3...
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 186      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.11     |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -0.996   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1499     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-17.72 +/- 2.62
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -17.7    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -35.7    |
# |    critic_loss     | 0.0989   |
# |    ent_coef        | 0.671    |
# |    ent_coef_loss   | -2.63    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3999     |
# ---------------------------------
# New best mean reward!
# 📦 [Checkpoint Check] Success rate: 0.00%
# ✅ [Success Monitor] Success rate: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 138      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 134      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | -46.3    |
# |    critic_loss     | 0.0919   |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -4.13    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6499     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-15.55 +/- 2.76
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -15.6    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -53      |
# |    critic_loss     | 0.0738   |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | -5.55    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8999     |
# ---------------------------------
# New best mean reward!
# 📦 [Checkpoint Check] Success rate: 0.00%
# ✅ [Success Monitor] Success rate: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 126      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 126      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 12500    |
# | train/             |          |
# |    actor_loss      | -55.8    |
# |    critic_loss     | 0.0597   |
# |    ent_coef        | 0.32     |
# |    ent_coef_loss   | -6.83    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11499    |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-11.53 +/- 3.20
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -11.5    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -56.6    |
# |    critic_loss     | 0.0471   |
# |    ent_coef        | 0.249    |
# |    ent_coef_loss   | -8.44    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13999    |
# ---------------------------------
# New best mean reward!
# 📦 [Checkpoint Check] Success rate: 0.00%
# ✅ [Success Monitor] Success rate: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 123      |
# |    time_elapsed    | 121      |
# |    total_timesteps | 15000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 123      |
# |    time_elapsed    | 141      |
# |    total_timesteps | 17500    |
# | train/             |          |
# |    actor_loss      | -54.8    |
# |    critic_loss     | 0.0352   |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -9.82    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16499    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=-7.46 +/- 2.50
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.46    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -51.9    |
# |    critic_loss     | 0.0239   |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -11.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18999    |
# ---------------------------------
# New best mean reward!
# 📦 [Checkpoint Check] Success rate: 30.00%
# ✅ [Success Monitor] Success rate: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 121      |
# |    time_elapsed    | 164      |
# |    total_timesteps | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 122      |
# |    time_elapsed    | 184      |
# |    total_timesteps | 22500    |
# | train/             |          |
# |    actor_loss      | -47.4    |
# |    critic_loss     | 0.0194   |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -12.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21499    |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=-8.92 +/- 3.57
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.92    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -43.9    |
# |    critic_loss     | 0.0106   |
# |    ent_coef        | 0.0919   |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 20.00%
# ✅ [Success Monitor] Success rate: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 120      |
# |    time_elapsed    | 207      |
# |    total_timesteps | 25000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 121      |
# |    time_elapsed    | 227      |
# |    total_timesteps | 27500    |
# | train/             |          |
# |    actor_loss      | -38.9    |
# |    critic_loss     | 0.00963  |
# |    ent_coef        | 0.0718   |
# |    ent_coef_loss   | -14.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26499    |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=-8.21 +/- 3.13
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.21    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -34.8    |
# |    critic_loss     | 0.00653  |
# |    ent_coef        | 0.056    |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 40.00%
# ✅ [Success Monitor] Success rate: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 119      |
# |    time_elapsed    | 250      |
# |    total_timesteps | 30000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 120      |
# |    time_elapsed    | 270      |
# |    total_timesteps | 32500    |
# | train/             |          |
# |    actor_loss      | -30.8    |
# |    critic_loss     | 0.00523  |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -17      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31499    |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=-8.18 +/- 2.59
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.18    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 0.00458  |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | -17.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 40.00%
# ✅ [Success Monitor] Success rate: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 119      |
# |    time_elapsed    | 293      |
# |    total_timesteps | 35000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 119      |
# |    time_elapsed    | 313      |
# |    total_timesteps | 37500    |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 0.00351  |
# |    ent_coef        | 0.0268   |
# |    ent_coef_loss   | -17.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36499    |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=-6.98 +/- 2.18
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.98    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -21.1    |
# |    critic_loss     | 0.00265  |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -18.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38999    |
# ---------------------------------
# New best mean reward!
# 📦 [Checkpoint Check] Success rate: 50.00%
# ✅ [Success Monitor] Success rate: 0.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 118      |
# |    time_elapsed    | 337      |
# |    total_timesteps | 40000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 118      |
# |    time_elapsed    | 357      |
# |    total_timesteps | 42500    |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 0.00216  |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -17.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 41499    |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=-7.94 +/- 3.28
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.94    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.00225  |
# |    ent_coef        | 0.0129   |
# |    ent_coef_loss   | -17.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 40.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 118      |
# |    time_elapsed    | 380      |
# |    total_timesteps | 45000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 950      |
# |    fps             | 118      |
# |    time_elapsed    | 400      |
# |    total_timesteps | 47500    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.00179  |
# |    ent_coef        | 0.0101   |
# |    ent_coef_loss   | -17.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 46499    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-8.99 +/- 3.76
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.99    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.00161  |
# |    ent_coef        | 0.00795  |
# |    ent_coef_loss   | -15.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 48999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 60.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 117      |
# |    time_elapsed    | 424      |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 1050     |
# |    fps             | 118      |
# |    time_elapsed    | 444      |
# |    total_timesteps | 52500    |
# | train/             |          |
# |    actor_loss      | -9.41    |
# |    critic_loss     | 0.00123  |
# |    ent_coef        | 0.00627  |
# |    ent_coef_loss   | -15.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51499    |
# ---------------------------------
# Eval num_timesteps=55000, episode_reward=-7.71 +/- 3.70
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.71    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | -8.13    |
# |    critic_loss     | 0.00101  |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -14.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 50.00%
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 117      |
# |    time_elapsed    | 467      |
# |    total_timesteps | 55000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1150     |
# |    fps             | 117      |
# |    time_elapsed    | 487      |
# |    total_timesteps | 57500    |
# | train/             |          |
# |    actor_loss      | -6.75    |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.00392  |
# |    ent_coef_loss   | -12.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 56499    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=-8.29 +/- 3.66
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.29    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -5.24    |
# |    critic_loss     | 0.000827 |
# |    ent_coef        | 0.00311  |
# |    ent_coef_loss   | -10.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 58999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 20.00%
# ✅ [Success Monitor] Success rate: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 117      |
# |    time_elapsed    | 510      |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 1250     |
# |    fps             | 117      |
# |    time_elapsed    | 531      |
# |    total_timesteps | 62500    |
# | train/             |          |
# |    actor_loss      | -4.41    |
# |    critic_loss     | 0.000833 |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | -7.5     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61499    |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=-6.28 +/- 3.03
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.28    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | -3.55    |
# |    critic_loss     | 0.000573 |
# |    ent_coef        | 0.00199  |
# |    ent_coef_loss   | -5.82    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 63999    |
# ---------------------------------
# New best mean reward!
# 📦 [Checkpoint Check] Success rate: 20.00%
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 117      |
# |    time_elapsed    | 554      |
# |    total_timesteps | 65000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 1350     |
# |    fps             | 117      |
# |    time_elapsed    | 574      |
# |    total_timesteps | 67500    |
# | train/             |          |
# |    actor_loss      | -3.1     |
# |    critic_loss     | 0.000653 |
# |    ent_coef        | 0.00161  |
# |    ent_coef_loss   | -4.45    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 66499    |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=-7.46 +/- 3.82
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.46    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 0.000685 |
# |    ent_coef        | 0.00134  |
# |    ent_coef_loss   | -2.25    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 68999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 30.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 117      |
# |    time_elapsed    | 598      |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1450     |
# |    fps             | 117      |
# |    time_elapsed    | 618      |
# |    total_timesteps | 72500    |
# | train/             |          |
# |    actor_loss      | -1.42    |
# |    critic_loss     | 0.000534 |
# |    ent_coef        | 0.00118  |
# |    ent_coef_loss   | -0.897   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 71499    |
# ---------------------------------
# Eval num_timesteps=75000, episode_reward=-5.26 +/- 2.35
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.26    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | -1.03    |
# |    critic_loss     | 0.000523 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 73999    |
# ---------------------------------
# New best mean reward!
# 📦 [Checkpoint Check] Success rate: 30.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 116      |
# |    time_elapsed    | 642      |
# |    total_timesteps | 75000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1550     |
# |    fps             | 116      |
# |    time_elapsed    | 662      |
# |    total_timesteps | 77500    |
# | train/             |          |
# |    actor_loss      | -0.677   |
# |    critic_loss     | 0.000453 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.107    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 76499    |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=-6.81 +/- 3.66
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.81    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -0.296   |
# |    critic_loss     | 0.00034  |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | 1.49     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 78999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 20.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 116      |
# |    time_elapsed    | 685      |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 1650     |
# |    fps             | 116      |
# |    time_elapsed    | 706      |
# |    total_timesteps | 82500    |
# | train/             |          |
# |    actor_loss      | 0.217    |
# |    critic_loss     | 0.000434 |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | 0.0267   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 81499    |
# ---------------------------------
# Eval num_timesteps=85000, episode_reward=-8.23 +/- 2.75
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.23    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 85000    |
# | train/             |          |
# |    actor_loss      | 0.333    |
# |    critic_loss     | 0.000315 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | 0.601    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 83999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 50.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 116      |
# |    time_elapsed    | 729      |
# |    total_timesteps | 85000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1750     |
# |    fps             | 116      |
# |    time_elapsed    | 749      |
# |    total_timesteps | 87500    |
# | train/             |          |
# |    actor_loss      | 0.534    |
# |    critic_loss     | 0.000442 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.196   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 86499    |
# ---------------------------------
# Eval num_timesteps=90000, episode_reward=-8.06 +/- 3.53
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.06    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | 0.657    |
# |    critic_loss     | 0.000449 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 88999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 40.00%
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 116      |
# |    time_elapsed    | 773      |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 1850     |
# |    fps             | 116      |
# |    time_elapsed    | 794      |
# |    total_timesteps | 92500    |
# | train/             |          |
# |    actor_loss      | 1.1      |
# |    critic_loss     | 0.000329 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.992    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91499    |
# ---------------------------------
# Eval num_timesteps=95000, episode_reward=-6.70 +/- 3.23
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.7     |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 95000    |
# | train/             |          |
# |    actor_loss      | 1.27     |
# |    critic_loss     | 0.00025  |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | -0.366   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 30.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 116      |
# |    time_elapsed    | 817      |
# |    total_timesteps | 95000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 1950     |
# |    fps             | 116      |
# |    time_elapsed    | 838      |
# |    total_timesteps | 97500    |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 0.000334 |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | 0.000585 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 96499    |
# ---------------------------------
# Eval num_timesteps=100000, episode_reward=-7.98 +/- 4.07
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.98    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | 1.28     |
# |    critic_loss     | 0.000293 |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | -0.509   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 98999    |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 30.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 116      |
# |    time_elapsed    | 861      |
# |    total_timesteps | 100000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2050     |
# |    fps             | 116      |
# |    time_elapsed    | 881      |
# |    total_timesteps | 102500   |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.00022  |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | -0.246   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 101499   |
# ---------------------------------
# Eval num_timesteps=105000, episode_reward=-7.50 +/- 3.12
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.5     |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 105000   |
# | train/             |          |
# |    actor_loss      | 1.73     |
# |    critic_loss     | 0.000285 |
# |    ent_coef        | 0.00117  |
# |    ent_coef_loss   | -0.205   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 103999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 20.00%
# ✅ [Success Monitor] Success rate: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 116      |
# |    time_elapsed    | 904      |
# |    total_timesteps | 105000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 2150     |
# |    fps             | 116      |
# |    time_elapsed    | 924      |
# |    total_timesteps | 107500   |
# | train/             |          |
# |    actor_loss      | 1.91     |
# |    critic_loss     | 0.000155 |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | -1.55    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 106499   |
# ---------------------------------
# Eval num_timesteps=110000, episode_reward=-7.69 +/- 3.84
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.69    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 110000   |
# | train/             |          |
# |    actor_loss      | 1.75     |
# |    critic_loss     | 0.000215 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | -0.458   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 108999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 30.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 116      |
# |    time_elapsed    | 947      |
# |    total_timesteps | 110000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2250     |
# |    fps             | 116      |
# |    time_elapsed    | 967      |
# |    total_timesteps | 112500   |
# | train/             |          |
# |    actor_loss      | 1.8      |
# |    critic_loss     | 0.000253 |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 111499   |
# ---------------------------------
# Eval num_timesteps=115000, episode_reward=-6.54 +/- 2.33
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.54    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 115000   |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 0.000219 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 113999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 70.00%
# ✅ [Success Monitor] Success rate: 70.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 116      |
# |    time_elapsed    | 990      |
# |    total_timesteps | 115000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2350     |
# |    fps             | 116      |
# |    time_elapsed    | 1010     |
# |    total_timesteps | 117500   |
# | train/             |          |
# |    actor_loss      | 1.9      |
# |    critic_loss     | 0.00026  |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.961   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 116499   |
# ---------------------------------
# Eval num_timesteps=120000, episode_reward=-7.73 +/- 3.34
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.73    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | 1.96     |
# |    critic_loss     | 0.000206 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.37     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 118999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 20.00%
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.47     |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 116      |
# |    time_elapsed    | 1033     |
# |    total_timesteps | 120000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2450     |
# |    fps             | 116      |
# |    time_elapsed    | 1052     |
# |    total_timesteps | 122500   |
# | train/             |          |
# |    actor_loss      | 2.04     |
# |    critic_loss     | 0.000311 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 1.85     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 121499   |
# ---------------------------------
# Eval num_timesteps=125000, episode_reward=-6.70 +/- 3.25
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.7     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 125000   |
# | train/             |          |
# |    actor_loss      | 2.25     |
# |    critic_loss     | 0.00018  |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.588    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 123999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 20.00%
# ✅ [Success Monitor] Success rate: 10.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 116      |
# |    time_elapsed    | 1075     |
# |    total_timesteps | 125000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 2550     |
# |    fps             | 116      |
# |    time_elapsed    | 1095     |
# |    total_timesteps | 127500   |
# | train/             |          |
# |    actor_loss      | 1.94     |
# |    critic_loss     | 0.000172 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | 0.342    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 126499   |
# ---------------------------------
# Eval num_timesteps=130000, episode_reward=-7.33 +/- 1.59
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.33    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 130000   |
# | train/             |          |
# |    actor_loss      | 1.87     |
# |    critic_loss     | 0.000132 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -0.684   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 128999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 60.00%
# ✅ [Success Monitor] Success rate: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 116      |
# |    time_elapsed    | 1118     |
# |    total_timesteps | 130000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2650     |
# |    fps             | 116      |
# |    time_elapsed    | 1138     |
# |    total_timesteps | 132500   |
# | train/             |          |
# |    actor_loss      | 2.21     |
# |    critic_loss     | 0.000172 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 0.518    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 131499   |
# ---------------------------------
# Eval num_timesteps=135000, episode_reward=-6.33 +/- 3.54
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.33    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 135000   |
# | train/             |          |
# |    actor_loss      | 2.3      |
# |    critic_loss     | 0.00012  |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -0.676   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 133999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 30.00%
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 116      |
# |    time_elapsed    | 1161     |
# |    total_timesteps | 135000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.48     |
# | time/              |          |
# |    episodes        | 2750     |
# |    fps             | 116      |
# |    time_elapsed    | 1181     |
# |    total_timesteps | 137500   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.000189 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 136499   |
# ---------------------------------
# Eval num_timesteps=140000, episode_reward=-8.37 +/- 2.73
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.37    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.000198 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | 0.339    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 138999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 70.00%
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 116      |
# |    time_elapsed    | 1204     |
# |    total_timesteps | 140000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 2850     |
# |    fps             | 116      |
# |    time_elapsed    | 1224     |
# |    total_timesteps | 142500   |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 0.000114 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | -0.84    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 141499   |
# ---------------------------------
# Eval num_timesteps=145000, episode_reward=-7.39 +/- 3.64
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.39    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 145000   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 0.000223 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.44    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 143999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 20.00%
# ✅ [Success Monitor] Success rate: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 116      |
# |    time_elapsed    | 1247     |
# |    total_timesteps | 145000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 2950     |
# |    fps             | 116      |
# |    time_elapsed    | 1267     |
# |    total_timesteps | 147500   |
# | train/             |          |
# |    actor_loss      | 2.27     |
# |    critic_loss     | 0.000122 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.536    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 146499   |
# ---------------------------------
# Eval num_timesteps=150000, episode_reward=-7.62 +/- 2.09
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.62    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 150000   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.000147 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.615   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 148999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 40.00%
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 116      |
# |    time_elapsed    | 1290     |
# |    total_timesteps | 150000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 3050     |
# |    fps             | 116      |
# |    time_elapsed    | 1310     |
# |    total_timesteps | 152500   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 0.000136 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -1.37    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 151499   |
# ---------------------------------
# Eval num_timesteps=155000, episode_reward=-7.16 +/- 2.39
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.16    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 155000   |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 0.000158 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | 0.866    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 153999   |
# ---------------------------------
# 📦 [Checkpoint Check] Success rate: 60.00%
# ...
# |    total_timesteps | 950000   |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 2.33e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.932    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 948999   |
# ---------------------------------
# New best mean reward!
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19000    |
# |    fps             | 113      |
# |    time_elapsed    | 8334     |
# |    total_timesteps | 950000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 19050    |
# |    fps             | 113      |
# |    time_elapsed    | 8356     |
# |    total_timesteps | 952500   |
# | train/             |          |
# |    actor_loss      | 1.86     |
# |    critic_loss     | 1.51e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.224   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 951499   |
# ---------------------------------
# Eval num_timesteps=955000, episode_reward=-9.07 +/- 3.67
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.07    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 955000   |
# | train/             |          |
# |    actor_loss      | 1.85     |
# |    critic_loss     | 2.82e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.258   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 953999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19100    |
# |    fps             | 113      |
# |    time_elapsed    | 8380     |
# |    total_timesteps | 955000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 19150    |
# |    fps             | 113      |
# |    time_elapsed    | 8402     |
# |    total_timesteps | 957500   |
# | train/             |          |
# |    actor_loss      | 2.35     |
# |    critic_loss     | 1.62e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.296   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 956499   |
# ---------------------------------
# Eval num_timesteps=960000, episode_reward=-7.09 +/- 3.61
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.09    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 960000   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 1.92e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.71    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 958999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.52     |
# | time/              |          |
# |    episodes        | 19200    |
# |    fps             | 113      |
# |    time_elapsed    | 8427     |
# |    total_timesteps | 960000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 19250    |
# |    fps             | 113      |
# |    time_elapsed    | 8449     |
# |    total_timesteps | 962500   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 1.31e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.635    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 961499   |
# ---------------------------------
# Eval num_timesteps=965000, episode_reward=-8.45 +/- 2.75
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.45    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 965000   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 7e-05    |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.537   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 963999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 20.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 19300    |
# |    fps             | 113      |
# |    time_elapsed    | 8473     |
# |    total_timesteps | 965000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19350    |
# |    fps             | 113      |
# |    time_elapsed    | 8495     |
# |    total_timesteps | 967500   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 2.1e-05  |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.148   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 966499   |
# ---------------------------------
# Eval num_timesteps=970000, episode_reward=-5.55 +/- 3.27
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.55    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 970000   |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 3.27e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.737    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 968999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19400    |
# |    fps             | 113      |
# |    time_elapsed    | 8519     |
# |    total_timesteps | 970000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 19450    |
# |    fps             | 113      |
# |    time_elapsed    | 8541     |
# |    total_timesteps | 972500   |
# | train/             |          |
# |    actor_loss      | 2.28     |
# |    critic_loss     | 2.26e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.814   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 971499   |
# ---------------------------------
# Eval num_timesteps=975000, episode_reward=-6.54 +/- 2.08
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.54    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 975000   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 3.97e-05 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.516   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 973999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 60.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 19500    |
# |    fps             | 113      |
# |    time_elapsed    | 8566     |
# |    total_timesteps | 975000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 19550    |
# |    fps             | 113      |
# |    time_elapsed    | 8588     |
# |    total_timesteps | 977500   |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 8.53e-05 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 976499   |
# ---------------------------------
# Eval num_timesteps=980000, episode_reward=-5.80 +/- 3.12
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.8     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | 1.99     |
# |    critic_loss     | 5.09e-05 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 978999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 19600    |
# |    fps             | 113      |
# |    time_elapsed    | 8612     |
# |    total_timesteps | 980000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 19650    |
# |    fps             | 113      |
# |    time_elapsed    | 8634     |
# |    total_timesteps | 982500   |
# | train/             |          |
# |    actor_loss      | 2.22     |
# |    critic_loss     | 5.4e-05  |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.0452  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 981499   |
# ---------------------------------
# Eval num_timesteps=985000, episode_reward=-8.07 +/- 3.42
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.07    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 985000   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 2.51e-05 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | 1.61     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 983999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 19700    |
# |    fps             | 113      |
# |    time_elapsed    | 8658     |
# |    total_timesteps | 985000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19750    |
# |    fps             | 113      |
# |    time_elapsed    | 8681     |
# |    total_timesteps | 987500   |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 2.59e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 986499   |
# ---------------------------------
# Eval num_timesteps=990000, episode_reward=-9.32 +/- 4.21
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.32    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 990000   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 2.04e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.0704   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 988999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 50.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 19800    |
# |    fps             | 113      |
# |    time_elapsed    | 8705     |
# |    total_timesteps | 990000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 19850    |
# |    fps             | 113      |
# |    time_elapsed    | 8727     |
# |    total_timesteps | 992500   |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 2.03e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | -0.368   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 991499   |
# ---------------------------------
# Eval num_timesteps=995000, episode_reward=-8.17 +/- 3.73
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.17    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 995000   |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 3.44e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.0841   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 993999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 40.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 19900    |
# |    fps             | 113      |
# |    time_elapsed    | 8751     |
# |    total_timesteps | 995000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 19950    |
# |    fps             | 113      |
# |    time_elapsed    | 8773     |
# |    total_timesteps | 997500   |
# | train/             |          |
# |    actor_loss      | 2.25     |
# |    critic_loss     | 3.68e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 996499   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=-7.28 +/- 2.99
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.28    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 1.85     |
# |    critic_loss     | 1.4e-05  |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -0.619   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 998999   |
# ---------------------------------
# ✅ [Success Monitor] Success rate: 30.00%
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 20000    |
# |    fps             | 113      |
# |    time_elapsed    | 8798     |
# |    total_timesteps | 1000000  |
# ---------------------------------
# ✅ Final model and VecNormalize saved.
#
# 🎯 Running final 1000-episode evaluation...
#
# ✅ Final Evaluation Success Rate: 36.40%
# ⚡ Not Fully Solved
#
# 📈 Plotting training curves...
# ✅ Plots saved: reward_plot.png & success_plot.png

# %% [markdown]
# FINE TUNING:

# %%
import os
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import SAC
from stable_baselines3.her.her_replay_buffer import HerReplayBuffer
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# --- Paths ---
checkpoint_dir = "./her_sac_FetchReach-v3_results/"
model_path = os.path.join(checkpoint_dir, "checkpoint_model.zip")  # ✅ 70% checkpoint
vecnorm_path = os.path.join(checkpoint_dir, "checkpoint_vecnormalize.pkl")
save_path = os.path.join(checkpoint_dir, "finetuned_model_stage3.zip")

# --- Reload environment ---
env = gym.make("FetchReach-v3", reward_type="dense")
env = DummyVecEnv([lambda: env])
env = VecNormalize.load(vecnorm_path, env)
env.training = True
env.norm_reward = False

# --- Load model ---
model = SAC.load(model_path, env=env)

# --- Conservative hyperparameters ---
model.learning_rate = 2e-5
model.learning_starts = 5000
model.actor.optimizer.param_groups[0]['lr'] = 2e-5
model.critic.optimizer.param_groups[0]['lr'] = 2e-5
model.batch_size = 1024

# ✅ Reset HER buffer with reduced goal sampling
model.replay_buffer = HerReplayBuffer(
    buffer_size=model.buffer_size,
    observation_space=model.observation_space,
    action_space=model.action_space,
    env=env,
    device=model.device,
    n_envs=1,
    optimize_memory_usage=False,
    handle_timeout_termination=True,
    n_sampled_goal=4,
    goal_selection_strategy="future"
)

# ✅ Prefill with 1 episode
print("📦 Prefilling HER buffer with 1 episode...")
obs = env.reset()
done = [False]
step = 0
while not done[0] and step < 60:
    action, _ = model.predict(obs, deterministic=False)
    next_obs, reward, done, info = env.step(action)
    model.replay_buffer.add(obs, next_obs, action, reward, done, info)
    obs = next_obs
    step += 1

# --- Callbacks ---
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=-5.0, verbose=1)
eval_callback = EvalCallback(
    env,
    best_model_save_path=os.path.join(checkpoint_dir, "finetuned_best_model_stage3"),
    log_path=checkpoint_dir,
    eval_freq=5000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
    callback_on_new_best=stop_callback,
    verbose=1
)

# --- Start fine-tuning ---
print("🚀 Starting Stage 3 Conservative Fine-Tuning...")
model.learn(
    total_timesteps=100_000,
    log_interval=50,
    callback=eval_callback,
    reset_num_timesteps=False
)

# --- Save model and vecnormalize ---
model.save(save_path)
env.save(os.path.join(checkpoint_dir, "vecnormalize_stage3.pkl"))
print(f"✅ Stage 3 fine-tuning complete. Model saved to: {save_path}")

# --- Plotting with true success rates ---
print("\n📈 Plotting updated reward + success rate curves...")

eval_file = os.path.join(checkpoint_dir, "evaluations.npz")
success_file = os.path.join(checkpoint_dir, "evaluations", "ep_success.npy")

if not os.path.exists(eval_file):
    raise FileNotFoundError("❌ Missing evaluations.npz")

data = np.load(eval_file)
timesteps = data["timesteps"]
results = data["results"]
mean_rewards = results.mean(axis=1)

if os.path.exists(success_file):
    successes = np.load(success_file)
    success_rates = successes.mean(axis=1) * 100
else:
    print("⚠️ Falling back to reward threshold for success plot.")
    success_rates = (results >= -1e-3).mean(axis=1) * 100

# Plot reward
plt.figure(figsize=(10, 4))
plt.plot(timesteps, mean_rewards, label="Mean Eval Reward", color="blue")
plt.xlabel("Timesteps")
plt.ylabel("Mean Reward")
plt.title("Fine-Tuning Stage 3: Reward vs Timesteps")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(checkpoint_dir, "finetune_stage3_reward_plot.png"))
plt.close()

# Plot success
plt.figure(figsize=(10, 4))
plt.plot(timesteps, success_rates, label="Success Rate", color="green")
plt.xlabel("Timesteps")
plt.ylabel("Success Rate (%)")
plt.title("Fine-Tuning Stage 3: Success Rate vs Timesteps")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(checkpoint_dir, "finetune_stage3_success_plot.png"))
plt.close()

print("✅ Plots saved:")
print("   🔹 finetune_stage3_reward_plot.png")
print("   🔹 finetune_stage3_success_plot.png")
# Out:
# 📦 Prefilling HER buffer with 1 episode...
# 🚀 Starting Stage 3 Conservative Fine-Tuning...
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 121      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 310050   |
# | train/             |          |
# |    actor_loss      | 24.4     |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 181      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 309048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 6250     |
# |    fps             | 121      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 312550   |
# | train/             |          |
# |    actor_loss      | 2.7      |
# |    critic_loss     | 0.0802   |
# |    ent_coef        | 0.00132  |
# |    ent_coef_loss   | 20.9     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 311548   |
# ---------------------------------
# Eval num_timesteps=315000, episode_reward=-8.72 +/- 3.62
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.72    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 315000   |
# | train/             |          |
# |    actor_loss      | 2.88     |
# |    critic_loss     | 0.00281  |
# |    ent_coef        | 0.00157  |
# |    ent_coef_loss   | 14.2     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 313998   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 6300     |
# |    fps             | 119      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 315050   |
# | train/             |          |
# |    actor_loss      | 2.81     |
# |    critic_loss     | 0.0527   |
# |    ent_coef        | 0.00158  |
# |    ent_coef_loss   | 15.3     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 314048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 6350     |
# |    fps             | 120      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 317550   |
# | train/             |          |
# |    actor_loss      | 2.88     |
# |    critic_loss     | 0.00335  |
# |    ent_coef        | 0.00191  |
# |    ent_coef_loss   | 8.21     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 316548   |
# ---------------------------------
# Eval num_timesteps=320000, episode_reward=-6.57 +/- 3.49
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.57    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 320000   |
# | train/             |          |
# |    actor_loss      | 3.02     |
# |    critic_loss     | 0.0018   |
# |    ent_coef        | 0.00227  |
# |    ent_coef_loss   | 2.07     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 318998   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 6400     |
# |    fps             | 119      |
# |    time_elapsed    | 84       |
# |    total_timesteps | 320050   |
# | train/             |          |
# |    actor_loss      | 2.69     |
# |    critic_loss     | 0.00133  |
# |    ent_coef        | 0.00228  |
# |    ent_coef_loss   | 2.63     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 319048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 6450     |
# |    fps             | 119      |
# |    time_elapsed    | 104      |
# |    total_timesteps | 322550   |
# | train/             |          |
# |    actor_loss      | 3.12     |
# |    critic_loss     | 0.101    |
# |    ent_coef        | 0.00254  |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 321548   |
# ---------------------------------
# Eval num_timesteps=325000, episode_reward=-8.20 +/- 3.66
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.2     |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 325000   |
# | train/             |          |
# |    actor_loss      | 3.11     |
# |    critic_loss     | 0.0089   |
# |    ent_coef        | 0.00244  |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 323998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 6500     |
# |    fps             | 119      |
# |    time_elapsed    | 126      |
# |    total_timesteps | 325050   |
# | train/             |          |
# |    actor_loss      | 3.02     |
# |    critic_loss     | 0.00783  |
# |    ent_coef        | 0.00243  |
# |    ent_coef_loss   | 1.09     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 324048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 6550     |
# |    fps             | 119      |
# |    time_elapsed    | 146      |
# |    total_timesteps | 327550   |
# | train/             |          |
# |    actor_loss      | 3.21     |
# |    critic_loss     | 0.00261  |
# |    ent_coef        | 0.00222  |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 326548   |
# ---------------------------------
# Eval num_timesteps=330000, episode_reward=-7.29 +/- 3.37
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.29    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 330000   |
# | train/             |          |
# |    actor_loss      | 3.25     |
# |    critic_loss     | 0.00168  |
# |    ent_coef        | 0.00219  |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 328998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 6600     |
# |    fps             | 119      |
# |    time_elapsed    | 168      |
# |    total_timesteps | 330050   |
# | train/             |          |
# |    actor_loss      | 3.6      |
# |    critic_loss     | 0.00143  |
# |    ent_coef        | 0.00219  |
# |    ent_coef_loss   | -0.809   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 329048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 6650     |
# |    fps             | 119      |
# |    time_elapsed    | 188      |
# |    total_timesteps | 332550   |
# | train/             |          |
# |    actor_loss      | 3.48     |
# |    critic_loss     | 0.000925 |
# |    ent_coef        | 0.00219  |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 331548   |
# ---------------------------------
# Eval num_timesteps=335000, episode_reward=-9.19 +/- 2.69
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.19    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 335000   |
# | train/             |          |
# |    actor_loss      | 3.32     |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.0023   |
# |    ent_coef_loss   | -0.016   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 333998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 6700     |
# |    fps             | 118      |
# |    time_elapsed    | 210      |
# |    total_timesteps | 335050   |
# | train/             |          |
# |    actor_loss      | 3.42     |
# |    critic_loss     | 0.000991 |
# |    ent_coef        | 0.0023   |
# |    ent_coef_loss   | -0.989   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 334048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 6750     |
# |    fps             | 119      |
# |    time_elapsed    | 231      |
# |    total_timesteps | 337550   |
# | train/             |          |
# |    actor_loss      | 3.35     |
# |    critic_loss     | 0.00111  |
# |    ent_coef        | 0.00229  |
# |    ent_coef_loss   | -0.603   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 336548   |
# ---------------------------------
# Eval num_timesteps=340000, episode_reward=-6.06 +/- 3.42
# Episode length: 50.00 +/- 0.00
# Success rate: 80.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.06    |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    total_timesteps | 340000   |
# | train/             |          |
# |    actor_loss      | 3.45     |
# |    critic_loss     | 0.0149   |
# |    ent_coef        | 0.00234  |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 338998   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 6800     |
# |    fps             | 118      |
# |    time_elapsed    | 253      |
# |    total_timesteps | 340050   |
# | train/             |          |
# |    actor_loss      | 3.37     |
# |    critic_loss     | 0.0158   |
# |    ent_coef        | 0.00234  |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 339048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 6850     |
# |    fps             | 118      |
# |    time_elapsed    | 274      |
# |    total_timesteps | 342550   |
# | train/             |          |
# |    actor_loss      | 3.47     |
# |    critic_loss     | 0.00149  |
# |    ent_coef        | 0.00231  |
# |    ent_coef_loss   | -1.15    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 341548   |
# ---------------------------------
# Eval num_timesteps=345000, episode_reward=-7.00 +/- 2.89
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7       |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 345000   |
# | train/             |          |
# |    actor_loss      | 3.3      |
# |    critic_loss     | 0.00101  |
# |    ent_coef        | 0.00238  |
# |    ent_coef_loss   | -0.933   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 343998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 6900     |
# |    fps             | 118      |
# |    time_elapsed    | 296      |
# |    total_timesteps | 345050   |
# | train/             |          |
# |    actor_loss      | 3.53     |
# |    critic_loss     | 0.00213  |
# |    ent_coef        | 0.00237  |
# |    ent_coef_loss   | 0.252    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 344048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 6950     |
# |    fps             | 118      |
# |    time_elapsed    | 317      |
# |    total_timesteps | 347550   |
# | train/             |          |
# |    actor_loss      | 3.67     |
# |    critic_loss     | 0.000881 |
# |    ent_coef        | 0.00239  |
# |    ent_coef_loss   | -0.546   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 346548   |
# ---------------------------------
# Eval num_timesteps=350000, episode_reward=-7.55 +/- 2.93
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.55    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 350000   |
# | train/             |          |
# |    actor_loss      | 3.6      |
# |    critic_loss     | 0.00172  |
# |    ent_coef        | 0.00232  |
# |    ent_coef_loss   | -1.44    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 348998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 7000     |
# |    fps             | 117      |
# |    time_elapsed    | 339      |
# |    total_timesteps | 350050   |
# | train/             |          |
# |    actor_loss      | 3.62     |
# |    critic_loss     | 0.00342  |
# |    ent_coef        | 0.00232  |
# |    ent_coef_loss   | 0.45     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 349048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 7050     |
# |    fps             | 117      |
# |    time_elapsed    | 361      |
# |    total_timesteps | 352550   |
# | train/             |          |
# |    actor_loss      | 3.75     |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.00237  |
# |    ent_coef_loss   | -0.0704  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 351548   |
# ---------------------------------
# Eval num_timesteps=355000, episode_reward=-6.92 +/- 2.94
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.92    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 355000   |
# | train/             |          |
# |    actor_loss      | 4.03     |
# |    critic_loss     | 2.74     |
# |    ent_coef        | 0.00235  |
# |    ent_coef_loss   | 0.852    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 353998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 7100     |
# |    fps             | 117      |
# |    time_elapsed    | 383      |
# |    total_timesteps | 355050   |
# | train/             |          |
# |    actor_loss      | 3.84     |
# |    critic_loss     | 0.00585  |
# |    ent_coef        | 0.00235  |
# |    ent_coef_loss   | -0.409   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 354048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 7150     |
# |    fps             | 117      |
# |    time_elapsed    | 404      |
# |    total_timesteps | 357550   |
# | train/             |          |
# |    actor_loss      | 3.87     |
# |    critic_loss     | 0.00186  |
# |    ent_coef        | 0.00239  |
# |    ent_coef_loss   | -1.75    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 356548   |
# ---------------------------------
# Eval num_timesteps=360000, episode_reward=-8.70 +/- 4.34
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.7     |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 360000   |
# | train/             |          |
# |    actor_loss      | 4.07     |
# |    critic_loss     | 0.00151  |
# |    ent_coef        | 0.0023   |
# |    ent_coef_loss   | -0.0766  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 358998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 7200     |
# |    fps             | 117      |
# |    time_elapsed    | 426      |
# |    total_timesteps | 360050   |
# | train/             |          |
# |    actor_loss      | 3.74     |
# |    critic_loss     | 0.000959 |
# |    ent_coef        | 0.0023   |
# |    ent_coef_loss   | -1.56    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 359048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 7250     |
# |    fps             | 117      |
# |    time_elapsed    | 447      |
# |    total_timesteps | 362550   |
# | train/             |          |
# |    actor_loss      | 3.81     |
# |    critic_loss     | 0.00098  |
# |    ent_coef        | 0.00227  |
# |    ent_coef_loss   | 0.215    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 361548   |
# ---------------------------------
# Eval num_timesteps=365000, episode_reward=-8.34 +/- 3.63
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.34    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 365000   |
# | train/             |          |
# |    actor_loss      | 3.85     |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.00223  |
# |    ent_coef_loss   | -0.78    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 363998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 7300     |
# |    fps             | 117      |
# |    time_elapsed    | 469      |
# |    total_timesteps | 365050   |
# | train/             |          |
# |    actor_loss      | 3.9      |
# |    critic_loss     | 0.0903   |
# |    ent_coef        | 0.00223  |
# |    ent_coef_loss   | 1.49     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 364048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 7350     |
# |    fps             | 117      |
# |    time_elapsed    | 490      |
# |    total_timesteps | 367550   |
# | train/             |          |
# |    actor_loss      | 3.95     |
# |    critic_loss     | 0.000756 |
# |    ent_coef        | 0.00232  |
# |    ent_coef_loss   | 0.447    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 366548   |
# ---------------------------------
# Eval num_timesteps=370000, episode_reward=-5.64 +/- 2.26
# Episode length: 50.00 +/- 0.00
# Success rate: 80.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -5.64    |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    total_timesteps | 370000   |
# | train/             |          |
# |    actor_loss      | 4.07     |
# |    critic_loss     | 0.000924 |
# |    ent_coef        | 0.00231  |
# |    ent_coef_loss   | -0.0424  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 368998   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 7400     |
# |    fps             | 116      |
# |    time_elapsed    | 514      |
# |    total_timesteps | 370050   |
# | train/             |          |
# |    actor_loss      | 3.75     |
# |    critic_loss     | 0.00106  |
# |    ent_coef        | 0.00231  |
# |    ent_coef_loss   | 0.427    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 369048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 7450     |
# |    fps             | 116      |
# |    time_elapsed    | 535      |
# |    total_timesteps | 372550   |
# | train/             |          |
# |    actor_loss      | 3.95     |
# |    critic_loss     | 0.00125  |
# |    ent_coef        | 0.00228  |
# |    ent_coef_loss   | -0.501   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 371548   |
# ---------------------------------
# Eval num_timesteps=375000, episode_reward=-7.46 +/- 3.32
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.46    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 375000   |
# | train/             |          |
# |    actor_loss      | 4.04     |
# |    critic_loss     | 0.00139  |
# |    ent_coef        | 0.00224  |
# |    ent_coef_loss   | -0.204   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 373998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 7500     |
# |    fps             | 116      |
# |    time_elapsed    | 557      |
# |    total_timesteps | 375050   |
# | train/             |          |
# |    actor_loss      | 4.08     |
# |    critic_loss     | 0.00432  |
# |    ent_coef        | 0.00223  |
# |    ent_coef_loss   | -0.607   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 374048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 7550     |
# |    fps             | 116      |
# |    time_elapsed    | 578      |
# |    total_timesteps | 377550   |
# | train/             |          |
# |    actor_loss      | 3.74     |
# |    critic_loss     | 0.00127  |
# |    ent_coef        | 0.00231  |
# |    ent_coef_loss   | -0.891   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 376548   |
# ---------------------------------
# Eval num_timesteps=380000, episode_reward=-7.27 +/- 3.22
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.27    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 380000   |
# | train/             |          |
# |    actor_loss      | 3.77     |
# |    critic_loss     | 0.0008   |
# |    ent_coef        | 0.0023   |
# |    ent_coef_loss   | 0.314    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 378998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 7600     |
# |    fps             | 116      |
# |    time_elapsed    | 600      |
# |    total_timesteps | 380050   |
# | train/             |          |
# |    actor_loss      | 3.83     |
# |    critic_loss     | 0.00133  |
# |    ent_coef        | 0.00231  |
# |    ent_coef_loss   | 1.46     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 379048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 7650     |
# |    fps             | 116      |
# |    time_elapsed    | 621      |
# |    total_timesteps | 382550   |
# | train/             |          |
# |    actor_loss      | 3.88     |
# |    critic_loss     | 0.000695 |
# |    ent_coef        | 0.00224  |
# |    ent_coef_loss   | 0.0142   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 381548   |
# ---------------------------------
# Eval num_timesteps=385000, episode_reward=-7.34 +/- 2.40
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.34    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 385000   |
# | train/             |          |
# |    actor_loss      | 3.77     |
# |    critic_loss     | 0.00128  |
# |    ent_coef        | 0.0022   |
# |    ent_coef_loss   | 0.796    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 383998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 7700     |
# |    fps             | 116      |
# |    time_elapsed    | 644      |
# |    total_timesteps | 385050   |
# | train/             |          |
# |    actor_loss      | 3.53     |
# |    critic_loss     | 0.000714 |
# |    ent_coef        | 0.0022   |
# |    ent_coef_loss   | 0.151    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 384048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.47     |
# | time/              |          |
# |    episodes        | 7750     |
# |    fps             | 116      |
# |    time_elapsed    | 665      |
# |    total_timesteps | 387550   |
# | train/             |          |
# |    actor_loss      | 3.81     |
# |    critic_loss     | 0.000675 |
# |    ent_coef        | 0.00219  |
# |    ent_coef_loss   | 2.08     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 386548   |
# ---------------------------------
# Eval num_timesteps=390000, episode_reward=-9.13 +/- 3.31
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.13    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 390000   |
# | train/             |          |
# |    actor_loss      | 3.96     |
# |    critic_loss     | 0.0185   |
# |    ent_coef        | 0.00205  |
# |    ent_coef_loss   | 0.741    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 388998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.46     |
# | time/              |          |
# |    episodes        | 7800     |
# |    fps             | 116      |
# |    time_elapsed    | 687      |
# |    total_timesteps | 390050   |
# | train/             |          |
# |    actor_loss      | 3.9      |
# |    critic_loss     | 0.00387  |
# |    ent_coef        | 0.00205  |
# |    ent_coef_loss   | 1.57     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 389048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 7850     |
# |    fps             | 116      |
# |    time_elapsed    | 708      |
# |    total_timesteps | 392550   |
# | train/             |          |
# |    actor_loss      | 3.69     |
# |    critic_loss     | 0.000749 |
# |    ent_coef        | 0.00202  |
# |    ent_coef_loss   | 0.276    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 391548   |
# ---------------------------------
# Eval num_timesteps=395000, episode_reward=-9.39 +/- 4.09
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.39    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 395000   |
# | train/             |          |
# |    actor_loss      | 3.69     |
# |    critic_loss     | 0.0268   |
# |    ent_coef        | 0.002    |
# |    ent_coef_loss   | -0.512   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 393998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 7900     |
# |    fps             | 116      |
# |    time_elapsed    | 730      |
# |    total_timesteps | 395050   |
# | train/             |          |
# |    actor_loss      | 3.83     |
# |    critic_loss     | 0.000822 |
# |    ent_coef        | 0.002    |
# |    ent_coef_loss   | -0.148   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 394048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 7950     |
# |    fps             | 116      |
# |    time_elapsed    | 752      |
# |    total_timesteps | 397550   |
# | train/             |          |
# |    actor_loss      | 3.92     |
# |    critic_loss     | 0.000733 |
# |    ent_coef        | 0.00201  |
# |    ent_coef_loss   | 0.551    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 396548   |
# ---------------------------------
# Eval num_timesteps=400000, episode_reward=-8.84 +/- 4.32
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.84    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 400000   |
# | train/             |          |
# |    actor_loss      | 3.72     |
# |    critic_loss     | 0.0012   |
# |    ent_coef        | 0.00196  |
# |    ent_coef_loss   | 0.107    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 398998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 8000     |
# |    fps             | 116      |
# |    time_elapsed    | 774      |
# |    total_timesteps | 400050   |
# | train/             |          |
# |    actor_loss      | 3.6      |
# |    critic_loss     | 0.00136  |
# |    ent_coef        | 0.00195  |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 399048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 8050     |
# |    fps             | 116      |
# |    time_elapsed    | 795      |
# |    total_timesteps | 402550   |
# | train/             |          |
# |    actor_loss      | 3.76     |
# |    critic_loss     | 0.000644 |
# |    ent_coef        | 0.00188  |
# |    ent_coef_loss   | -0.975   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 401548   |
# ---------------------------------
# Eval num_timesteps=405000, episode_reward=-7.81 +/- 4.20
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.81    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 405000   |
# | train/             |          |
# |    actor_loss      | 3.74     |
# |    critic_loss     | 0.000554 |
# |    ent_coef        | 0.00188  |
# |    ent_coef_loss   | -0.271   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 403998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 8100     |
# |    fps             | 116      |
# |    time_elapsed    | 818      |
# |    total_timesteps | 405050   |
# | train/             |          |
# |    actor_loss      | 3.53     |
# |    critic_loss     | 0.00217  |
# |    ent_coef        | 0.00188  |
# |    ent_coef_loss   | -0.86    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 404048   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 8150     |
# |    fps             | 116      |
# |    time_elapsed    | 839      |
# |    total_timesteps | 407550   |
# | train/             |          |
# |    actor_loss      | 3.81     |
# |    critic_loss     | 0.00168  |
# |    ent_coef        | 0.00183  |
# |    ent_coef_loss   | -0.144   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 406548   |
# ---------------------------------
# Eval num_timesteps=410000, episode_reward=-6.27 +/- 2.57
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.27    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 410000   |
# | train/             |          |
# |    actor_loss      | 3.8      |
# |    critic_loss     | 0.000682 |
# |    ent_coef        | 0.00179  |
# |    ent_coef_loss   | 0.0826   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 408998   |
# ---------------------------------
# ✅ Stage 3 fine-tuning complete. Model saved to: ./her_sac_FetchReach-v3_results/finetuned_model_stage3.zip
#
# 📈 Plotting updated reward + success rate curves...
# ⚠️ Falling back to reward threshold for success plot.
# ✅ Plots saved:
#    🔹 finetune_stage3_reward_plot.png
#    🔹 finetune_stage3_success_plot.png

# %% [markdown]
# RESTART FROM SCRATCH TRAINING:

# %%
import os
import gymnasium as gym
import gymnasium_robotics
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.callbacks import EvalCallback, CallbackList, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.logger import configure

# === Custom Callbacks ===
class StopTrainingOnSuccessRate(BaseCallback):
    def __init__(self, success_threshold=0.90, eval_freq=2000, verbose=1):
        super().__init__(verbose)
        self.success_threshold = success_threshold
        self.eval_freq = eval_freq

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0:
            successes = []
            for _ in range(10):
                obs = self.training_env.reset()
                done = False
                while not done:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, reward, done, infos = self.training_env.step(action)
                    done = done[0]
                    infos = infos[0]
                successes.append(infos['is_success'])
            success_rate = np.mean(successes)
            self.logger.record("custom/success_rate_eval", success_rate)
            if self.verbose:
                print(f"✅ [Monitor] Success rate: {success_rate * 100:.2f}%")
            if success_rate >= self.success_threshold:
                print(f"🏆 [Early Stop] Target success rate {success_rate * 100:.2f}% reached.")
                return False
        return True

class CheckpointOnSuccessRate(BaseCallback):
    def __init__(self, save_path, success_threshold=0.80, eval_freq=2000, verbose=1):
        super().__init__(verbose)
        self.save_path = save_path
        self.success_threshold = success_threshold
        self.eval_freq = eval_freq
        self.stabilized = False

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0:
            successes = []
            for _ in range(10):
                obs = self.training_env.reset()
                done = False
                while not done:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, reward, done, infos = self.training_env.step(action)
                    done = done[0]
                    infos = infos[0]
                successes.append(infos['is_success'])
            success_rate = np.mean(successes)
            self.logger.record("custom/success_rate_checkpoint", success_rate)
            if success_rate >= self.success_threshold and not self.stabilized:
                print(f"📦 [Checkpoint] Saving model at {success_rate * 100:.2f}% success rate.")
                self.model.save(os.path.join(self.save_path, "checkpoint_model"))
                self.training_env.save(os.path.join(self.save_path, "checkpoint_vecnormalize.pkl"))
                # Reduce entropy and learning rate to stabilize
                self.model.ent_coef = 0.001
                self.model.lr_schedule = lambda _: 5e-5
                self.stabilized = True
        return True

# === Config ===
env_id = "FetchReach-v3"
save_dir = f"./tensorboard_sac_her_{env_id}/"
best_model_path = os.path.join(save_dir, "best_model")
final_model_path = os.path.join(save_dir, "final_model")

os.makedirs(save_dir, exist_ok=True)

# === Env Setup ===
env = gym.make(env_id, reward_type='dense')
env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=False)

# === SAC + HER ===
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=16,
        goal_selection_strategy='future',
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_starts=500,
    batch_size=256,
    learning_rate=1e-4,
    gamma=0.98,
    tau=0.005,
    tensorboard_log=os.path.join(save_dir, "tb_log")
)

# === Set up TensorBoard logger ===
new_logger = configure(os.path.join(save_dir, "tb_log"), ["stdout", "tensorboard"])
model.set_logger(new_logger)

# === Callbacks ===
eval_callback = EvalCallback(
    env,
    best_model_save_path=best_model_path,
    log_path=save_dir,
    eval_freq=2000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
    verbose=1
)

checkpoint_callback = CheckpointOnSuccessRate(
    save_path=save_dir,
    success_threshold=0.80,
    eval_freq=2000,
    verbose=1
)

stop_callback = StopTrainingOnSuccessRate(
    success_threshold=0.90,
    eval_freq=2000,
    verbose=1
)

callback = CallbackList([eval_callback, checkpoint_callback, stop_callback])

# === Train ===
print(f"🚀 Training SAC + HER on {env_id} with TensorBoard...")
model.learn(total_timesteps=1_000_000, log_interval=50, callback=callback)

# === Save ===
model.save(final_model_path)
env.save(os.path.join(save_dir, "vecnormalize.pkl"))
print("✅ Final model and VecNormalize saved.")

# === TensorBoard usage ===
print("\n📊 To view TensorBoard logs:")
print(f"tensorboard --logdir {os.path.join(save_dir, 'tb_log')}")
# Out:
# Using cuda device
# Logging to ./tensorboard_sac_her_FetchReach-v3/tb_log
# 🚀 Training SAC + HER on FetchReach-v3 with TensorBoard...
# Eval num_timesteps=2000, episode_reward=-22.50 +/- 5.09
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -22.5    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.133    |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -0.995   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1499     |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 0.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.0      |
# | rollout/                   |          |
# |    success_rate            | 0        |
# | time/                      |          |
# |    episodes                | 50       |
# |    fps                     | 131      |
# |    time_elapsed            | 18       |
# |    total_timesteps         | 2500     |
# | train/                     |          |
# |    actor_loss              | -21.9    |
# |    critic_loss             | 0.114    |
# |    ent_coef                | 0.819    |
# |    ent_coef_loss           | -1.32    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 1999     |
# -----------------------------------------
# Eval num_timesteps=4000, episode_reward=-19.52 +/- 2.13
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -19.5    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 0.0995   |
# |    ent_coef        | 0.706    |
# |    ent_coef_loss   | -2.27    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3499     |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 0.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.0      |
# | rollout/                   |          |
# |    success_rate            | 0        |
# | time/                      |          |
# |    episodes                | 100      |
# |    fps                     | 120      |
# |    time_elapsed            | 41       |
# |    total_timesteps         | 5000     |
# | train/                     |          |
# |    actor_loss              | -35.7    |
# |    critic_loss             | 0.0927   |
# |    ent_coef                | 0.639    |
# |    ent_coef_loss           | -2.89    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 4499     |
# -----------------------------------------
# Eval num_timesteps=6000, episode_reward=-18.47 +/- 3.51
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -18.5    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -39.1    |
# |    critic_loss     | 0.0874   |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | -3.49    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5499     |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 0.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.0      |
# | rollout/                   |          |
# |    success_rate            | 0        |
# | time/                      |          |
# |    episodes                | 150      |
# |    fps                     | 117      |
# |    time_elapsed            | 63       |
# |    total_timesteps         | 7500     |
# | train/                     |          |
# |    actor_loss              | -41      |
# |    critic_loss             | 0.0897   |
# |    ent_coef                | 0.499    |
# |    ent_coef_loss           | -4.35    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 6999     |
# -----------------------------------------
# Eval num_timesteps=8000, episode_reward=-18.79 +/- 2.95
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -18.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -42.4    |
# |    critic_loss     | 0.0966   |
# |    ent_coef        | 0.475    |
# |    ent_coef_loss   | -4.75    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7499     |
# ---------------------------------
# ✅ [Monitor] Success rate: 0.00%
# Eval num_timesteps=10000, episode_reward=-16.34 +/- 1.02
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.0      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -16.3    |
# |    success_rate            | 0.0      |
# | time/                      |          |
# |    total_timesteps         | 10000    |
# | train/                     |          |
# |    actor_loss              | -43.1    |
# |    critic_loss             | 0.0779   |
# |    ent_coef                | 0.39     |
# |    ent_coef_loss           | -5.72    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 9499     |
# -----------------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 0.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.0      |
# | rollout/                   |          |
# |    success_rate            | 0        |
# | time/                      |          |
# |    episodes                | 200      |
# |    fps                     | 112      |
# |    time_elapsed            | 88       |
# |    total_timesteps         | 10000    |
# -----------------------------------------
# Eval num_timesteps=12000, episode_reward=-14.95 +/- 1.72
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -15      |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -42      |
# |    critic_loss     | 0.0629   |
# |    ent_coef        | 0.32     |
# |    ent_coef_loss   | -6.84    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 0.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.0      |
# | rollout/                   |          |
# |    success_rate            | 0        |
# | time/                      |          |
# |    episodes                | 250      |
# |    fps                     | 112      |
# |    time_elapsed            | 111      |
# |    total_timesteps         | 12500    |
# | train/                     |          |
# |    actor_loss              | -41.3    |
# |    critic_loss             | 0.0549   |
# |    ent_coef                | 0.304    |
# |    ent_coef_loss           | -7.13    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 11999    |
# -----------------------------------------
# Eval num_timesteps=14000, episode_reward=-13.26 +/- 1.99
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -13.3    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -40.6    |
# |    critic_loss     | 0.0436   |
# |    ent_coef        | 0.262    |
# |    ent_coef_loss   | -7.92    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 0.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.0      |
# | rollout/                   |          |
# |    success_rate            | 0        |
# | time/                      |          |
# |    episodes                | 300      |
# |    fps                     | 112      |
# |    time_elapsed            | 133      |
# |    total_timesteps         | 15000    |
# | train/                     |          |
# |    actor_loss              | -39.3    |
# |    critic_loss             | 0.0453   |
# |    ent_coef                | 0.237    |
# |    ent_coef_loss           | -8.52    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 14499    |
# -----------------------------------------
# Eval num_timesteps=16000, episode_reward=-11.20 +/- 3.36
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -11.2    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -37.4    |
# |    critic_loss     | 0.0399   |
# |    ent_coef        | 0.215    |
# |    ent_coef_loss   | -9.02    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 0.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.0      |
# | rollout/                   |          |
# |    success_rate            | 0        |
# | time/                      |          |
# |    episodes                | 350      |
# |    fps                     | 111      |
# |    time_elapsed            | 156      |
# |    total_timesteps         | 17500    |
# | train/                     |          |
# |    actor_loss              | -35.5    |
# |    critic_loss             | 0.0319   |
# |    ent_coef                | 0.185    |
# |    ent_coef_loss           | -10.1    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 16999    |
# -----------------------------------------
# Eval num_timesteps=18000, episode_reward=-10.96 +/- 3.61
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -11      |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -34.7    |
# |    critic_loss     | 0.0264   |
# |    ent_coef        | 0.176    |
# |    ent_coef_loss   | -10.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 10.00%
# Eval num_timesteps=20000, episode_reward=-11.46 +/- 3.13
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.0      |
# |    success_rate_eval       | 0.1      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -11.5    |
# |    success_rate            | 0.2      |
# | time/                      |          |
# |    total_timesteps         | 20000    |
# | train/                     |          |
# |    actor_loss              | -31.3    |
# |    critic_loss             | 0.0198   |
# |    ent_coef                | 0.144    |
# |    ent_coef_loss           | -11.7    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 19499    |
# -----------------------------------------
# ✅ [Monitor] Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.1      |
# |    success_rate_eval       | 0.3      |
# | rollout/                   |          |
# |    success_rate            | 0.01     |
# | time/                      |          |
# |    episodes                | 400      |
# |    fps                     | 109      |
# |    time_elapsed            | 181      |
# |    total_timesteps         | 20000    |
# -----------------------------------------
# Eval num_timesteps=22000, episode_reward=-8.32 +/- 2.88
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.32    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 0.0125   |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -13      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 10.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.5      |
# |    success_rate_eval       | 0.1      |
# | rollout/                   |          |
# |    success_rate            | 0.02     |
# | time/                      |          |
# |    episodes                | 450      |
# |    fps                     | 110      |
# |    time_elapsed            | 204      |
# |    total_timesteps         | 22500    |
# | train/                     |          |
# |    actor_loss              | -26.5    |
# |    critic_loss             | 0.0121   |
# |    ent_coef                | 0.112    |
# |    ent_coef_loss           | -13.2    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 21999    |
# -----------------------------------------
# Eval num_timesteps=24000, episode_reward=-10.49 +/- 3.30
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.5    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 0.0103   |
# |    ent_coef        | 0.0965   |
# |    ent_coef_loss   | -13.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 10.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.1      |
# |    success_rate_eval       | 0.1      |
# | rollout/                   |          |
# |    success_rate            | 0.03     |
# | time/                      |          |
# |    episodes                | 500      |
# |    fps                     | 110      |
# |    time_elapsed            | 226      |
# |    total_timesteps         | 25000    |
# | train/                     |          |
# |    actor_loss              | -21.8    |
# |    critic_loss             | 0.00788  |
# |    ent_coef                | 0.0874   |
# |    ent_coef_loss           | -14.5    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 24499    |
# -----------------------------------------
# Eval num_timesteps=26000, episode_reward=-8.15 +/- 3.57
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.15    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 0.00902  |
# |    ent_coef        | 0.0791   |
# |    ent_coef_loss   | -14.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval       | 0.2      |
# | rollout/                   |          |
# |    success_rate            | 0.09     |
# | time/                      |          |
# |    episodes                | 550      |
# |    fps                     | 110      |
# |    time_elapsed            | 248      |
# |    total_timesteps         | 27500    |
# | train/                     |          |
# |    actor_loss              | -17.9    |
# |    critic_loss             | 0.00562  |
# |    ent_coef                | 0.0682   |
# |    ent_coef_loss           | -15.4    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 26999    |
# -----------------------------------------
# Eval num_timesteps=28000, episode_reward=-8.20 +/- 1.97
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.2     |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 0.00698  |
# |    ent_coef        | 0.0649   |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 20.00%
# Eval num_timesteps=30000, episode_reward=-8.24 +/- 3.29
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.2      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -8.24    |
# |    success_rate            | 0.2      |
# | time/                      |          |
# |    total_timesteps         | 30000    |
# | train/                     |          |
# |    actor_loss              | -14.5    |
# |    critic_loss             | 0.00438  |
# |    ent_coef                | 0.0533   |
# |    ent_coef_loss           | -16.4    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 29499    |
# -----------------------------------------
# ✅ [Monitor] Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval       | 0.2      |
# | rollout/                   |          |
# |    success_rate            | 0.13     |
# | time/                      |          |
# |    episodes                | 600      |
# |    fps                     | 109      |
# |    time_elapsed            | 273      |
# |    total_timesteps         | 30000    |
# -----------------------------------------
# Eval num_timesteps=32000, episode_reward=-7.19 +/- 2.64
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.19    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 0.00351  |
# |    ent_coef        | 0.0437   |
# |    ent_coef_loss   | -16.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 10.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.5      |
# |    success_rate_eval       | 0.1      |
# | rollout/                   |          |
# |    success_rate            | 0.13     |
# | time/                      |          |
# |    episodes                | 650      |
# |    fps                     | 109      |
# |    time_elapsed            | 296      |
# |    total_timesteps         | 32500    |
# | train/                     |          |
# |    actor_loss              | -11.5    |
# |    critic_loss             | 0.00347  |
# |    ent_coef                | 0.0416   |
# |    ent_coef_loss           | -16.7    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 31999    |
# -----------------------------------------
# Eval num_timesteps=34000, episode_reward=-8.16 +/- 3.34
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.16    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 34000    |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 0.00286  |
# |    ent_coef        | 0.0359   |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.2      |
# | rollout/                   |          |
# |    success_rate            | 0.21     |
# | time/                      |          |
# |    episodes                | 700      |
# |    fps                     | 109      |
# |    time_elapsed            | 318      |
# |    total_timesteps         | 35000    |
# | train/                     |          |
# |    actor_loss              | -8.99    |
# |    critic_loss             | 0.00249  |
# |    ent_coef                | 0.0325   |
# |    ent_coef_loss           | -17.1    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 34499    |
# -----------------------------------------
# Eval num_timesteps=36000, episode_reward=-7.95 +/- 4.08
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.95    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -8.19    |
# |    critic_loss     | 0.00239  |
# |    ent_coef        | 0.0295   |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 35499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.1      |
# |    success_rate_eval       | 0.3      |
# | rollout/                   |          |
# |    success_rate            | 0.27     |
# | time/                      |          |
# |    episodes                | 750      |
# |    fps                     | 109      |
# |    time_elapsed            | 340      |
# |    total_timesteps         | 37500    |
# | train/                     |          |
# |    actor_loss              | -7.06    |
# |    critic_loss             | 0.00172  |
# |    ent_coef                | 0.0255   |
# |    ent_coef_loss           | -18.5    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 36999    |
# -----------------------------------------
# Eval num_timesteps=38000, episode_reward=-7.19 +/- 2.46
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.19    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 38000    |
# | train/             |          |
# |    actor_loss      | -6.56    |
# |    critic_loss     | 0.00357  |
# |    ent_coef        | 0.0243   |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 37499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 30.00%
# Eval num_timesteps=40000, episode_reward=-9.60 +/- 3.27
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.6      |
# |    success_rate_eval       | 0.3      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -9.6     |
# |    success_rate            | 0.2      |
# | time/                      |          |
# |    total_timesteps         | 40000    |
# | train/                     |          |
# |    actor_loss              | -5.37    |
# |    critic_loss             | 0.00171  |
# |    ent_coef                | 0.0199   |
# |    ent_coef_loss           | -18.3    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 39499    |
# -----------------------------------------
# ✅ [Monitor] Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.3      |
# | rollout/                   |          |
# |    success_rate            | 0.26     |
# | time/                      |          |
# |    episodes                | 800      |
# |    fps                     | 109      |
# |    time_elapsed            | 366      |
# |    total_timesteps         | 40000    |
# -----------------------------------------
# Eval num_timesteps=42000, episode_reward=-7.24 +/- 3.01
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.24    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | -3.93    |
# |    critic_loss     | 0.00163  |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -17.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 41499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 60.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.6      |
# | rollout/                   |          |
# |    success_rate            | 0.27     |
# | time/                      |          |
# |    episodes                | 850      |
# |    fps                     | 109      |
# |    time_elapsed            | 389      |
# |    total_timesteps         | 42500    |
# | train/                     |          |
# |    actor_loss              | -3.99    |
# |    critic_loss             | 0.00118  |
# |    ent_coef                | 0.0156   |
# |    ent_coef_loss           | -17.9    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 41999    |
# -----------------------------------------
# Eval num_timesteps=44000, episode_reward=-7.35 +/- 3.86
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.35    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -3.02    |
# |    critic_loss     | 0.00139  |
# |    ent_coef        | 0.0135   |
# |    ent_coef_loss   | -17.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 40.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.4      |
# | rollout/                   |          |
# |    success_rate            | 0.29     |
# | time/                      |          |
# |    episodes                | 900      |
# |    fps                     | 109      |
# |    time_elapsed            | 412      |
# |    total_timesteps         | 45000    |
# | train/                     |          |
# |    actor_loss              | -2.74    |
# |    critic_loss             | 0.00106  |
# |    ent_coef                | 0.0123   |
# |    ent_coef_loss           | -17.1    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 44499    |
# -----------------------------------------
# Eval num_timesteps=46000, episode_reward=-7.25 +/- 3.21
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.25    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 46000    |
# | train/             |          |
# |    actor_loss      | -2.26    |
# |    critic_loss     | 0.000886 |
# |    ent_coef        | 0.0111   |
# |    ent_coef_loss   | -16.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 45499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 50.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.5      |
# | rollout/                   |          |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    episodes                | 950      |
# |    fps                     | 109      |
# |    time_elapsed            | 434      |
# |    total_timesteps         | 47500    |
# | train/                     |          |
# |    actor_loss              | -1.89    |
# |    critic_loss             | 0.0011   |
# |    ent_coef                | 0.00964  |
# |    ent_coef_loss           | -17.7    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 46999    |
# -----------------------------------------
# Eval num_timesteps=48000, episode_reward=-7.90 +/- 2.99
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.9     |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -1.71    |
# |    critic_loss     | 0.00091  |
# |    ent_coef        | 0.00918  |
# |    ent_coef_loss   | -17      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 47499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 30.00%
# Eval num_timesteps=50000, episode_reward=-8.07 +/- 3.28
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.3      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -8.07    |
# |    success_rate            | 0.4      |
# | time/                      |          |
# |    total_timesteps         | 50000    |
# | train/                     |          |
# |    actor_loss              | -1.21    |
# |    critic_loss             | 0.000853 |
# |    ent_coef                | 0.00757  |
# |    ent_coef_loss           | -17.5    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 49499    |
# -----------------------------------------
# ✅ [Monitor] Success rate: 40.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.4      |
# | rollout/                   |          |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    episodes                | 1000     |
# |    fps                     | 108      |
# |    time_elapsed            | 461      |
# |    total_timesteps         | 50000    |
# -----------------------------------------
# Eval num_timesteps=52000, episode_reward=-7.68 +/- 2.70
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.68    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -0.738   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.00625  |
# |    ent_coef_loss   | -15      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 50.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.5      |
# | rollout/                   |          |
# |    success_rate            | 0.34     |
# | time/                      |          |
# |    episodes                | 1050     |
# |    fps                     | 108      |
# |    time_elapsed            | 484      |
# |    total_timesteps         | 52500    |
# | train/                     |          |
# |    actor_loss              | -0.49    |
# |    critic_loss             | 0.00072  |
# |    ent_coef                | 0.00596  |
# |    ent_coef_loss           | -15.1    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 51999    |
# -----------------------------------------
# Eval num_timesteps=54000, episode_reward=-8.55 +/- 3.46
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.55    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 54000    |
# | train/             |          |
# |    actor_loss      | -0.249   |
# |    critic_loss     | 0.000613 |
# |    ent_coef        | 0.00517  |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 50.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval       | 0.5      |
# | rollout/                   |          |
# |    success_rate            | 0.34     |
# | time/                      |          |
# |    episodes                | 1100     |
# |    fps                     | 108      |
# |    time_elapsed            | 506      |
# |    total_timesteps         | 55000    |
# | train/                     |          |
# |    actor_loss              | -0.0145  |
# |    critic_loss             | 0.000635 |
# |    ent_coef                | 0.00471  |
# |    ent_coef_loss           | -14.4    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 54499    |
# -----------------------------------------
# Eval num_timesteps=56000, episode_reward=-7.29 +/- 4.12
# Episode length: 50.00 +/- 0.00
# Success rate: 60.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.29    |
# |    success_rate    | 0.6      |
# | time/              |          |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | 0.164    |
# |    critic_loss     | 0.000821 |
# |    ent_coef        | 0.00428  |
# |    ent_coef_loss   | -13.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 55499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 60.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.1      |
# |    success_rate_eval       | 0.6      |
# | rollout/                   |          |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    episodes                | 1150     |
# |    fps                     | 108      |
# |    time_elapsed            | 529      |
# |    total_timesteps         | 57500    |
# | train/                     |          |
# |    actor_loss              | 0.291    |
# |    critic_loss             | 0.000434 |
# |    ent_coef                | 0.00372  |
# |    ent_coef_loss           | -13.6    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 56999    |
# -----------------------------------------
# Eval num_timesteps=58000, episode_reward=-7.07 +/- 3.46
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.07    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 58000    |
# | train/             |          |
# |    actor_loss      | 0.217    |
# |    critic_loss     | 0.000468 |
# |    ent_coef        | 0.00355  |
# |    ent_coef_loss   | -11.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 20.00%
# Eval num_timesteps=60000, episode_reward=-7.55 +/- 2.65
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval       | 0.2      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -7.55    |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    total_timesteps         | 60000    |
# | train/                     |          |
# |    actor_loss              | 0.603    |
# |    critic_loss             | 0.000436 |
# |    ent_coef                | 0.00295  |
# |    ent_coef_loss           | -10.3    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 59499    |
# -----------------------------------------
# ✅ [Monitor] Success rate: 60.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.6      |
# | rollout/                   |          |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    episodes                | 1200     |
# |    fps                     | 108      |
# |    time_elapsed            | 554      |
# |    total_timesteps         | 60000    |
# -----------------------------------------
# Eval num_timesteps=62000, episode_reward=-8.95 +/- 3.23
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.95    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 62000    |
# | train/             |          |
# |    actor_loss      | 0.738    |
# |    critic_loss     | 0.000489 |
# |    ent_coef        | 0.00247  |
# |    ent_coef_loss   | -8.53    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.2      |
# | rollout/                   |          |
# |    success_rate            | 0.31     |
# | time/                      |          |
# |    episodes                | 1250     |
# |    fps                     | 108      |
# |    time_elapsed            | 577      |
# |    total_timesteps         | 62500    |
# | train/                     |          |
# |    actor_loss              | 0.708    |
# |    critic_loss             | 0.00038  |
# |    ent_coef                | 0.00236  |
# |    ent_coef_loss           | -9.65    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 61999    |
# -----------------------------------------
# Eval num_timesteps=64000, episode_reward=-7.24 +/- 3.53
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.24    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | 0.795    |
# |    critic_loss     | 0.000407 |
# |    ent_coef        | 0.00207  |
# |    ent_coef_loss   | -7.11    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 63499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 10.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval       | 0.1      |
# | rollout/                   |          |
# |    success_rate            | 0.38     |
# | time/                      |          |
# |    episodes                | 1300     |
# |    fps                     | 108      |
# |    time_elapsed            | 599      |
# |    total_timesteps         | 65000    |
# | train/                     |          |
# |    actor_loss              | 0.785    |
# |    critic_loss             | 0.000367 |
# |    ent_coef                | 0.0019   |
# |    ent_coef_loss           | -5.98    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 64499    |
# -----------------------------------------
# Eval num_timesteps=66000, episode_reward=-7.06 +/- 2.97
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.06    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 66000    |
# | train/             |          |
# |    actor_loss      | 0.821    |
# |    critic_loss     | 0.00027  |
# |    ent_coef        | 0.00174  |
# |    ent_coef_loss   | -5.12    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 65499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 10.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval       | 0.1      |
# | rollout/                   |          |
# |    success_rate            | 0.44     |
# | time/                      |          |
# |    episodes                | 1350     |
# |    fps                     | 108      |
# |    time_elapsed            | 624      |
# |    total_timesteps         | 67500    |
# | train/                     |          |
# |    actor_loss              | 0.849    |
# |    critic_loss             | 0.000329 |
# |    ent_coef                | 0.00154  |
# |    ent_coef_loss           | -4.68    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 66999    |
# -----------------------------------------
# Eval num_timesteps=68000, episode_reward=-6.89 +/- 3.41
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.89    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | 0.899    |
# |    critic_loss     | 0.000266 |
# |    ent_coef        | 0.00149  |
# |    ent_coef_loss   | -5.3     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 67499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 20.00%
# Eval num_timesteps=70000, episode_reward=-9.15 +/- 3.80
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.2      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -9.15    |
# |    success_rate            | 0.2      |
# | time/                      |          |
# |    total_timesteps         | 70000    |
# | train/                     |          |
# |    actor_loss              | 1.07     |
# |    critic_loss             | 0.000323 |
# |    ent_coef                | 0.0013   |
# |    ent_coef_loss           | -1.16    |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 69499    |
# -----------------------------------------
# ✅ [Monitor] Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.6      |
# |    success_rate_eval       | 0.3      |
# | rollout/                   |          |
# |    success_rate            | 0.42     |
# | time/                      |          |
# |    episodes                | 1400     |
# |    fps                     | 107      |
# |    time_elapsed            | 650      |
# |    total_timesteps         | 70000    |
# -----------------------------------------
# Eval num_timesteps=72000, episode_reward=-6.36 +/- 4.02
# Episode length: 50.00 +/- 0.00
# Success rate: 70.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.36    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | 1.01     |
# |    critic_loss     | 0.000299 |
# |    ent_coef        | 0.00118  |
# |    ent_coef_loss   | -1.81    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 71499    |
# ---------------------------------
# New best mean reward!
# ✅ [Monitor] Success rate: 50.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.6      |
# |    success_rate_eval       | 0.5      |
# | rollout/                   |          |
# |    success_rate            | 0.39     |
# | time/                      |          |
# |    episodes                | 1450     |
# |    fps                     | 107      |
# |    time_elapsed            | 673      |
# |    total_timesteps         | 72500    |
# | train/                     |          |
# |    actor_loss              | 1.02     |
# |    critic_loss             | 0.000268 |
# |    ent_coef                | 0.00116  |
# |    ent_coef_loss           | -0.457   |
# |    learning_rate           | 0.0001   |
# |    n_updates               | 71999    |
# -----------------------------------------
# Eval num_timesteps=74000, episode_reward=-8.55 +/- 3.27
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.55    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 74000    |
# | train/             |          |
# |    actor_loss      | 0.947    |
# |    critic_loss     | 0.00019  |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | 0.0416   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 73499    |
# ---------------------------------
# ✅ [Monitor] Success rate: 50.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval       | 0.5      |
# | rollout/                   |          |
# |    success_rate            | 0.34     |
# | time/                      |          |
# |    episodes                | 1500     |
# |    fps                     | 107      |
# |    time_elapsed            | 695      |
# |    total_timesteps         | 75000    |
# | train/                     |          |
# |    actor_loss              | 0.974    |
# |    critic_loss             | 0.00038  |
# |    ent_coef                | 0.00112  |
# ...
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 1.77     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 975499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 40.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval       | 0.4      |
# | rollout/                   |          |
# |    success_rate            | 0.4      |
# | time/                      |          |
# |    episodes                | 19550    |
# |    fps                     | 105      |
# |    time_elapsed            | 9309     |
# |    total_timesteps         | 977500   |
# | train/                     |          |
# |    actor_loss              | 0.946    |
# |    critic_loss             | 9.54e-06 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | 0.801    |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 976999   |
# -----------------------------------------
# Eval num_timesteps=978000, episode_reward=-9.21 +/- 3.47
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.21    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 978000   |
# | train/             |          |
# |    actor_loss      | 1.14     |
# |    critic_loss     | 6.52e-06 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 977499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 20.00%
# Eval num_timesteps=980000, episode_reward=-9.68 +/- 3.40
# Episode length: 50.00 +/- 0.00
# Success rate: 10.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.2      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -9.68    |
# |    success_rate            | 0.1      |
# | time/                      |          |
# |    total_timesteps         | 980000   |
# | train/                     |          |
# |    actor_loss              | 1.05     |
# |    critic_loss             | 8.35e-06 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | -0.024   |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 979499   |
# -----------------------------------------
# ✅ [Monitor] Success rate: 60.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.1      |
# |    success_rate_eval       | 0.6      |
# | rollout/                   |          |
# |    success_rate            | 0.34     |
# | time/                      |          |
# |    episodes                | 19600    |
# |    fps                     | 104      |
# |    time_elapsed            | 9335     |
# |    total_timesteps         | 980000   |
# -----------------------------------------
# Eval num_timesteps=982000, episode_reward=-7.56 +/- 3.44
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.56    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 982000   |
# | train/             |          |
# |    actor_loss      | 0.885    |
# |    critic_loss     | 6.85e-06 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 1.11     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 981499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.2      |
# | rollout/                   |          |
# |    success_rate            | 0.27     |
# | time/                      |          |
# |    episodes                | 19650    |
# |    fps                     | 104      |
# |    time_elapsed            | 9359     |
# |    total_timesteps         | 982500   |
# | train/                     |          |
# |    actor_loss              | 0.944    |
# |    critic_loss             | 6.44e-06 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | -0.109   |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 981999   |
# -----------------------------------------
# Eval num_timesteps=984000, episode_reward=-8.67 +/- 4.52
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.67    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 984000   |
# | train/             |          |
# |    actor_loss      | 1        |
# |    critic_loss     | 2.43e-05 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 0.455    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 983499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.5      |
# |    success_rate_eval       | 0.3      |
# | rollout/                   |          |
# |    success_rate            | 0.35     |
# | time/                      |          |
# |    episodes                | 19700    |
# |    fps                     | 104      |
# |    time_elapsed            | 9383     |
# |    total_timesteps         | 985000   |
# | train/                     |          |
# |    actor_loss              | 0.935    |
# |    critic_loss             | 1.17e-05 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | 1.14     |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 984499   |
# -----------------------------------------
# Eval num_timesteps=986000, episode_reward=-8.21 +/- 3.22
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.21    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 986000   |
# | train/             |          |
# |    actor_loss      | 0.995    |
# |    critic_loss     | 1.76e-05 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 0.158    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 985499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 50.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval       | 0.5      |
# | rollout/                   |          |
# |    success_rate            | 0.33     |
# | time/                      |          |
# |    episodes                | 19750    |
# |    fps                     | 104      |
# |    time_elapsed            | 9407     |
# |    total_timesteps         | 987500   |
# | train/                     |          |
# |    actor_loss              | 0.984    |
# |    critic_loss             | 7.92e-06 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | 1.12     |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 986999   |
# -----------------------------------------
# Eval num_timesteps=988000, episode_reward=-8.44 +/- 3.71
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.44    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 988000   |
# | train/             |          |
# |    actor_loss      | 0.996    |
# |    critic_loss     | 1.17e-05 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | 0.103    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 987499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 30.00%
# Eval num_timesteps=990000, episode_reward=-8.22 +/- 3.11
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval       | 0.3      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -8.22    |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    total_timesteps         | 990000   |
# | train/                     |          |
# |    actor_loss              | 0.972    |
# |    critic_loss             | 8.85e-06 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | -0.126   |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 989499   |
# -----------------------------------------
# ✅ [Monitor] Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.3      |
# | rollout/                   |          |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    episodes                | 19800    |
# |    fps                     | 104      |
# |    time_elapsed            | 9433     |
# |    total_timesteps         | 990000   |
# -----------------------------------------
# Eval num_timesteps=992000, episode_reward=-8.36 +/- 3.38
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.36    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 992000   |
# | train/             |          |
# |    actor_loss      | 0.874    |
# |    critic_loss     | 6.74e-06 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 991499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 50.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.5      |
# | rollout/                   |          |
# |    success_rate            | 0.31     |
# | time/                      |          |
# |    episodes                | 19850    |
# |    fps                     | 104      |
# |    time_elapsed            | 9457     |
# |    total_timesteps         | 992500   |
# | train/                     |          |
# |    actor_loss              | 0.933    |
# |    critic_loss             | 6.11e-06 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | 0.789    |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 991999   |
# -----------------------------------------
# Eval num_timesteps=994000, episode_reward=-7.28 +/- 2.69
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.28    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 994000   |
# | train/             |          |
# |    actor_loss      | 0.894    |
# |    critic_loss     | 1.55e-05 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -0.984   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 993499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.5      |
# |    success_rate_eval       | 0.2      |
# | rollout/                   |          |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    episodes                | 19900    |
# |    fps                     | 104      |
# |    time_elapsed            | 9481     |
# |    total_timesteps         | 995000   |
# | train/                     |          |
# |    actor_loss              | 1.04     |
# |    critic_loss             | 6.29e-06 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | -1.18    |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 994499   |
# -----------------------------------------
# Eval num_timesteps=996000, episode_reward=-6.04 +/- 3.33
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.04    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 996000   |
# | train/             |          |
# |    actor_loss      | 0.967    |
# |    critic_loss     | 5.98e-06 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 995499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 40.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.5      |
# |    success_rate_eval       | 0.4      |
# | rollout/                   |          |
# |    success_rate            | 0.39     |
# | time/                      |          |
# |    episodes                | 19950    |
# |    fps                     | 104      |
# |    time_elapsed            | 9504     |
# |    total_timesteps         | 997500   |
# | train/                     |          |
# |    actor_loss              | 1.1      |
# |    critic_loss             | 7.71e-06 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | 0.713    |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 996999   |
# -----------------------------------------
# Eval num_timesteps=998000, episode_reward=-7.17 +/- 2.43
# Episode length: 50.00 +/- 0.00
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.17    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 998000   |
# | train/             |          |
# |    actor_loss      | 0.951    |
# |    critic_loss     | 5.84e-06 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -0.491   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 997499   |
# ---------------------------------
# ✅ [Monitor] Success rate: 40.00%
# Eval num_timesteps=1000000, episode_reward=-8.34 +/- 3.06
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval       | 0.4      |
# | eval/                      |          |
# |    mean_ep_length          | 50       |
# |    mean_reward             | -8.34    |
# |    success_rate            | 0.3      |
# | time/                      |          |
# |    total_timesteps         | 1000000  |
# | train/                     |          |
# |    actor_loss              | 0.962    |
# |    critic_loss             | 1.16e-05 |
# |    ent_coef                | 0.00109  |
# |    ent_coef_loss           | -1.01    |
# |    learning_rate           | 5e-05    |
# |    n_updates               | 999499   |
# -----------------------------------------
# ✅ [Monitor] Success rate: 20.00%
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval       | 0.2      |
# | rollout/                   |          |
# |    success_rate            | 0.35     |
# | time/                      |          |
# |    episodes                | 20000    |
# |    fps                     | 104      |
# |    time_elapsed            | 9531     |
# |    total_timesteps         | 1000000  |
# -----------------------------------------
# ✅ Final model and VecNormalize saved.
#
# 📊 To view TensorBoard logs:
# tensorboard --logdir ./tensorboard_sac_her_FetchReach-v3/tb_log

# %% [markdown]
# FINE TUNE NEW MODEL:

# %%
import os
import gymnasium as gym
import gymnasium_robotics # noqa - Registering FetchReach environments
import numpy as np
# import matplotlib.pyplot as plt # Not used in this script, but can be useful for custom plotting
from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.callbacks import EvalCallback, CallbackList, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor # To wrap the env for EvalCallback and custom callbacks

# === Custom Callbacks (Re-used from your original script) ===
class StopTrainingOnSuccessRate(BaseCallback):
    """
    Stop training when a threshold success rate is reached in evaluation.
    Uses the model's training environment for evaluation.

    :param success_threshold: The target success rate (e.g., 0.9 for 90%).
    :param eval_freq: How often to evaluate the success rate (in timesteps).
    :param verbose: Verbosity level.
    :param n_eval_episodes: Number of episodes for evaluation.
    """
    def __init__(self, success_threshold=0.90, eval_freq=2000, verbose=1, n_eval_episodes=10):
        super().__init__(verbose)
        self.success_threshold = success_threshold
        self.eval_freq = eval_freq
        self.n_eval_episodes = n_eval_episodes

    def _on_step(self) -> bool:
        # Check if it's time to evaluate
        if self.num_timesteps % self.eval_freq == 0:
            successes = []
            # Get the vectorized training environment from the model
            eval_env = self.model.get_env()

            if eval_env is None:
                if self.verbose > 0:
                    print("⚠️ [Monitor - Stop CB] Evaluation environment not found in model.")
                return True # Continue training, cannot evaluate

            for _ in range(self.n_eval_episodes):
                # Reset the environment. For VecEnv, reset returns a list/dict of obs.
                # We expect a single environment in DummyVecEnv, so obs_list[0]
                obs_list = eval_env.reset()
                obs = obs_list[0] if isinstance(obs_list, list) else obs_list
                done_list = [False] # For VecEnv, done is a list

                while not done_list[0]:
                    action, _ = self.model.predict(obs, deterministic=True)
                    # Step in the vectorized environment
                    next_obs_list, _, done_list, infos_list = eval_env.step(action)
                    obs = next_obs_list[0] if isinstance(next_obs_list, list) else next_obs_list

                # Extract 'is_success' from the info dictionary
                # Monitor wrapper places it in 'final_info' if truncated, or directly if terminated
                info = infos_list[0]
                is_success = info.get('is_success')
                if is_success is None and 'final_info' in info and info['final_info'] is not None:
                    is_success = info['final_info'].get('is_success')
                
                successes.append(is_success if is_success is not None else 0.0)


            if successes: # Ensure successes list is not empty
                success_rate = np.mean(successes)
                self.logger.record("custom/success_rate_eval_stop", success_rate)
                if self.verbose > 0:
                    print(f"✅ [Monitor - Stop CB] Success rate: {success_rate * 100:.2f}% (Timesteps: {self.num_timesteps})")
                if success_rate >= self.success_threshold:
                    print(f"🏆 [Early Stop CB] Target success rate {self.success_threshold*100:.2f}% reached ({success_rate * 100:.2f}%). Stopping training.")
                    return False # Stop training
            else:
                if self.verbose > 0:
                    print(f"⚠️ [Monitor - Stop CB] No success info recorded in {self.n_eval_episodes} episodes. Check 'is_success' key and Monitor wrapper.")

        return True # Continue training

class CheckpointOnSuccessRate(BaseCallback):
    """
    Save a checkpoint of the model when a threshold success rate is reached.
    Uses the model's training environment for evaluation.

    :param save_path: Path to save the checkpoint.
    :param success_threshold: The success rate threshold to trigger checkpointing.
    :param eval_freq: How often to evaluate the success rate (in timesteps).
    :param verbose: Verbosity level.
    :param n_eval_episodes: Number of episodes to run for evaluation.
    """
    def __init__(self, save_path, success_threshold=0.80, eval_freq=2000, verbose=1, n_eval_episodes=10):
        super().__init__(verbose)
        self.save_path = save_path
        self.success_threshold = success_threshold
        self.eval_freq = eval_freq
        self.n_eval_episodes = n_eval_episodes
        self.last_saved_timestep_checkpoint = -1 # Avoid saving multiple times for the same threshold if success fluctuates

    def _on_step(self) -> bool:
        if self.num_timesteps % self.eval_freq == 0:
            successes = []
            eval_env = self.model.get_env()

            if eval_env is None:
                if self.verbose > 0:
                    print("⚠️ [Monitor - Checkpoint CB] Evaluation environment not found in model.")
                return True

            for _ in range(self.n_eval_episodes):
                obs_list = eval_env.reset()
                obs = obs_list[0] if isinstance(obs_list, list) else obs_list
                done_list = [False]
                while not done_list[0]:
                    action, _ = self.model.predict(obs, deterministic=True)
                    next_obs_list, _, done_list, infos_list = eval_env.step(action)
                    obs = next_obs_list[0] if isinstance(next_obs_list, list) else next_obs_list
                
                info = infos_list[0]
                is_success = info.get('is_success')
                if is_success is None and 'final_info' in info and info['final_info'] is not None:
                    is_success = info['final_info'].get('is_success')
                successes.append(is_success if is_success is not None else 0.0)

            if successes:
                success_rate = np.mean(successes)
                self.logger.record("custom/success_rate_checkpoint", success_rate)
                if self.verbose > 0:
                     print(f"🧐 [Monitor - Checkpoint CB] Success rate: {success_rate * 100:.2f}% (Timesteps: {self.num_timesteps})")

                # Check if success rate is above threshold AND we haven't saved for this specific success level recently
                # This simple check avoids re-saving if it hovers around the threshold.
                # A more robust 'stabilized' flag might involve multiple consecutive high scores.
                if success_rate >= self.success_threshold and self.num_timesteps > self.last_saved_timestep_checkpoint:
                    checkpoint_model_path = os.path.join(self.save_path, f"checkpoint_model_ft_succ{int(success_rate*100)}_{self.num_timesteps}")
                    checkpoint_vecnorm_path = os.path.join(self.save_path, f"checkpoint_vecnormalize_ft_succ{int(success_rate*100)}_{self.num_timesteps}.pkl")

                    print(f"📦 [Checkpoint CB] Saving model at {success_rate * 100:.2f}% success rate to {checkpoint_model_path}")
                    self.model.save(checkpoint_model_path)
                    self.last_saved_timestep_checkpoint = self.num_timesteps # Update last saved timestep

                    # Save VecNormalize stats if the training environment is VecNormalize
                    # self.training_env is an alias for self.model.get_env() in callbacks
                    if isinstance(self.training_env, VecNormalize):
                        self.training_env.save(checkpoint_vecnorm_path)
                        if self.verbose > 0:
                            print(f"📦 [Checkpoint CB] Saved VecNormalize stats to {checkpoint_vecnorm_path}")
            else:
                if self.verbose > 0:
                    print(f"⚠️ [Monitor - Checkpoint CB] No success info recorded in {self.n_eval_episodes} episodes for checkpointing.")
        return True


# === Config for Fine-Tuning ===
env_id = "FetchReach-v3"
original_save_dir = f"./tensorboard_sac_her_{env_id}/" # Path to original model and stats
# Choose which model to load. Ensure this file exists.
# model_to_load_name = "final_model.zip"
# model_to_load_name = "best_model.zip"
model_to_load_name = "checkpoint_model.zip" # From your previous training

# Path for saving the fine-tuned model and its logs
finetune_save_dir = f"./tensorboard_sac_her_{env_id}_finetuned/"
finetune_best_model_path = os.path.join(finetune_save_dir, "best_finetuned_model")
finetune_final_model_path = os.path.join(finetune_save_dir, "final_finetuned_model")

os.makedirs(finetune_save_dir, exist_ok=True)

# === Env Setup for Fine-Tuning ===
def make_env():
    """Helper function to create and wrap the environment."""
    env = gym.make(env_id, reward_type='dense') # Use the same reward_type as original training
    env = Monitor(env) # Add Monitor to track episode stats like 'is_success' for callbacks
    return env

# Create the base vectorized environment for training
# This will be wrapped by VecNormalize
base_training_vec_env = DummyVecEnv([make_env])

# Load the VecNormalize statistics for the training environment
vecnormalize_path = os.path.join(original_save_dir, "vecnormalize.pkl") # Or specific checkpoint vecnormalize

if os.path.exists(vecnormalize_path):
    print(f"🔄 Loading training VecNormalize statistics from {vecnormalize_path}")
    # Load the saved VecNormalize stats and apply them to the base_training_vec_env
    training_env = VecNormalize.load(vecnormalize_path, base_training_vec_env)
    # For fine-tuning, continue to update normalization stats
    training_env.training = True
    # Ensure norm_reward setting matches original if it was part of VecNormalize config (usually False for HER)
    # training_env.norm_reward = False # Explicitly set if needed, load should handle it.
    print("✅ Training VecNormalize loaded and configured.")
else:
    print(f"⚠️ Training VecNormalize file not found at {vecnormalize_path}. Using new VecNormalize wrapper.")
    print("This might lead to unexpected behavior if the original model relied on specific normalization.")
    training_env = VecNormalize(base_training_vec_env, norm_obs=True, norm_reward=False, gamma=0.98) # Match original gamma if needed


# === Load Pre-trained Model ===
load_model_path = os.path.join(original_save_dir, model_to_load_name)
if not os.path.exists(load_model_path):
    raise FileNotFoundError(f"Model to load not found: {load_model_path}. Please check the path and filename.")

print(f"🔄 Loading pre-trained model from {load_model_path}")

# Custom objects for loading. Crucially, HerReplayBuffer needs the env.
# The learning rate here will be the new initial learning rate for fine-tuning.
custom_objects = {
    "learning_rate": 5e-5,  # Example: A potentially smaller learning rate for fine-tuning
    "replay_buffer_class": HerReplayBuffer,
    "replay_buffer_kwargs": dict(
        n_sampled_goal=16, # Must match original if not re-specifying everything
        goal_selection_strategy='future', # Must match original
    ),
    "gamma": 0.98, # Ensure consistency if these were non-default
    "tau": 0.005,
    # "buffer_size": int(1e6), # Usually part of saved model, but can be specified
}

# Load the model, providing the training_env directly
model = SAC.load(
    load_model_path,
    env=training_env, # CRITICAL FIX: Pass the prepared training_env here
    custom_objects=custom_objects,
    # device='cuda' # Uncomment if you want to force a device, e.g., 'cuda' or 'cpu'
)

# model.set_env(training_env) # This is now redundant as env is passed to load and set internally.

print(f"✅ Model loaded. Policy learning rate: {model.learning_rate}, Entropy coef: {model.ent_coef if hasattr(model, 'ent_coef') else 'N/A (auto?)'}")


# === Set up TensorBoard logger for Fine-Tuning ===
finetune_tb_log_path = os.path.join(finetune_save_dir, "tb_log_ft")
new_logger_ft = configure(finetune_tb_log_path, ["stdout", "tensorboard"])
model.set_logger(new_logger_ft)
print(f"📝 Logging fine-tuning to: {finetune_tb_log_path}")

# === Callbacks for Fine-Tuning ===
# Setup evaluation environment for EvalCallback
base_eval_env_ft = DummyVecEnv([make_env]) # Create a separate base instance for evaluation

if os.path.exists(vecnormalize_path):
    print(f"🔄 Loading VecNormalize statistics for separate eval_env_ft from {vecnormalize_path}")
    eval_env_ft = VecNormalize.load(vecnormalize_path, base_eval_env_ft)
    eval_env_ft.training = False  # CRUCIAL: Do not update normalization stats during evaluation
    eval_env_ft.norm_reward = False # Match training env's reward normalization setting
    print("✅ EvalCallback's VecNormalize loaded and configured.")
else:
    print(f"⚠️ VecNormalize file not found for EvalCallback's env at {vecnormalize_path}.")
    print("     EvalCallback will use a new VecNormalize wrapper with fresh (non-synced) stats.")
    eval_env_ft = VecNormalize(base_eval_env_ft, norm_obs=True, norm_reward=False, training=False, gamma=0.98)


eval_callback_ft = EvalCallback(
    eval_env_ft, 
    best_model_save_path=finetune_best_model_path,
    log_path=finetune_save_dir,
    eval_freq=5000, # Adjust frequency as needed for fine-tuning
    n_eval_episodes=20, # More episodes for robust evaluation
    deterministic=True,
    render=False,
    verbose=1
)

checkpoint_callback_ft = CheckpointOnSuccessRate(
    save_path=finetune_save_dir,
    success_threshold=0.90, # Potentially a higher threshold if fine-tuning
    eval_freq=5000,
    verbose=1,
    n_eval_episodes=10 # Custom callbacks use the training_env
)

stop_callback_ft = StopTrainingOnSuccessRate(
    success_threshold=0.98, # Higher threshold for stopping fine-tuning
    eval_freq=5000,
    verbose=1,
    n_eval_episodes=10 # Custom callbacks use the training_env
)

callback_ft = CallbackList([eval_callback_ft, checkpoint_callback_ft, stop_callback_ft])

# === Fine-Tune the Model ===
fine_tune_total_timesteps = 250_000 # Example: fine-tune for additional timesteps
log_interval_ft = 25

print(f"🚀 Fine-tuning SAC + HER on {env_id} for {fine_tune_total_timesteps} timesteps...")
# Consider reset_num_timesteps based on how you want to view logs.
# True: Fine-tuning starts from step 0 in new TensorBoard log.
# False: Continues from loaded model's timesteps.
model.learn(
    total_timesteps=fine_tune_total_timesteps,
    log_interval=log_interval_ft,
    callback=callback_ft,
    reset_num_timesteps=True # Recommended for clear fine-tuning logs
)

# === Save Fine-Tuned Model and VecNormalize Stats ===
model.save(finetune_final_model_path)
# Save the updated VecNormalize stats from the fine-tuning *training* environment
training_env.save(os.path.join(finetune_save_dir, "vecnormalize_finetuned.pkl"))
print(f"✅ Fine-tuned model saved to {finetune_final_model_path}")
print(f"✅ Updated VecNormalize stats saved to {os.path.join(finetune_save_dir, 'vecnormalize_finetuned.pkl')}")

# === TensorBoard usage for fine-tuning logs ===
print("\n📊 To view fine-tuning TensorBoard logs:")
print(f"tensorboard --logdir {finetune_tb_log_path}")
print("\n📊 To view original and fine-tuning logs together (if paths are structured correctly):")
# Assumes original logs are in original_save_dir/tb_log
original_tb_log_path = os.path.join(original_save_dir, "tb_log")
print(f"tensorboard --logdir_spec original:{original_tb_log_path},finetuned:{finetune_tb_log_path}")

# Close environments
training_env.close()
eval_env_ft.close()
print("Environments closed.")
# Out:
# 🔄 Loading training VecNormalize statistics from ./tensorboard_sac_her_FetchReach-v3/vecnormalize.pkl
# ✅ Training VecNormalize loaded and configured.
# 🔄 Loading pre-trained model from ./tensorboard_sac_her_FetchReach-v3/checkpoint_model.zip
# ✅ Model loaded. Policy learning rate: 5e-05, Entropy coef: auto
# Logging to ./tensorboard_sac_her_FetchReach-v3_finetuned/tb_log_ft
# 📝 Logging fine-tuning to: ./tensorboard_sac_her_FetchReach-v3_finetuned/tb_log_ft
# 🔄 Loading VecNormalize statistics for separate eval_env_ft from ./tensorboard_sac_her_FetchReach-v3/vecnormalize.pkl
# ✅ EvalCallback's VecNormalize loaded and configured.
# 🚀 Fine-tuning SAC + HER on FetchReach-v3 for 250000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -16      |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 185      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1250     |
# | train/             |          |
# |    actor_loss      | 0.809    |
# |    critic_loss     | 2.78e-05 |
# |    ent_coef        | 0.00113  |
# |    ent_coef_loss   | -1.86    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 444248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -12.1    |
# |    success_rate    | 0.26     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 150      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | 0.978    |
# |    critic_loss     | 1.37e-05 |
# |    ent_coef        | 0.00114  |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 445498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -10.5    |
# |    success_rate    | 0.293    |
# | time/              |          |
# |    episodes        | 75       |
# |    fps             | 141      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 3750     |
# | train/             |          |
# |    actor_loss      | 0.964    |
# |    critic_loss     | 1.47e-05 |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | 0.954    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 446748   |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-7.61 +/- 3.29
# Episode length: 50.00 +/- 0.00
# Success rate: 35.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.61    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | 1.08     |
# |    critic_loss     | 1.43e-05 |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | 0.178    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 447998   |
# ---------------------------------
# New best mean reward!
# 🧐 [Monitor - Checkpoint CB] Success rate: 20.00% (Timesteps: 5000)
# ✅ [Monitor - Stop CB] Success rate: 40.00% (Timesteps: 5000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval_stop  | 0.4      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -10.1    |
# |    success_rate            | 0.26     |
# | time/                      |          |
# |    episodes                | 100      |
# |    fps                     | 124      |
# |    time_elapsed            | 40       |
# |    total_timesteps         | 5000     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -8.1     |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 125      |
# |    fps             | 124      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 6250     |
# | train/             |          |
# |    actor_loss      | 0.939    |
# |    critic_loss     | 1.19e-05 |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 0.0811   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 449248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.92    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 124      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | 0.884    |
# |    critic_loss     | 8.57e-06 |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 450498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.72    |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 175      |
# |    fps             | 125      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 8750     |
# | train/             |          |
# |    actor_loss      | 0.829    |
# |    critic_loss     | 9.85e-06 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -1.7     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 451748   |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-7.36 +/- 3.30
# Episode length: 50.00 +/- 0.00
# Success rate: 35.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.36    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 0.978    |
# |    critic_loss     | 9.33e-06 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -2.39    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 452998   |
# ---------------------------------
# New best mean reward!
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 10000)
# ✅ [Monitor - Stop CB] Success rate: 20.00% (Timesteps: 10000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.2      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.62    |
# |    success_rate            | 0.31     |
# | time/                      |          |
# |    episodes                | 200      |
# |    fps                     | 119      |
# |    time_elapsed            | 83       |
# |    total_timesteps         | 10000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.47    |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 225      |
# |    fps             | 120      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 11250    |
# | train/             |          |
# |    actor_loss      | 1.04     |
# |    critic_loss     | 8.24e-06 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 0.957    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 454248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.35    |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 120      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 12500    |
# | train/             |          |
# |    actor_loss      | 0.921    |
# |    critic_loss     | 1.14e-05 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -0.641   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 455498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.56    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 275      |
# |    fps             | 121      |
# |    time_elapsed    | 113      |
# |    total_timesteps | 13750    |
# | train/             |          |
# |    actor_loss      | 0.996    |
# |    critic_loss     | 7.64e-06 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 0.723    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 456748   |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-6.55 +/- 3.49
# Episode length: 50.00 +/- 0.00
# Success rate: 45.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.55    |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 1.04     |
# |    critic_loss     | 1.02e-05 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 0.112    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 457998   |
# ---------------------------------
# New best mean reward!
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 15000)
# ✅ [Monitor - Stop CB] Success rate: 30.00% (Timesteps: 15000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.3      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.37    |
# |    success_rate            | 0.38     |
# | time/                      |          |
# |    episodes                | 300      |
# |    fps                     | 117      |
# |    time_elapsed            | 127      |
# |    total_timesteps         | 15000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.35    |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 325      |
# |    fps             | 118      |
# |    time_elapsed    | 137      |
# |    total_timesteps | 16250    |
# | train/             |          |
# |    actor_loss      | 0.835    |
# |    critic_loss     | 1.19e-05 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 459248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.66    |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 118      |
# |    time_elapsed    | 147      |
# |    total_timesteps | 17500    |
# | train/             |          |
# |    actor_loss      | 1.02     |
# |    critic_loss     | 1.53e-05 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 460498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.4     |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 375      |
# |    fps             | 119      |
# |    time_elapsed    | 157      |
# |    total_timesteps | 18750    |
# | train/             |          |
# |    actor_loss      | 0.885    |
# |    critic_loss     | 1.14e-05 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 0.425    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 461748   |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=-7.83 +/- 3.68
# Episode length: 50.00 +/- 0.00
# Success rate: 45.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.83    |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | 1.02     |
# |    critic_loss     | 1.37e-05 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | 0.581    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 462998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 20.00% (Timesteps: 20000)
# ✅ [Monitor - Stop CB] Success rate: 50.00% (Timesteps: 20000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval_stop  | 0.5      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.55    |
# |    success_rate            | 0.35     |
# | time/                      |          |
# |    episodes                | 400      |
# |    fps                     | 117      |
# |    time_elapsed            | 170      |
# |    total_timesteps         | 20000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.4     |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 425      |
# |    fps             | 117      |
# |    time_elapsed    | 180      |
# |    total_timesteps | 21250    |
# | train/             |          |
# |    actor_loss      | 1.02     |
# |    critic_loss     | 9.85e-06 |
# |    ent_coef        | 0.00108  |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 464248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -6.88    |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 117      |
# |    time_elapsed    | 190      |
# |    total_timesteps | 22500    |
# | train/             |          |
# |    actor_loss      | 1.01     |
# |    critic_loss     | 1.41e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.107    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 465498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.06    |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 475      |
# |    fps             | 118      |
# |    time_elapsed    | 200      |
# |    total_timesteps | 23750    |
# | train/             |          |
# |    actor_loss      | 0.852    |
# |    critic_loss     | 1.16e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.261   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 466748   |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=-7.43 +/- 3.49
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.43    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | 0.886    |
# |    critic_loss     | 1.28e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.767   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 467998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 40.00% (Timesteps: 25000)
# ✅ [Monitor - Stop CB] Success rate: 10.00% (Timesteps: 25000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval_stop  | 0.1      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -6.71    |
# |    success_rate            | 0.43     |
# | time/                      |          |
# |    episodes                | 500      |
# |    fps                     | 116      |
# |    time_elapsed            | 214      |
# |    total_timesteps         | 25000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.03    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 525      |
# |    fps             | 116      |
# |    time_elapsed    | 224      |
# |    total_timesteps | 26250    |
# | train/             |          |
# |    actor_loss      | 0.955    |
# |    critic_loss     | 1.3e-05  |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.233    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 469248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.28    |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 117      |
# |    time_elapsed    | 234      |
# |    total_timesteps | 27500    |
# | train/             |          |
# |    actor_loss      | 1.06     |
# |    critic_loss     | 1.14e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.966    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 470498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.19    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 575      |
# |    fps             | 117      |
# |    time_elapsed    | 244      |
# |    total_timesteps | 28750    |
# | train/             |          |
# |    actor_loss      | 1.02     |
# |    critic_loss     | 1.41e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.519   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 471748   |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=-7.84 +/- 3.20
# Episode length: 50.00 +/- 0.00
# Success rate: 35.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.84    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | 0.976    |
# |    critic_loss     | 1.25e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.959    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 472998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 20.00% (Timesteps: 30000)
# ✅ [Monitor - Stop CB] Success rate: 70.00% (Timesteps: 30000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval_stop  | 0.7      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.5     |
# |    success_rate            | 0.33     |
# | time/                      |          |
# |    episodes                | 600      |
# |    fps                     | 116      |
# |    time_elapsed            | 258      |
# |    total_timesteps         | 30000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.36    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 625      |
# |    fps             | 116      |
# |    time_elapsed    | 268      |
# |    total_timesteps | 31250    |
# | train/             |          |
# |    actor_loss      | 0.899    |
# |    critic_loss     | 7.63e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.309   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 474248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.39    |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 116      |
# |    time_elapsed    | 278      |
# |    total_timesteps | 32500    |
# | train/             |          |
# |    actor_loss      | 0.956    |
# |    critic_loss     | 1.72e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.196    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 475498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.79    |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 675      |
# |    fps             | 116      |
# |    time_elapsed    | 288      |
# |    total_timesteps | 33750    |
# | train/             |          |
# |    actor_loss      | 0.919    |
# |    critic_loss     | 9.42e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.864    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 476748   |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=-7.64 +/- 3.16
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.64    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | 0.93     |
# |    critic_loss     | 1.52e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.346    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 477998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 70.00% (Timesteps: 35000)
# ✅ [Monitor - Stop CB] Success rate: 10.00% (Timesteps: 35000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.7      |
# |    success_rate_eval_stop  | 0.1      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.45    |
# |    success_rate            | 0.32     |
# | time/                      |          |
# |    episodes                | 700      |
# |    fps                     | 115      |
# |    time_elapsed            | 302      |
# |    total_timesteps         | 35000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.68    |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 725      |
# |    fps             | 116      |
# |    time_elapsed    | 312      |
# |    total_timesteps | 36250    |
# | train/             |          |
# |    actor_loss      | 1.03     |
# |    critic_loss     | 7.64e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.2      |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 479248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.92    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 116      |
# |    time_elapsed    | 322      |
# |    total_timesteps | 37500    |
# | train/             |          |
# |    actor_loss      | 0.841    |
# |    critic_loss     | 1.53e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -1.4     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 480498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.61    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 775      |
# |    fps             | 116      |
# |    time_elapsed    | 332      |
# |    total_timesteps | 38750    |
# | train/             |          |
# |    actor_loss      | 1.03     |
# |    critic_loss     | 7.59e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.28     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 481748   |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=-6.01 +/- 2.84
# Episode length: 50.00 +/- 0.00
# Success rate: 50.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.01    |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | 1.04     |
# |    critic_loss     | 8.42e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.098    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 482998   |
# ---------------------------------
# New best mean reward!
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 40000)
# ✅ [Monitor - Stop CB] Success rate: 50.00% (Timesteps: 40000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.5      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.78    |
# |    success_rate            | 0.36     |
# | time/                      |          |
# |    episodes                | 800      |
# |    fps                     | 115      |
# |    time_elapsed            | 346      |
# |    total_timesteps         | 40000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.55    |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 825      |
# |    fps             | 115      |
# |    time_elapsed    | 356      |
# |    total_timesteps | 41250    |
# | train/             |          |
# |    actor_loss      | 0.923    |
# |    critic_loss     | 9.09e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.211    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 484248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.53    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 115      |
# |    time_elapsed    | 366      |
# |    total_timesteps | 42500    |
# | train/             |          |
# |    actor_loss      | 0.954    |
# |    critic_loss     | 1.04e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.629   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 485498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.75    |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 875      |
# |    fps             | 116      |
# |    time_elapsed    | 376      |
# |    total_timesteps | 43750    |
# | train/             |          |
# |    actor_loss      | 1.01     |
# |    critic_loss     | 2.17e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.739    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 486748   |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=-6.78 +/- 3.21
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.78    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | 0.977    |
# |    critic_loss     | 1.05e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.0671   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 487998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 45000)
# ✅ [Monitor - Stop CB] Success rate: 20.00% (Timesteps: 45000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.2      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.81    |
# |    success_rate            | 0.31     |
# | time/                      |          |
# |    episodes                | 900      |
# |    fps                     | 115      |
# |    time_elapsed            | 390      |
# |    total_timesteps         | 45000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.67    |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 925      |
# |    fps             | 115      |
# |    time_elapsed    | 400      |
# |    total_timesteps | 46250    |
# | train/             |          |
# |    actor_loss      | 1.07     |
# |    critic_loss     | 1.39e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 1.94     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 489248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.39    |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 950      |
# |    fps             | 115      |
# |    time_elapsed    | 410      |
# |    total_timesteps | 47500    |
# | train/             |          |
# |    actor_loss      | 0.886    |
# |    critic_loss     | 8.25e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.845   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 490498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.48    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 975      |
# |    fps             | 115      |
# |    time_elapsed    | 420      |
# |    total_timesteps | 48750    |
# | train/             |          |
# |    actor_loss      | 0.926    |
# |    critic_loss     | 1.03e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.35    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 491748   |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-7.77 +/- 3.30
# Episode length: 50.00 +/- 0.00
# Success rate: 30.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.77    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | 0.974    |
# |    critic_loss     | 6.61e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.22     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 492998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 50.00% (Timesteps: 50000)
# ✅ [Monitor - Stop CB] Success rate: 20.00% (Timesteps: 50000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.5      |
# |    success_rate_eval_stop  | 0.2      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.5     |
# |    success_rate            | 0.42     |
# | time/                      |          |
# |    episodes                | 1000     |
# |    fps                     | 115      |
# |    time_elapsed            | 434      |
# |    total_timesteps         | 50000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.55    |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 1025     |
# |    fps             | 115      |
# |    time_elapsed    | 444      |
# |    total_timesteps | 51250    |
# | train/             |          |
# |    actor_loss      | 1.03     |
# |    critic_loss     | 1.35e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.742    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 494248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.78    |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1050     |
# |    fps             | 115      |
# |    time_elapsed    | 454      |
# |    total_timesteps | 52500    |
# | train/             |          |
# |    actor_loss      | 1.07     |
# |    critic_loss     | 1.31e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -1.74    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 495498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.63    |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 1075     |
# |    fps             | 115      |
# |    time_elapsed    | 464      |
# |    total_timesteps | 53750    |
# | train/             |          |
# |    actor_loss      | 0.929    |
# |    critic_loss     | 9.75e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.155    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 496748   |
# ---------------------------------
# Eval num_timesteps=55000, episode_reward=-7.30 +/- 4.39
# Episode length: 50.00 +/- 0.00
# Success rate: 55.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.3     |
# |    success_rate    | 0.55     |
# | time/              |          |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | 0.942    |
# |    critic_loss     | 1.03e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.091   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 497998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 20.00% (Timesteps: 55000)
# ✅ [Monitor - Stop CB] Success rate: 40.00% (Timesteps: 55000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval_stop  | 0.4      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.64    |
# |    success_rate            | 0.39     |
# | time/                      |          |
# |    episodes                | 1100     |
# |    fps                     | 114      |
# |    time_elapsed            | 478      |
# |    total_timesteps         | 55000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.46    |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 1125     |
# |    fps             | 115      |
# |    time_elapsed    | 488      |
# |    total_timesteps | 56250    |
# | train/             |          |
# |    actor_loss      | 0.933    |
# |    critic_loss     | 7.48e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.416   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 499248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1150     |
# |    fps             | 115      |
# |    time_elapsed    | 498      |
# |    total_timesteps | 57500    |
# | train/             |          |
# |    actor_loss      | 0.922    |
# |    critic_loss     | 1.25e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.535   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 500498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.36    |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1175     |
# |    fps             | 115      |
# |    time_elapsed    | 508      |
# |    total_timesteps | 58750    |
# | train/             |          |
# |    actor_loss      | 0.934    |
# |    critic_loss     | 1.14e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.903   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 501748   |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=-8.20 +/- 3.57
# Episode length: 50.00 +/- 0.00
# Success rate: 25.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.2     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | 0.965    |
# |    critic_loss     | 8.01e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -1.37    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 502998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 60000)
# ✅ [Monitor - Stop CB] Success rate: 60.00% (Timesteps: 60000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.6      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.49    |
# |    success_rate            | 0.39     |
# | time/                      |          |
# |    episodes                | 1200     |
# |    fps                     | 114      |
# |    time_elapsed            | 522      |
# |    total_timesteps         | 60000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.67    |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 1225     |
# |    fps             | 114      |
# |    time_elapsed    | 532      |
# |    total_timesteps | 61250    |
# | train/             |          |
# |    actor_loss      | 0.871    |
# |    critic_loss     | 8.22e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.244    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 504248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.64    |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 1250     |
# |    fps             | 115      |
# |    time_elapsed    | 542      |
# |    total_timesteps | 62500    |
# | train/             |          |
# |    actor_loss      | 0.947    |
# |    critic_loss     | 1.11e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 505498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.27    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1275     |
# |    fps             | 115      |
# |    time_elapsed    | 552      |
# |    total_timesteps | 63750    |
# | train/             |          |
# |    actor_loss      | 0.949    |
# |    critic_loss     | 8.73e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 1.82     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 506748   |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=-6.90 +/- 3.50
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.9     |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | 1.06     |
# |    critic_loss     | 1.22e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.116   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 507998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 65000)
# ✅ [Monitor - Stop CB] Success rate: 40.00% (Timesteps: 65000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.4      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.1     |
# |    success_rate            | 0.39     |
# | time/                      |          |
# |    episodes                | 1300     |
# |    fps                     | 114      |
# |    time_elapsed            | 566      |
# |    total_timesteps         | 65000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.38    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 1325     |
# |    fps             | 114      |
# |    time_elapsed    | 576      |
# |    total_timesteps | 66250    |
# | train/             |          |
# |    actor_loss      | 0.992    |
# |    critic_loss     | 9.22e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.815    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 509248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.38    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1350     |
# |    fps             | 115      |
# |    time_elapsed    | 586      |
# |    total_timesteps | 67500    |
# | train/             |          |
# |    actor_loss      | 0.97     |
# |    critic_loss     | 9.14e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.165    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 510498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.94    |
# |    success_rate    | 0.28     |
# | time/              |          |
# |    episodes        | 1375     |
# |    fps             | 115      |
# |    time_elapsed    | 596      |
# |    total_timesteps | 68750    |
# | train/             |          |
# |    actor_loss      | 0.935    |
# |    critic_loss     | 1.35e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.796   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 511748   |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=-7.71 +/- 3.34
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.71    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | 1        |
# |    critic_loss     | 1.76e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.0152   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 512998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 70000)
# ✅ [Monitor - Stop CB] Success rate: 40.00% (Timesteps: 70000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.4      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.93    |
# |    success_rate            | 0.31     |
# | time/                      |          |
# |    episodes                | 1400     |
# |    fps                     | 114      |
# |    time_elapsed            | 610      |
# |    total_timesteps         | 70000    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.53    |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 1425     |
# |    fps             | 114      |
# |    time_elapsed    | 620      |
# |    total_timesteps | 71250    |
# | train/             |          |
# |    actor_loss      | 1.01     |
# |    critic_loss     | 7.9e-06  |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.579    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 514248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.54    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 1450     |
# |    fps             | 114      |
# |    time_elapsed    | 631      |
# |    total_timesteps | 72500    |
# | train/             |          |
# |    actor_loss      | 1.01     |
# |    critic_loss     | 1.01e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.783    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 515498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.13    |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 1475     |
# |    fps             | 115      |
# |    time_elapsed    | 641      |
# |    total_timesteps | 73750    |
# | train/             |          |
# |    actor_loss      | 0.926    |
# |    critic_loss     | 8.28e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.975    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 516748   |
# ---------------------------------
# Eval num_timesteps=75000, episode_reward=-7.32 +/- 3.65
# Episode length: 50.00 +/- 0.00
# Success rate: 35.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.32    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | 1.04     |
# |    critic_loss     | 1.71e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.478   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 517998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 40.00% (Timesteps: 75000)
# ✅ [Monitor - Stop CB] Success rate: 50.00% (Timesteps: 75000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval_stop  | 0.5      |
# | rollout/                   |          |
# ...
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 669248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.41    |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 4550     |
# |    fps             | 113      |
# |    time_elapsed    | 2012     |
# |    total_timesteps | 227500   |
# | train/             |          |
# |    actor_loss      | 0.894    |
# |    critic_loss     | 6.35e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -1.67    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 670498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.4     |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 4575     |
# |    fps             | 113      |
# |    time_elapsed    | 2022     |
# |    total_timesteps | 228750   |
# | train/             |          |
# |    actor_loss      | 1.02     |
# |    critic_loss     | 6.76e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 1.21     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 671748   |
# ---------------------------------
# Eval num_timesteps=230000, episode_reward=-7.60 +/- 3.10
# Episode length: 50.00 +/- 0.00
# Success rate: 25.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.6     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    total_timesteps | 230000   |
# | train/             |          |
# |    actor_loss      | 1.07     |
# |    critic_loss     | 6.05e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 1.55     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 672998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 40.00% (Timesteps: 230000)
# ✅ [Monitor - Stop CB] Success rate: 30.00% (Timesteps: 230000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval_stop  | 0.3      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.54    |
# |    success_rate            | 0.34     |
# | time/                      |          |
# |    episodes                | 4600     |
# |    fps                     | 112      |
# |    time_elapsed            | 2037     |
# |    total_timesteps         | 230000   |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.43    |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 4625     |
# |    fps             | 112      |
# |    time_elapsed    | 2047     |
# |    total_timesteps | 231250   |
# | train/             |          |
# |    actor_loss      | 0.979    |
# |    critic_loss     | 2.44e-05 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.766    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 674248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 4650     |
# |    fps             | 112      |
# |    time_elapsed    | 2057     |
# |    total_timesteps | 232500   |
# | train/             |          |
# |    actor_loss      | 0.964    |
# |    critic_loss     | 1e-05    |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.209    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 675498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.27    |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 4675     |
# |    fps             | 113      |
# |    time_elapsed    | 2067     |
# |    total_timesteps | 233750   |
# | train/             |          |
# |    actor_loss      | 0.878    |
# |    critic_loss     | 5.54e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.864   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 676748   |
# ---------------------------------
# Eval num_timesteps=235000, episode_reward=-6.59 +/- 2.88
# Episode length: 50.00 +/- 0.00
# Success rate: 55.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -6.59    |
# |    success_rate    | 0.55     |
# | time/              |          |
# |    total_timesteps | 235000   |
# | train/             |          |
# |    actor_loss      | 0.903    |
# |    critic_loss     | 7.07e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -1.13    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 677998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 235000)
# ✅ [Monitor - Stop CB] Success rate: 70.00% (Timesteps: 235000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.7      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.16    |
# |    success_rate            | 0.43     |
# | time/                      |          |
# |    episodes                | 4700     |
# |    fps                     | 112      |
# |    time_elapsed            | 2082     |
# |    total_timesteps         | 235000   |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.33    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 4725     |
# |    fps             | 112      |
# |    time_elapsed    | 2092     |
# |    total_timesteps | 236250   |
# | train/             |          |
# |    actor_loss      | 0.871    |
# |    critic_loss     | 8.05e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.534   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 679248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.05    |
# |    success_rate    | 0.39     |
# | time/              |          |
# |    episodes        | 4750     |
# |    fps             | 112      |
# |    time_elapsed    | 2102     |
# |    total_timesteps | 237500   |
# | train/             |          |
# |    actor_loss      | 0.907    |
# |    critic_loss     | 7.51e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.511   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 680498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.53    |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 4775     |
# |    fps             | 112      |
# |    time_elapsed    | 2113     |
# |    total_timesteps | 238750   |
# | train/             |          |
# |    actor_loss      | 0.929    |
# |    critic_loss     | 7.39e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | 0.594    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 681748   |
# ---------------------------------
# Eval num_timesteps=240000, episode_reward=-9.36 +/- 3.46
# Episode length: 50.00 +/- 0.00
# Success rate: 15.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -9.36    |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    total_timesteps | 240000   |
# | train/             |          |
# |    actor_loss      | 0.986    |
# |    critic_loss     | 7.52e-06 |
# |    ent_coef        | 0.00107  |
# |    ent_coef_loss   | -0.045   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 682998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 20.00% (Timesteps: 240000)
# ✅ [Monitor - Stop CB] Success rate: 40.00% (Timesteps: 240000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.2      |
# |    success_rate_eval_stop  | 0.4      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.86    |
# |    success_rate            | 0.33     |
# | time/                      |          |
# |    episodes                | 4800     |
# |    fps                     | 112      |
# |    time_elapsed            | 2127     |
# |    total_timesteps         | 240000   |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.46    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 4825     |
# |    fps             | 112      |
# |    time_elapsed    | 2137     |
# |    total_timesteps | 241250   |
# | train/             |          |
# |    actor_loss      | 0.923    |
# |    critic_loss     | 6.83e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.918   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 684248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.81    |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 4850     |
# |    fps             | 112      |
# |    time_elapsed    | 2147     |
# |    total_timesteps | 242500   |
# | train/             |          |
# |    actor_loss      | 0.976    |
# |    critic_loss     | 8.22e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.793    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 685498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.56    |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 4875     |
# |    fps             | 112      |
# |    time_elapsed    | 2158     |
# |    total_timesteps | 243750   |
# | train/             |          |
# |    actor_loss      | 0.981    |
# |    critic_loss     | 7.42e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.923   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 686748   |
# ---------------------------------
# Eval num_timesteps=245000, episode_reward=-8.80 +/- 3.65
# Episode length: 50.00 +/- 0.00
# Success rate: 25.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.8     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    total_timesteps | 245000   |
# | train/             |          |
# |    actor_loss      | 0.915    |
# |    critic_loss     | 7.2e-06  |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 0.477    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 687998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 30.00% (Timesteps: 245000)
# ✅ [Monitor - Stop CB] Success rate: 50.00% (Timesteps: 245000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.3      |
# |    success_rate_eval_stop  | 0.5      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.52    |
# |    success_rate            | 0.34     |
# | time/                      |          |
# |    episodes                | 4900     |
# |    fps                     | 112      |
# |    time_elapsed            | 2172     |
# |    total_timesteps         | 245000   |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.99    |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 4925     |
# |    fps             | 112      |
# |    time_elapsed    | 2182     |
# |    total_timesteps | 246250   |
# | train/             |          |
# |    actor_loss      | 0.977    |
# |    critic_loss     | 5.48e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -0.899   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 689248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -8.06    |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 4950     |
# |    fps             | 112      |
# |    time_elapsed    | 2192     |
# |    total_timesteps | 247500   |
# | train/             |          |
# |    actor_loss      | 0.924    |
# |    critic_loss     | 5.29e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 690498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.95    |
# |    success_rate    | 0.31     |
# | time/              |          |
# |    episodes        | 4975     |
# |    fps             | 112      |
# |    time_elapsed    | 2202     |
# |    total_timesteps | 248750   |
# | train/             |          |
# |    actor_loss      | 1.08     |
# |    critic_loss     | 2.8e-05  |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | 1.57     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 691748   |
# ---------------------------------
# Eval num_timesteps=250000, episode_reward=-7.68 +/- 4.14
# Episode length: 50.00 +/- 0.00
# Success rate: 40.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.68    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    total_timesteps | 250000   |
# | train/             |          |
# |    actor_loss      | 1.02     |
# |    critic_loss     | 6.27e-06 |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -1.44    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 692998   |
# ---------------------------------
# 🧐 [Monitor - Checkpoint CB] Success rate: 40.00% (Timesteps: 250000)
# ✅ [Monitor - Stop CB] Success rate: 40.00% (Timesteps: 250000)
# -----------------------------------------
# | custom/                    |          |
# |    success_rate_checkpoint | 0.4      |
# |    success_rate_eval_stop  | 0.4      |
# | rollout/                   |          |
# |    ep_len_mean             | 50       |
# |    ep_rew_mean             | -7.6     |
# |    success_rate            | 0.35     |
# | time/                      |          |
# |    episodes                | 5000     |
# |    fps                     | 112      |
# |    time_elapsed            | 2219     |
# |    total_timesteps         | 250000   |
# -----------------------------------------
# ✅ Fine-tuned model saved to ./tensorboard_sac_her_FetchReach-v3_finetuned/final_finetuned_model
# ✅ Updated VecNormalize stats saved to ./tensorboard_sac_her_FetchReach-v3_finetuned/vecnormalize_finetuned.pkl
#
# 📊 To view fine-tuning TensorBoard logs:
# tensorboard --logdir ./tensorboard_sac_her_FetchReach-v3_finetuned/tb_log_ft
#
# 📊 To view original and fine-tuning logs together (if paths are structured correctly):
# tensorboard --logdir_spec original:./tensorboard_sac_her_FetchReach-v3/tb_log,finetuned:./tensorboard_sac_her_FetchReach-v3_finetuned/tb_log_ft
# Environments closed.

# %%
import os
import gymnasium as gym
import gymnasium_robotics
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import deque
import random
from torch.utils.tensorboard import SummaryWriter # Import TensorBoard

config = {
    "env_name": "FetchReach-v3",
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "steps": 20000, # Total environment steps for training
    "hidden_dim": 256,
    "log_every": 1000, # Log metrics every N steps
    "imag_horizon": 15, # Imagination horizon length (H)
    "batch_size": 64,
    "buffer_size": 100000,
    "prefill_steps": 1000, # Steps to prefill buffer with random actions
    "gamma": 0.99, # Discount factor for rewards
    "learning_rate": 3e-4,
    "action_scale": 0.05, # Scale factor for actor's output actions
    "dyn_loss_scale": 0.5, # Weight for the dynamics prediction loss in World Model
    "actor_critic_update_freq": 1, # How often to update actor/critic per env step (after prefill)
    "world_model_update_freq": 1, # How often to update world model per env step (after prefill)
}

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, obs, action, reward, next_obs, done):
        # Ensure obs and next_obs are base numpy arrays if they are dicts
        obs_flat = obs['observation'] if isinstance(obs, dict) else obs
        next_obs_flat = next_obs['observation'] if isinstance(next_obs, dict) else next_obs
        self.buffer.append((obs_flat, action, reward, next_obs_flat, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        obs, act, rew, next_obs, done = map(np.stack, zip(*batch))
        return (
            torch.tensor(obs, dtype=torch.float32).to(config["device"]),
            torch.tensor(act, dtype=torch.float32).to(config["device"]),
            torch.tensor(rew, dtype=torch.float32).unsqueeze(1).to(config["device"]),
            torch.tensor(next_obs, dtype=torch.float32).to(config["device"]),
            torch.tensor(done, dtype=torch.float32).unsqueeze(1).to(config["device"])
        )

    def __len__(self):
        return len(self.buffer)

class WorldModel(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        # Encodes observation s_t to an embedding e_t
        self.encoder = nn.Sequential(
            nn.Linear(obs_dim, config["hidden_dim"]),
            nn.ReLU(),
            # Optionally add more layers or different activations
        )
        # GRU cell for dynamics: h_t = GRU(cat(e_t, a_t), h_{t-1})
        # Input to GRU is concatenation of observation embedding and action
        self.dynamics = nn.GRUCell(config["hidden_dim"] + act_dim, config["hidden_dim"])
        # Predicts reward from the GRU's hidden state h_t
        self.reward_head = nn.Linear(config["hidden_dim"], 1)
        # Head to predict next observation embedding (optional, but part of many world models)
        # For this script, dynamics output (hidden state) IS the predicted next latent state.

    def forward(self, obs_embed, action, prev_gru_state):
        """
        Applies the dynamics model for one step.
        Args:
            obs_embed (Tensor): Embedding of the current observation (e_t).
            action (Tensor): Action taken (a_t).
            prev_gru_state (Tensor): Previous hidden state of the GRU (h_{t-1}).
        Returns:
            next_gru_state (Tensor): Next hidden state of the GRU (h_t), which is the predicted latent.
            pred_reward (Tensor): Predicted reward (r_t).
        """
        # Concatenate current observation embedding and action for GRU input
        gru_input = torch.cat([obs_embed, action], dim=-1)
        next_gru_state = self.dynamics(gru_input, prev_gru_state)
        pred_reward = self.reward_head(next_gru_state)
        return next_gru_state, pred_reward

    def encode_obs(self, obs):
        """Encodes a raw observation."""
        return self.encoder(obs)

class Actor(nn.Module):
    def __init__(self, feat_dim, act_dim): # feat_dim is hidden_dim (GRU state dim)
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], config["hidden_dim"]), # Added another layer
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], act_dim),
            nn.Tanh() # Outputs actions in [-1, 1]
        )
        self.action_scale = torch.tensor(config["action_scale"], dtype=torch.float32)

    def forward(self, latent_state_features):
        # Scale Tanh output to desired action range
        return self.action_scale.to(latent_state_features.device) * self.net(latent_state_features)

class Critic(nn.Module):
    def __init__(self, feat_dim): # feat_dim is hidden_dim (GRU state dim)
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], config["hidden_dim"]), # Added another layer
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], 1) # Outputs a scalar value
        )

    def forward(self, latent_state_features):
        return self.net(latent_state_features)

def imagine_rollout(actor, world_model, start_latent_state, horizon):
    """
    Generates an imagined trajectory using the actor and world model.
    Args:
        actor (Actor): The policy network.
        world_model (WorldModel): The learned world model.
        start_latent_state (Tensor): The initial latent state for imagination (batch_size, hidden_dim).
        horizon (int): The length of the imagined trajectory.
    Returns:
        List of tuples: [(imag_latent_k, imag_reward_k), ...], where k is from 1 to H.
                        imag_latent_k is the k-th imagined latent state (output of dynamics).
                        imag_reward_k is the k-th predicted reward.
    """
    imag_latents_rewards = []
    current_latent = start_latent_state # z_0

    for _ in range(horizon):
        action = actor(current_latent) # a_k ~ actor(z_k)
        # In our WorldModel, forward_through_dynamics is essentially the dynamics step.
        # It needs an "observation embedding" and "action" for its GRU input part.
        # During imagination, the "observation embedding" is the current_latent itself.
        # The GRU's "previous hidden state" is also the current_latent.
        # So, z_{k+1}, r_{k+1} = WM_dynamics(z_k, a_k, z_k)
        next_latent, pred_reward = world_model.forward(current_latent, action, current_latent)
        imag_latents_rewards.append((next_latent, pred_reward))
        current_latent = next_latent # Update for next imagination step
    return imag_latents_rewards


def make_env():
    env = gym.make(config["env_name"], reward_type="dense") # Ensure dense reward explicitly
    # Seed for reproducibility, though other sources of randomness exist (torch, numpy)
    # For full reproducibility, seed torch, numpy, and random.
    # obs, info = env.reset(seed=42) # Seeding here is good
    return env

def train():
    env = make_env()
    # Seeding for external libraries
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)
    obs_dict_init, _ = env.reset(seed=42)


    obs_space_dims = env.observation_space["observation"].shape[0]
    act_dim = env.action_space.shape[0]

    buffer = ReplayBuffer(config["buffer_size"])
    writer = SummaryWriter(log_dir=f"runs/{config['env_name']}_DreamerV3_style_{random.randint(0,10000)}") # Tensorboard writer

    # Initialize models
    wm = WorldModel(obs_space_dims, act_dim).to(config["device"])
    actor = Actor(config["hidden_dim"], act_dim).to(config["device"])
    critic = Critic(config["hidden_dim"]).to(config["device"])

    # Optimizers
    optim_wm = torch.optim.Adam(wm.parameters(), lr=config["learning_rate"], eps=1e-5) # Added eps for stability
    optim_actor = torch.optim.Adam(actor.parameters(), lr=config["learning_rate"], eps=1e-5)
    optim_critic = torch.optim.Adam(critic.parameters(), lr=config["learning_rate"], eps=1e-5)

    # Initial observation and agent state
    obs_dict, _ = env.reset()
    current_obs = obs_dict["observation"]
    
    # Prefill replay buffer with random actions
    print(f"Prefilling buffer with {config['prefill_steps']} random steps...")
    for _ in range(config["prefill_steps"]):
        action = env.action_space.sample()
        next_obs_dict, env_reward, done, truncated, _ = env.step(action)
        
        # Dense reward shaping for FetchReach
        reward = -np.linalg.norm(next_obs_dict["achieved_goal"] - next_obs_dict["desired_goal"])
        
        buffer.push(current_obs, action, reward, next_obs_dict["observation"], done or truncated)
        current_obs = next_obs_dict["observation"]
        if done or truncated:
            obs_dict, _ = env.reset()
            current_obs = obs_dict["observation"]
    print("Buffer prefill complete.")

    # Reset environment and agent state for training phase
    obs_dict, _ = env.reset()
    current_obs = obs_dict["observation"]
    agent_gru_state = torch.zeros(1, config["hidden_dim"]).to(config["device"]) # Agent's recurrent state h_{t-1}
    prev_action_tensor = torch.zeros(1, act_dim).to(config["device"])         # Agent's previous action a_{t-1}
    
    total_episodes_done = 0
    current_episode_reward = 0
    total_env_steps = 0

    for step in range(config["steps"]):
        total_env_steps +=1
        obs_tensor = torch.tensor(current_obs, dtype=torch.float32).unsqueeze(0).to(config["device"])

        with torch.no_grad():
            current_obs_embedding = wm.encode_obs(obs_tensor) # e_t = Enc(s_t)
            # Update agent's GRU state: h_t = GRU(cat(e_t, a_{t-1}), h_{t-1})
            # WorldModel.forward takes (obs_embed, action, prev_gru_state)
            next_agent_gru_state, _ = wm.forward(current_obs_embedding, prev_action_tensor, agent_gru_state)
            # Actor selects action based on current agent state h_t
            action_np = actor(next_agent_gru_state).squeeze(0).cpu().numpy()
        
        agent_gru_state = next_agent_gru_state # Update agent's state for the next step h_t becomes h_{t-1}

        # Interact with environment
        next_obs_dict, env_reward, done, truncated, _ = env.step(action_np)
        next_obs_env = next_obs_dict["observation"]
        
        # Dense reward shaping for FetchReach
        shaped_reward = -np.linalg.norm(next_obs_dict["achieved_goal"] - next_obs_dict["desired_goal"])
        
        buffer.push(current_obs, action_np, shaped_reward, next_obs_env, done or truncated)
        current_episode_reward += shaped_reward # Use shaped reward for learning

        # Prepare for next iteration
        current_obs = next_obs_env
        prev_action_tensor = torch.tensor(action_np, dtype=torch.float32).unsqueeze(0).to(config["device"])

        if done or truncated:
            writer.add_scalar('Reward/EpisodeActual', current_episode_reward, total_episodes_done)
            print(f"Step {step+1}, Episode {total_episodes_done+1}: Total Reward = {current_episode_reward:.2f}")
            current_episode_reward = 0
            total_episodes_done += 1
            
            obs_dict, _ = env.reset()
            current_obs = obs_dict["observation"]
            agent_gru_state = torch.zeros(1, config["hidden_dim"]).to(config["device"]) # Reset GRU state
            prev_action_tensor = torch.zeros(1, act_dim).to(config["device"])    # Reset prev_action

        if len(buffer) < config["batch_size"]: # Wait for enough samples for a batch
            continue

        # --- Training Phase ---
        # Sample a batch from replay buffer
        obs_b, act_b, rew_b, next_obs_b, done_b = buffer.sample(config["batch_size"])

        # 1. Train World Model
        if total_env_steps % config["world_model_update_freq"] == 0:
            optim_wm.zero_grad()
            
            # Encode current observations from batch: e_t = Enc(s_t)
            obs_embed_b = wm.encode_obs(obs_b)
            # For GRU, h_{t-1} for the batch. Using zeros as initial state for one-step predictions.
            initial_gru_state_batch = torch.zeros(config["batch_size"], config["hidden_dim"], device=config["device"])
            
            # Predict next latent state and reward: h_t_pred, r_t_pred = WM(e_t, a_t, h_{t-1}=0)
            h_t_pred_from_dynamics, pred_reward_batch = wm.forward(obs_embed_b, act_b, initial_gru_state_batch)

            # Reward prediction loss
            loss_wm_rew = F.mse_loss(pred_reward_batch, rew_b)

            # Dynamics prediction loss: predict embedding of next observation
            with torch.no_grad():
                target_next_latent_embed = wm.encode_obs(next_obs_b).detach() # e_{t+1} = Enc(s_{t+1})
            loss_wm_dyn = F.mse_loss(h_t_pred_from_dynamics, target_next_latent_embed)
            
            loss_wm = loss_wm_rew + config["dyn_loss_scale"] * loss_wm_dyn
            loss_wm.backward()
            #torch.nn.utils.clip_grad_norm_(wm.parameters(), 100.0) # Optional gradient clipping
            
            torch.nn.utils.clip_grad_norm_(wm.parameters(), 100.0)
            # ...
            torch.nn.utils.clip_grad_norm_(critic.parameters(), 100.0)
            # ...
            torch.nn.utils.clip_grad_norm_(actor.parameters(), 100.0)
            
            # Update world model parameters            
            optim_wm.step()
            
            writer.add_scalar('Loss/WM_Reward', loss_wm_rew.item(), step)
            writer.add_scalar('Loss/WM_Dynamics', loss_wm_dyn.item(), step)
            writer.add_scalar('Loss/WM_Total', loss_wm.item(), step)
            writer.add_scalar('Values/PredReward_Mean_WM', pred_reward_batch.mean().item(), step)

        # Latent state to start imagination from (this is h_t_pred from the world model)
        # Detach because we don't want gradients flowing back to WM from actor/critic losses via this start state.
        start_imag_latent = h_t_pred_from_dynamics.detach()


        # 2. Train Actor and Critic using imagined rollouts
        if total_env_steps % config["actor_critic_update_freq"] == 0:
            # Generate imagined trajectories
            # rollout contains [(h_1, r_1), ..., (h_H, r_H)] where H is imag_horizon
            rollout = imagine_rollout(actor, wm, start_imag_latent, config["imag_horizon"])
            
            # Unpack imagined latents and rewards
            # imag_latents: (H, batch_size, hidden_dim) -> h_1, ..., h_H
            # imag_rewards: (H, batch_size, 1)       -> r_1, ..., r_H
            imag_latents, imag_rewards = zip(*rollout)
            imag_latents = torch.stack(imag_latents) 
            imag_rewards = torch.stack(imag_rewards)

            # Calculate value targets (lambda-returns or GAE-style) for critic
            # Here using N-step bootstrapped returns: R_t = r_t + gamma * R_{t+1}, with R_H = V_critic(h_H)
            value_targets = torch.zeros_like(imag_rewards)
            with torch.no_grad():
                # Bootstrap value for the very last state of the horizon V(h_H)
                last_imag_state_value = critic(imag_latents[-1]) # V(h_H)

            # Calculate targets iteratively from H-1 down to 0
            # V_target(h_k) = r_k + gamma * V_target(h_{k+1})
            # V_target(h_H) = r_H + gamma * V_critic(h_H) (adjusting this for typical Bellman)
            # Let value_targets[k] be the target for critic(imag_latents[k])
            
            next_value_target = last_imag_state_value
            for t in reversed(range(config["imag_horizon"])):
                if t == config["imag_horizon"] - 1: # For V(h_H)
                    value_targets[t] = imag_rewards[t] + config["gamma"] * (1.0 - 0.0) * next_value_target # No (1-done) in imagination
                else: # For V(h_k), k < H
                    value_targets[t] = imag_rewards[t] + config["gamma"] * (1.0 - 0.0) * value_targets[t+1]
            
            # Critic Update
            # Predicted values V(h_k) for all imagined states by current critic
            # Note: imag_latents are already detached from WM graph for actor/critic training
            # if start_imag_latent was detached. However, gradients need to flow through actor for its update.
            # For critic loss, detach imag_latents to ensure targets are fixed.
            value_preds_critic = critic(imag_latents.detach()) # V_current(h_k)
            loss_critic = F.mse_loss(value_preds_critic, value_targets.detach())
            
            optim_critic.zero_grad()
            loss_critic.backward()
            #torch.nn.utils.clip_grad_norm_(critic.parameters(), 100.0) # Optional
            optim_critic.step()
            writer.add_scalar('Loss/Critic', loss_critic.item(), step)

            # Actor Update
            # Re-evaluate value predictions with current critic, allowing gradients to flow back to actor
            # The actor's actions influenced imag_latents through the (fixed for this update) world model.
            # We want to update actor to produce actions leading to high-value latents.
            value_preds_actor = critic(imag_latents) # Gradients will flow through imag_latents to actor
            loss_actor = -value_preds_actor.mean() # Maximize the mean predicted value of imagined states

            optim_actor.zero_grad()
            loss_actor.backward()
            #torch.nn.utils.clip_grad_norm_(actor.parameters(), 100.0) # Optional
            optim_actor.step()
            writer.add_scalar('Loss/Actor', loss_actor.item(), step)
            writer.add_scalar('Values/ImaginedReturn_Mean', value_targets.mean().item(), step)


        if (step + 1) % config["log_every"] == 0:
            print(f"--- Training Step {step+1}/{config['steps']} ---")
            if 'loss_wm' in locals(): # Check if WM was updated in this step block
                 print(f"  WM Losses: Reward={loss_wm_rew.item():.4f}, Dynamics={loss_wm_dyn.item():.4f}, Total={loss_wm.item():.4f}")
            if 'loss_critic' in locals():
                 print(f"  Actor-Critic Losses: Critic={loss_critic.item():.4f}, Actor={loss_actor.item():.4f}")
            print(f"  Buffer Size: {len(buffer)}")
            # Log average action magnitudes if desired
            writer.add_scalar('Params/ActionNorm_Mean', torch.norm(prev_action_tensor, p=2).item(), step)


    env.close()
    writer.close()
    print("Training complete.")

if __name__ == "__main__":
    train()
# Out:
# Prefilling buffer with 1000 random steps...
# Buffer prefill complete.
# Step 50, Episode 1: Total Reward = -28.20
# Step 100, Episode 2: Total Reward = -23.74
# Step 150, Episode 3: Total Reward = -29.36
# Step 200, Episode 4: Total Reward = -22.25
# Step 250, Episode 5: Total Reward = -29.98
# Step 300, Episode 6: Total Reward = -32.52
# Step 350, Episode 7: Total Reward = -18.45
# Step 400, Episode 8: Total Reward = -22.38
# Step 450, Episode 9: Total Reward = -27.04
# Step 500, Episode 10: Total Reward = -21.68
# Step 550, Episode 11: Total Reward = -22.06
# Step 600, Episode 12: Total Reward = -33.06
# Step 650, Episode 13: Total Reward = -30.31
# Step 700, Episode 14: Total Reward = -27.18
# Step 750, Episode 15: Total Reward = -29.82
# Step 800, Episode 16: Total Reward = -21.21
# Step 850, Episode 17: Total Reward = -28.49
# Step 900, Episode 18: Total Reward = -25.43
# Step 950, Episode 19: Total Reward = -29.98
# Step 1000, Episode 20: Total Reward = -19.15
# --- Training Step 1000/20000 ---
#   WM Losses: Reward=0.0064, Dynamics=0.0005, Total=0.0067
#   Actor-Critic Losses: Critic=2172277.5000, Actor=6632.5117
#   Buffer Size: 2000
# Step 1050, Episode 21: Total Reward = -22.60
# Step 1100, Episode 22: Total Reward = -22.34
# Step 1150, Episode 23: Total Reward = -26.02
# Step 1200, Episode 24: Total Reward = -33.98
# Step 1250, Episode 25: Total Reward = -24.08
# Step 1300, Episode 26: Total Reward = -34.09
# Step 1350, Episode 27: Total Reward = -25.57
# Step 1400, Episode 28: Total Reward = -29.86
# Step 1450, Episode 29: Total Reward = -36.41
# Step 1500, Episode 30: Total Reward = -22.41
# Step 1550, Episode 31: Total Reward = -29.23
# Step 1600, Episode 32: Total Reward = -23.32
# Step 1650, Episode 33: Total Reward = -20.67
# Step 1700, Episode 34: Total Reward = -31.81
# Step 1750, Episode 35: Total Reward = -34.82
# Step 1800, Episode 36: Total Reward = -23.92
# Step 1850, Episode 37: Total Reward = -21.22
# Step 1900, Episode 38: Total Reward = -35.37
# Step 1950, Episode 39: Total Reward = -35.26
# Step 2000, Episode 40: Total Reward = -31.06
# --- Training Step 2000/20000 ---
#   WM Losses: Reward=0.0116, Dynamics=0.0003, Total=0.0117
#   Actor-Critic Losses: Critic=6055.3525, Actor=972.1788
#   Buffer Size: 3000
# Step 2050, Episode 41: Total Reward = -21.28
# Step 2100, Episode 42: Total Reward = -34.72
# Step 2150, Episode 43: Total Reward = -33.52
# Step 2200, Episode 44: Total Reward = -28.05
# Step 2250, Episode 45: Total Reward = -23.92
# Step 2300, Episode 46: Total Reward = -32.16
# Step 2350, Episode 47: Total Reward = -25.49
# Step 2400, Episode 48: Total Reward = -23.82
# Step 2450, Episode 49: Total Reward = -31.34
# Step 2500, Episode 50: Total Reward = -31.90
# Step 2550, Episode 51: Total Reward = -20.99
# Step 2600, Episode 52: Total Reward = -25.04
# Step 2650, Episode 53: Total Reward = -35.85
# Step 2700, Episode 54: Total Reward = -24.17
# Step 2750, Episode 55: Total Reward = -25.43
# Step 2800, Episode 56: Total Reward = -34.25
# Step 2850, Episode 57: Total Reward = -34.44
# Step 2900, Episode 58: Total Reward = -25.52
# Step 2950, Episode 59: Total Reward = -34.67
# Step 3000, Episode 60: Total Reward = -28.99
# --- Training Step 3000/20000 ---
#   WM Losses: Reward=0.0076, Dynamics=0.0002, Total=0.0077
#   Actor-Critic Losses: Critic=806.1107, Actor=311.0137
#   Buffer Size: 4000
# Step 3050, Episode 61: Total Reward = -27.83
# Step 3100, Episode 62: Total Reward = -29.31
# Step 3150, Episode 63: Total Reward = -25.78
# Step 3200, Episode 64: Total Reward = -35.16
# Step 3250, Episode 65: Total Reward = -30.27
# Step 3300, Episode 66: Total Reward = -28.93
# Step 3350, Episode 67: Total Reward = -27.03
# Step 3400, Episode 68: Total Reward = -24.94
# Step 3450, Episode 69: Total Reward = -25.36
# Step 3500, Episode 70: Total Reward = -31.35
# Step 3550, Episode 71: Total Reward = -26.88
# Step 3600, Episode 72: Total Reward = -25.75
# Step 3650, Episode 73: Total Reward = -23.61
# Step 3700, Episode 74: Total Reward = -22.26
# Step 3750, Episode 75: Total Reward = -21.86
# Step 3800, Episode 76: Total Reward = -35.09
# Step 3850, Episode 77: Total Reward = -34.58
# Step 3900, Episode 78: Total Reward = -32.94
# Step 3950, Episode 79: Total Reward = -24.51
# Step 4000, Episode 80: Total Reward = -33.31
# --- Training Step 4000/20000 ---
#   WM Losses: Reward=0.0100, Dynamics=0.0002, Total=0.0101
#   Actor-Critic Losses: Critic=300.2143, Actor=238.5348
#   Buffer Size: 5000
# Step 4050, Episode 81: Total Reward = -30.68
# Step 4100, Episode 82: Total Reward = -27.32
# Step 4150, Episode 83: Total Reward = -26.11
# Step 4200, Episode 84: Total Reward = -25.34
# Step 4250, Episode 85: Total Reward = -33.37
# Step 4300, Episode 86: Total Reward = -25.53
# Step 4350, Episode 87: Total Reward = -31.21
# Step 4400, Episode 88: Total Reward = -30.93
# Step 4450, Episode 89: Total Reward = -24.63
# Step 4500, Episode 90: Total Reward = -24.79
# Step 4550, Episode 91: Total Reward = -32.43
# Step 4600, Episode 92: Total Reward = -24.93
# Step 4650, Episode 93: Total Reward = -30.15
# Step 4700, Episode 94: Total Reward = -36.41
# Step 4750, Episode 95: Total Reward = -22.58
# Step 4800, Episode 96: Total Reward = -28.05
# Step 4850, Episode 97: Total Reward = -27.67
# Step 4900, Episode 98: Total Reward = -29.11
# Step 4950, Episode 99: Total Reward = -27.60
# Step 5000, Episode 100: Total Reward = -29.85
# --- Training Step 5000/20000 ---
#   WM Losses: Reward=0.0084, Dynamics=0.0001, Total=0.0085
#   Actor-Critic Losses: Critic=989.0107, Actor=-12.4054
#   Buffer Size: 6000
# Step 5050, Episode 101: Total Reward = -32.28
# Step 5100, Episode 102: Total Reward = -34.42
# Step 5150, Episode 103: Total Reward = -26.87
# Step 5200, Episode 104: Total Reward = -33.82
# Step 5250, Episode 105: Total Reward = -30.85
# Step 5300, Episode 106: Total Reward = -34.10
# Step 5350, Episode 107: Total Reward = -34.23
# Step 5400, Episode 108: Total Reward = -24.86
# Step 5450, Episode 109: Total Reward = -23.28
# Step 5500, Episode 110: Total Reward = -22.72
# Step 5550, Episode 111: Total Reward = -27.15
# Step 5600, Episode 112: Total Reward = -24.29
# Step 5650, Episode 113: Total Reward = -23.45
# Step 5700, Episode 114: Total Reward = -26.43
# Step 5750, Episode 115: Total Reward = -34.15
# Step 5800, Episode 116: Total Reward = -22.34
# Step 5850, Episode 117: Total Reward = -25.55
# Step 5900, Episode 118: Total Reward = -23.20
# Step 5950, Episode 119: Total Reward = -23.06
# Step 6000, Episode 120: Total Reward = -24.39
# --- Training Step 6000/20000 ---
#   WM Losses: Reward=0.0083, Dynamics=0.0001, Total=0.0084
#   Actor-Critic Losses: Critic=39106.0352, Actor=-1154.2626
#   Buffer Size: 7000
# Step 6050, Episode 121: Total Reward = -30.94
# Step 6100, Episode 122: Total Reward = -31.35
# Step 6150, Episode 123: Total Reward = -32.32
# Step 6200, Episode 124: Total Reward = -20.92
# Step 6250, Episode 125: Total Reward = -30.29
# Step 6300, Episode 126: Total Reward = -33.28
# Step 6350, Episode 127: Total Reward = -29.90
# Step 6400, Episode 128: Total Reward = -23.20
# Step 6450, Episode 129: Total Reward = -32.83
# Step 6500, Episode 130: Total Reward = -25.44
# Step 6550, Episode 131: Total Reward = -27.78
# Step 6600, Episode 132: Total Reward = -28.49
# Step 6650, Episode 133: Total Reward = -25.33
# Step 6700, Episode 134: Total Reward = -27.29
# Step 6750, Episode 135: Total Reward = -24.30
# Step 6800, Episode 136: Total Reward = -21.91
# Step 6850, Episode 137: Total Reward = -21.54
# Step 6900, Episode 138: Total Reward = -27.33
# Step 6950, Episode 139: Total Reward = -20.08
# Step 7000, Episode 140: Total Reward = -18.16
# --- Training Step 7000/20000 ---
#   WM Losses: Reward=0.0089, Dynamics=0.0001, Total=0.0089
#   Actor-Critic Losses: Critic=10596.6885, Actor=-548.6630
#   Buffer Size: 8000
# Step 7050, Episode 141: Total Reward = -20.54
# Step 7100, Episode 142: Total Reward = -27.26
# Step 7150, Episode 143: Total Reward = -22.18
# Step 7200, Episode 144: Total Reward = -23.50
# Step 7250, Episode 145: Total Reward = -23.63
# Step 7300, Episode 146: Total Reward = -32.29
# Step 7350, Episode 147: Total Reward = -29.59
# Step 7400, Episode 148: Total Reward = -28.38
# Step 7450, Episode 149: Total Reward = -30.69
# Step 7500, Episode 150: Total Reward = -23.50
# Step 7550, Episode 151: Total Reward = -29.94
# Step 7600, Episode 152: Total Reward = -31.54
# Step 7650, Episode 153: Total Reward = -27.11
# Step 7700, Episode 154: Total Reward = -29.98
# Step 7750, Episode 155: Total Reward = -23.10
# Step 7800, Episode 156: Total Reward = -23.76
# Step 7850, Episode 157: Total Reward = -19.38
# Step 7900, Episode 158: Total Reward = -18.01
# Step 7950, Episode 159: Total Reward = -27.58
# Step 8000, Episode 160: Total Reward = -23.70
# --- Training Step 8000/20000 ---
#   WM Losses: Reward=0.0080, Dynamics=0.0001, Total=0.0080
#   Actor-Critic Losses: Critic=217.1323, Actor=-61.8444
#   Buffer Size: 9000
# Step 8050, Episode 161: Total Reward = -17.65
# Step 8100, Episode 162: Total Reward = -25.83
# Step 8150, Episode 163: Total Reward = -31.72
# Step 8200, Episode 164: Total Reward = -20.94
# Step 8250, Episode 165: Total Reward = -27.20
# Step 8300, Episode 166: Total Reward = -28.34
# Step 8350, Episode 167: Total Reward = -27.00
# Step 8400, Episode 168: Total Reward = -21.55
# Step 8450, Episode 169: Total Reward = -28.98
# Step 8500, Episode 170: Total Reward = -30.69
# Step 8550, Episode 171: Total Reward = -27.39
# Step 8600, Episode 172: Total Reward = -23.93
# Step 8650, Episode 173: Total Reward = -21.29
# Step 8700, Episode 174: Total Reward = -21.95
# Step 8750, Episode 175: Total Reward = -16.00
# Step 8800, Episode 176: Total Reward = -21.44
# Step 8850, Episode 177: Total Reward = -19.75
# Step 8900, Episode 178: Total Reward = -31.54
# Step 8950, Episode 179: Total Reward = -27.44
# Step 9000, Episode 180: Total Reward = -31.41
# --- Training Step 9000/20000 ---
#   WM Losses: Reward=0.0077, Dynamics=0.0001, Total=0.0078
#   Actor-Critic Losses: Critic=10861.6230, Actor=-849.5841
#   Buffer Size: 10000
# Step 9050, Episode 181: Total Reward = -21.34
# Step 9100, Episode 182: Total Reward = -24.65
# Step 9150, Episode 183: Total Reward = -34.39
# Step 9200, Episode 184: Total Reward = -29.74
# Step 9250, Episode 185: Total Reward = -16.23
# Step 9300, Episode 186: Total Reward = -31.47
# Step 9350, Episode 187: Total Reward = -25.74
# Step 9400, Episode 188: Total Reward = -23.66
# Step 9450, Episode 189: Total Reward = -33.38
# Step 9500, Episode 190: Total Reward = -22.94
# Step 9550, Episode 191: Total Reward = -28.34
# Step 9600, Episode 192: Total Reward = -30.32
# Step 9650, Episode 193: Total Reward = -23.90
# Step 9700, Episode 194: Total Reward = -24.82
# Step 9750, Episode 195: Total Reward = -24.61
# Step 9800, Episode 196: Total Reward = -34.69
# Step 9850, Episode 197: Total Reward = -27.57
# Step 9900, Episode 198: Total Reward = -30.32
# Step 9950, Episode 199: Total Reward = -35.53
# Step 10000, Episode 200: Total Reward = -24.99
# --- Training Step 10000/20000 ---
#   WM Losses: Reward=0.0074, Dynamics=0.0001, Total=0.0074
#   Actor-Critic Losses: Critic=754.6547, Actor=-174.0240
#   Buffer Size: 11000
# Step 10050, Episode 201: Total Reward = -38.12
# Step 10100, Episode 202: Total Reward = -23.54
# Step 10150, Episode 203: Total Reward = -33.93
# Step 10200, Episode 204: Total Reward = -34.54
# Step 10250, Episode 205: Total Reward = -29.47
# Step 10300, Episode 206: Total Reward = -22.19
# Step 10350, Episode 207: Total Reward = -28.09
# Step 10400, Episode 208: Total Reward = -34.56
# Step 10450, Episode 209: Total Reward = -35.40
# Step 10500, Episode 210: Total Reward = -34.16
# Step 10550, Episode 211: Total Reward = -30.76
# Step 10600, Episode 212: Total Reward = -26.13
# Step 10650, Episode 213: Total Reward = -31.32
# Step 10700, Episode 214: Total Reward = -29.02
# Step 10750, Episode 215: Total Reward = -23.43
# Step 10800, Episode 216: Total Reward = -29.41
# Step 10850, Episode 217: Total Reward = -23.32
# Step 10900, Episode 218: Total Reward = -25.20
# Step 10950, Episode 219: Total Reward = -28.52
# Step 11000, Episode 220: Total Reward = -27.74
# --- Training Step 11000/20000 ---
#   WM Losses: Reward=0.0072, Dynamics=0.0001, Total=0.0072
#   Actor-Critic Losses: Critic=597.0820, Actor=303.3786
#   Buffer Size: 12000
# Step 11050, Episode 221: Total Reward = -19.78
# Step 11100, Episode 222: Total Reward = -27.07
# Step 11150, Episode 223: Total Reward = -26.74
# Step 11200, Episode 224: Total Reward = -24.73
# Step 11250, Episode 225: Total Reward = -28.23
# Step 11300, Episode 226: Total Reward = -33.05
# Step 11350, Episode 227: Total Reward = -26.83
# Step 11400, Episode 228: Total Reward = -28.03
# Step 11450, Episode 229: Total Reward = -24.64
# Step 11500, Episode 230: Total Reward = -29.87
# Step 11550, Episode 231: Total Reward = -33.87
# Step 11600, Episode 232: Total Reward = -30.71
# Step 11650, Episode 233: Total Reward = -17.80
# Step 11700, Episode 234: Total Reward = -24.79
# Step 11750, Episode 235: Total Reward = -28.13
# Step 11800, Episode 236: Total Reward = -25.91
# Step 11850, Episode 237: Total Reward = -29.09
# Step 11900, Episode 238: Total Reward = -27.24
# Step 11950, Episode 239: Total Reward = -31.01
# Step 12000, Episode 240: Total Reward = -33.43
# --- Training Step 12000/20000 ---
#   WM Losses: Reward=0.0071, Dynamics=0.0001, Total=0.0071
#   Actor-Critic Losses: Critic=136.3461, Actor=58.2278
#   Buffer Size: 13000
# Step 12050, Episode 241: Total Reward = -24.01
# Step 12100, Episode 242: Total Reward = -23.41
# Step 12150, Episode 243: Total Reward = -24.11
# Step 12200, Episode 244: Total Reward = -22.21
# Step 12250, Episode 245: Total Reward = -28.66
# Step 12300, Episode 246: Total Reward = -30.09
# Step 12350, Episode 247: Total Reward = -18.89
# Step 12400, Episode 248: Total Reward = -23.22
# Step 12450, Episode 249: Total Reward = -16.15
# Step 12500, Episode 250: Total Reward = -20.83
# Step 12550, Episode 251: Total Reward = -29.05
# Step 12600, Episode 252: Total Reward = -19.59
# Step 12650, Episode 253: Total Reward = -26.57
# Step 12700, Episode 254: Total Reward = -28.32
# Step 12750, Episode 255: Total Reward = -25.89
# Step 12800, Episode 256: Total Reward = -24.64
# Step 12850, Episode 257: Total Reward = -27.11
# Step 12900, Episode 258: Total Reward = -29.03
# Step 12950, Episode 259: Total Reward = -29.09
# Step 13000, Episode 260: Total Reward = -19.19
# --- Training Step 13000/20000 ---
#   WM Losses: Reward=0.0079, Dynamics=0.0001, Total=0.0079
#   Actor-Critic Losses: Critic=52.9218, Actor=193.9173
#   Buffer Size: 14000
# Step 13050, Episode 261: Total Reward = -30.95
# Step 13100, Episode 262: Total Reward = -28.53
# Step 13150, Episode 263: Total Reward = -35.67
# Step 13200, Episode 264: Total Reward = -28.16
# Step 13250, Episode 265: Total Reward = -25.25
# Step 13300, Episode 266: Total Reward = -31.35
# Step 13350, Episode 267: Total Reward = -29.41
# Step 13400, Episode 268: Total Reward = -26.47
# Step 13450, Episode 269: Total Reward = -20.77
# Step 13500, Episode 270: Total Reward = -27.53
# Step 13550, Episode 271: Total Reward = -23.35
# Step 13600, Episode 272: Total Reward = -25.58
# Step 13650, Episode 273: Total Reward = -31.27
# Step 13700, Episode 274: Total Reward = -27.68
# Step 13750, Episode 275: Total Reward = -28.94
# Step 13800, Episode 276: Total Reward = -29.52
# Step 13850, Episode 277: Total Reward = -33.45
# Step 13900, Episode 278: Total Reward = -20.81
# Step 13950, Episode 279: Total Reward = -26.95
# Step 14000, Episode 280: Total Reward = -31.79
# --- Training Step 14000/20000 ---
#   WM Losses: Reward=0.0079, Dynamics=0.0001, Total=0.0080
#   Actor-Critic Losses: Critic=54.5044, Actor=338.1797
#   Buffer Size: 15000
# Step 14050, Episode 281: Total Reward = -23.93
# Step 14100, Episode 282: Total Reward = -27.48
# Step 14150, Episode 283: Total Reward = -33.84
# Step 14200, Episode 284: Total Reward = -27.90
# Step 14250, Episode 285: Total Reward = -29.09
# Step 14300, Episode 286: Total Reward = -29.12
# Step 14350, Episode 287: Total Reward = -24.53
# Step 14400, Episode 288: Total Reward = -28.30
# Step 14450, Episode 289: Total Reward = -24.76
# Step 14500, Episode 290: Total Reward = -32.52
# Step 14550, Episode 291: Total Reward = -22.50
# Step 14600, Episode 292: Total Reward = -20.35
# Step 14650, Episode 293: Total Reward = -24.75
# Step 14700, Episode 294: Total Reward = -27.03
# Step 14750, Episode 295: Total Reward = -27.26
# Step 14800, Episode 296: Total Reward = -24.60
# Step 14850, Episode 297: Total Reward = -32.26
# Step 14900, Episode 298: Total Reward = -26.63
# Step 14950, Episode 299: Total Reward = -28.87
# Step 15000, Episode 300: Total Reward = -31.62
# --- Training Step 15000/20000 ---
#   WM Losses: Reward=0.0091, Dynamics=0.0001, Total=0.0091
#   Actor-Critic Losses: Critic=672.7007, Actor=539.9656
#   Buffer Size: 16000
# Step 15050, Episode 301: Total Reward = -25.96
# Step 15100, Episode 302: Total Reward = -26.50
# Step 15150, Episode 303: Total Reward = -32.03
# Step 15200, Episode 304: Total Reward = -27.62
# Step 15250, Episode 305: Total Reward = -20.99
# Step 15300, Episode 306: Total Reward = -31.88
# Step 15350, Episode 307: Total Reward = -32.03
# Step 15400, Episode 308: Total Reward = -21.56
# Step 15450, Episode 309: Total Reward = -29.43
# Step 15500, Episode 310: Total Reward = -31.65
# Step 15550, Episode 311: Total Reward = -19.57
# Step 15600, Episode 312: Total Reward = -20.79
# Step 15650, Episode 313: Total Reward = -20.07
# Step 15700, Episode 314: Total Reward = -32.85
# Step 15750, Episode 315: Total Reward = -26.90
# Step 15800, Episode 316: Total Reward = -25.20
# Step 15850, Episode 317: Total Reward = -20.96
# Step 15900, Episode 318: Total Reward = -24.44
# Step 15950, Episode 319: Total Reward = -30.73
# Step 16000, Episode 320: Total Reward = -30.21
# --- Training Step 16000/20000 ---
#   WM Losses: Reward=0.0091, Dynamics=0.0001, Total=0.0091
#   Actor-Critic Losses: Critic=83.0377, Actor=472.9676
#   Buffer Size: 17000
# Step 16050, Episode 321: Total Reward = -27.21
# Step 16100, Episode 322: Total Reward = -26.05
# Step 16150, Episode 323: Total Reward = -32.54
# Step 16200, Episode 324: Total Reward = -26.38
# Step 16250, Episode 325: Total Reward = -25.50
# Step 16300, Episode 326: Total Reward = -28.93
# Step 16350, Episode 327: Total Reward = -25.34
# Step 16400, Episode 328: Total Reward = -34.35
# Step 16450, Episode 329: Total Reward = -25.24
# Step 16500, Episode 330: Total Reward = -21.55
# Step 16550, Episode 331: Total Reward = -26.04
# Step 16600, Episode 332: Total Reward = -33.21
# Step 16650, Episode 333: Total Reward = -28.55
# Step 16700, Episode 334: Total Reward = -28.04
# Step 16750, Episode 335: Total Reward = -22.02
# Step 16800, Episode 336: Total Reward = -24.93
# Step 16850, Episode 337: Total Reward = -26.83
# Step 16900, Episode 338: Total Reward = -29.45
# Step 16950, Episode 339: Total Reward = -29.73
# Step 17000, Episode 340: Total Reward = -33.91
# --- Training Step 17000/20000 ---
#   WM Losses: Reward=0.0076, Dynamics=0.0001, Total=0.0076
#   Actor-Critic Losses: Critic=1569.8822, Actor=207.0457
#   Buffer Size: 18000
# Step 17050, Episode 341: Total Reward = -31.73
# Step 17100, Episode 342: Total Reward = -22.54
# Step 17150, Episode 343: Total Reward = -22.27
# Step 17200, Episode 344: Total Reward = -21.18
# Step 17250, Episode 345: Total Reward = -29.33
# Step 17300, Episode 346: Total Reward = -28.60
# Step 17350, Episode 347: Total Reward = -31.65
# Step 17400, Episode 348: Total Reward = -34.63
# Step 17450, Episode 349: Total Reward = -23.75
# Step 17500, Episode 350: Total Reward = -37.87
# Step 17550, Episode 351: Total Reward = -30.73
# Step 17600, Episode 352: Total Reward = -33.64
# Step 17650, Episode 353: Total Reward = -25.85
# Step 17700, Episode 354: Total Reward = -26.16
# Step 17750, Episode 355: Total Reward = -32.41
# Step 17800, Episode 356: Total Reward = -20.72
# Step 17850, Episode 357: Total Reward = -28.29
# Step 17900, Episode 358: Total Reward = -19.92
# Step 17950, Episode 359: Total Reward = -28.54
# Step 18000, Episode 360: Total Reward = -29.00
# --- Training Step 18000/20000 ---
#   WM Losses: Reward=0.0099, Dynamics=0.0000, Total=0.0099
#   Actor-Critic Losses: Critic=87.1023, Actor=638.3253
#   Buffer Size: 19000
# Step 18050, Episode 361: Total Reward = -32.06
# Step 18100, Episode 362: Total Reward = -23.76
# Step 18150, Episode 363: Total Reward = -20.66
# Step 18200, Episode 364: Total Reward = -24.46
# Step 18250, Episode 365: Total Reward = -33.14
# Step 18300, Episode 366: Total Reward = -33.71
# Step 18350, Episode 367: Total Reward = -28.99
# Step 18400, Episode 368: Total Reward = -33.66
# Step 18450, Episode 369: Total Reward = -30.89
# Step 18500, Episode 370: Total Reward = -27.24
# Step 18550, Episode 371: Total Reward = -27.05
# Step 18600, Episode 372: Total Reward = -31.49
# Step 18650, Episode 373: Total Reward = -23.96
# Step 18700, Episode 374: Total Reward = -25.81
# Step 18750, Episode 375: Total Reward = -27.78
# Step 18800, Episode 376: Total Reward = -29.60
# Step 18850, Episode 377: Total Reward = -27.83
# Step 18900, Episode 378: Total Reward = -23.93
# Step 18950, Episode 379: Total Reward = -25.59
# Step 19000, Episode 380: Total Reward = -24.15
# --- Training Step 19000/20000 ---
#   WM Losses: Reward=0.0072, Dynamics=0.0000, Total=0.0072
#   Actor-Critic Losses: Critic=134.0530, Actor=288.4243
#   Buffer Size: 20000
# Step 19050, Episode 381: Total Reward = -26.97
# Step 19100, Episode 382: Total Reward = -27.74
# Step 19150, Episode 383: Total Reward = -25.45
# Step 19200, Episode 384: Total Reward = -22.87
# Step 19250, Episode 385: Total Reward = -24.70
# Step 19300, Episode 386: Total Reward = -29.34
# Step 19350, Episode 387: Total Reward = -29.72
# Step 19400, Episode 388: Total Reward = -33.27
# Step 19450, Episode 389: Total Reward = -27.01
# Step 19500, Episode 390: Total Reward = -25.42
# Step 19550, Episode 391: Total Reward = -25.01
# Step 19600, Episode 392: Total Reward = -29.86
# Step 19650, Episode 393: Total Reward = -19.84
# Step 19700, Episode 394: Total Reward = -27.41
# Step 19750, Episode 395: Total Reward = -35.06
# Step 19800, Episode 396: Total Reward = -18.16
# Step 19850, Episode 397: Total Reward = -28.33
# Step 19900, Episode 398: Total Reward = -26.87
# Step 19950, Episode 399: Total Reward = -23.42
# Step 20000, Episode 400: Total Reward = -28.61
# --- Training Step 20000/20000 ---
#   WM Losses: Reward=0.0084, Dynamics=0.0000, Total=0.0084
#   Actor-Critic Losses: Critic=970.1147, Actor=-195.4685
#   Buffer Size: 21000
# Training complete.

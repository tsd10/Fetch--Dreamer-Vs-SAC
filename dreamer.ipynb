# %%
# DreamerV3-style RL agent for FetchReach-v3 with dense reward shaping

import os
import gymnasium as gym
import gymnasium_robotics
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import deque
import random

config = {
    "env_name": "FetchReach-v3",
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "steps": 20000,
    "hidden_dim": 256,
    "log_every": 1000,
    "imag_horizon": 15,
    "batch_size": 32,
    "buffer_size": 100000,
    "prefill_steps": 1000,
    "gamma": 0.99,
    "learning_rate": 3e-4,
    "action_scale": 0.05,
}

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, obs, action, reward, next_obs, done):
        self.buffer.append((obs, action, reward, next_obs, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        obs, act, rew, next_obs, done = map(np.stack, zip(*batch))
        return (
            torch.tensor(obs, dtype=torch.float32).to(config["device"]),
            torch.tensor(act, dtype=torch.float32).to(config["device"]),
            torch.tensor(rew, dtype=torch.float32).unsqueeze(1).to(config["device"]),
            torch.tensor(next_obs, dtype=torch.float32).to(config["device"]),
            torch.tensor(done, dtype=torch.float32).unsqueeze(1).to(config["device"])
        )

    def __len__(self):
        return len(self.buffer)

class WorldModel(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        self.encoder = nn.Sequential(nn.Linear(obs_dim, config["hidden_dim"]), nn.ReLU())
        self.dynamics = nn.GRUCell(config["hidden_dim"] + act_dim, config["hidden_dim"])
        self.reward_head = nn.Linear(config["hidden_dim"], 1)

    def forward(self, obs, action, hidden):
        emb = self.encoder(obs)
        return self.forward_through_dynamics(emb, action, hidden)

    def forward_through_dynamics(self, emb, action, hidden):
        hidden = self.dynamics(torch.cat([emb, action], dim=-1), hidden)
        reward = self.reward_head(hidden)
        return hidden, reward

class Actor(nn.Module):
    def __init__(self, feat_dim, act_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], act_dim),
            nn.Tanh()
        )
        self.action_scale = torch.tensor(config["action_scale"])

    def forward(self, feat):
        return self.action_scale.to(feat.device) * self.net(feat)

class Critic(nn.Module):
    def __init__(self, feat_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], 1)
        )

    def forward(self, feat):
        return self.net(feat)

def imagine_rollout(actor, world_model, start_hidden, horizon):
    imag_feats = []
    hidden = start_hidden
    for _ in range(horizon):
        action = actor(hidden)
        emb_dummy = torch.zeros_like(hidden)
        hidden, reward = world_model.forward_through_dynamics(emb_dummy, action, hidden)
        imag_feats.append((hidden, reward))
    return imag_feats

def make_env():
    env = gym.make(config["env_name"])
    env.reset(seed=42)
    return env

def train():
    env = make_env()
    obs_dim = env.observation_space["observation"].shape[0]
    act_dim = env.action_space.shape[0]

    buffer = ReplayBuffer(config["buffer_size"])
    wm = WorldModel(obs_dim, act_dim).to(config["device"])
    actor = Actor(config["hidden_dim"], act_dim).to(config["device"])
    critic = Critic(config["hidden_dim"]).to(config["device"])

    optim_wm = torch.optim.Adam(wm.parameters(), lr=config["learning_rate"])
    optim_actor = torch.optim.Adam(actor.parameters(), lr=config["learning_rate"])
    optim_critic = torch.optim.Adam(critic.parameters(), lr=config["learning_rate"])

    obs_dict, _ = env.reset()
    obs = obs_dict["observation"]
    total_reward = 0

    for _ in range(config["prefill_steps"]):
        action = env.action_space.sample()
        next_obs_dict, _, done, truncated, _ = env.step(action)
        next_obs = next_obs_dict["observation"]
        reward = -np.linalg.norm(next_obs_dict["achieved_goal"] - next_obs_dict["desired_goal"])
        buffer.push(obs, action, reward, next_obs, done or truncated)
        obs = next_obs if not done and not truncated else env.reset()[0]["observation"]

    obs_dict, _ = env.reset()
    obs = obs_dict["observation"]
    hidden = torch.zeros(config["batch_size"], config["hidden_dim"]).to(config["device"])

    for step in range(config["steps"]):
        obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0).to(config["device"])
        with torch.no_grad():
            emb = wm.encoder(obs_tensor)
            hidden = wm.dynamics(torch.cat([emb, torch.zeros((1, act_dim)).to(config["device"])] , dim=-1), hidden[:1])
            action = actor(hidden).squeeze(0).cpu().numpy()

        next_obs_dict, _, done, truncated, _ = env.step(action)
        next_obs = next_obs_dict["observation"]
        reward = -np.linalg.norm(next_obs_dict["achieved_goal"] - next_obs_dict["desired_goal"])
        buffer.push(obs, action, reward, next_obs, done or truncated)
        total_reward += reward

        obs = next_obs if not done and not truncated else env.reset()[0]["observation"]

        if len(buffer) < config["batch_size"]:
            continue

        obs_b, act_b, rew_b, next_obs_b, done_b = buffer.sample(config["batch_size"])
        hidden = torch.zeros(config["batch_size"], config["hidden_dim"]).to(config["device"])
        next_hidden, pred_reward = wm(obs_b, act_b, hidden)
        loss_wm = F.mse_loss(pred_reward, rew_b)
        optim_wm.zero_grad()
        loss_wm.backward()
        
        optim_wm.step()

        rollout = imagine_rollout(actor, wm, next_hidden.detach(), config["imag_horizon"])
        feats, rewards = zip(*rollout)
        feats = torch.stack(feats)
        rewards = torch.stack(rewards)

        returns = torch.zeros_like(rewards)
        for t in reversed(range(len(rewards))):
            returns[t] = rewards[t] + config["gamma"] * (returns[t + 1] if t + 1 < len(rewards) else 0)

        val_preds = critic(feats.detach())
        loss_critic = F.mse_loss(val_preds.squeeze(-1), returns.detach().squeeze(-1))
        optim_critic.zero_grad()
        loss_critic.backward()
        optim_critic.step()

        val_preds = critic(feats)
        loss_actor = -val_preds.mean()
        optim_actor.zero_grad()
        loss_actor.backward()
        optim_actor.step()

        if (step + 1) % config["log_every"] == 0:
            avg_pred_reward = pred_reward.mean().item()
            print(f"Step {step+1}: Total Reward = {total_reward:.1f}")
            print(f"  Loss_WM: {loss_wm.item():.4f} | Loss_Critic: {loss_critic.item():.4f} | Loss_Actor: {loss_actor.item():.4f} | Pred_Reward_Mean: {avg_pred_reward:.4f}")
            total_reward = 0

    env.close()

if __name__ == "__main__":
    train()
# Out:
# Step 1000: Total Reward = -572.6
#   Loss_WM: 0.0075 | Loss_Critic: 0.0534 | Loss_Actor: 1.0472 | Pred_Reward_Mean: -0.5491
# Step 2000: Total Reward = -582.0
#   Loss_WM: 0.0130 | Loss_Critic: 0.0307 | Loss_Actor: 1.0616 | Pred_Reward_Mean: -0.5435
# Step 3000: Total Reward = -591.1
#   Loss_WM: 0.0077 | Loss_Critic: 0.0224 | Loss_Actor: 1.1358 | Pred_Reward_Mean: -0.5623
# Step 4000: Total Reward = -582.6
#   Loss_WM: 0.0084 | Loss_Critic: 0.0169 | Loss_Actor: 1.1578 | Pred_Reward_Mean: -0.5591
# Step 5000: Total Reward = -584.2
#   Loss_WM: 0.0098 | Loss_Critic: 0.0138 | Loss_Actor: 1.2585 | Pred_Reward_Mean: -0.5931
# Step 6000: Total Reward = -575.8
#   Loss_WM: 0.0084 | Loss_Critic: 0.0127 | Loss_Actor: 1.3253 | Pred_Reward_Mean: -0.5773
# Step 7000: Total Reward = -583.8
#   Loss_WM: 0.0066 | Loss_Critic: 0.0125 | Loss_Actor: 1.3996 | Pred_Reward_Mean: -0.5866
# Step 8000: Total Reward = -598.6
#   Loss_WM: 0.0056 | Loss_Critic: 0.0130 | Loss_Actor: 1.4358 | Pred_Reward_Mean: -0.5762
# Step 9000: Total Reward = -585.1
#   Loss_WM: 0.0099 | Loss_Critic: 0.0087 | Loss_Actor: 1.4605 | Pred_Reward_Mean: -0.5707
# Step 10000: Total Reward = -592.6
#   Loss_WM: 0.0086 | Loss_Critic: 0.0121 | Loss_Actor: 1.5729 | Pred_Reward_Mean: -0.5841
# Step 11000: Total Reward = -609.1
#   Loss_WM: 0.0065 | Loss_Critic: 0.0094 | Loss_Actor: 1.5911 | Pred_Reward_Mean: -0.5800
# Step 12000: Total Reward = -603.8
#   Loss_WM: 0.0092 | Loss_Critic: 0.0123 | Loss_Actor: 1.6049 | Pred_Reward_Mean: -0.5626
# Step 13000: Total Reward = -551.3
#   Loss_WM: 0.0093 | Loss_Critic: 0.0072 | Loss_Actor: 1.6806 | Pred_Reward_Mean: -0.5790
# Step 14000: Total Reward = -628.4
#   Loss_WM: 0.0067 | Loss_Critic: 0.0156 | Loss_Actor: 1.7280 | Pred_Reward_Mean: -0.6005
# Step 15000: Total Reward = -617.7
#   Loss_WM: 0.0081 | Loss_Critic: 0.0075 | Loss_Actor: 1.7292 | Pred_Reward_Mean: -0.5887
# Step 16000: Total Reward = -595.0
#   Loss_WM: 0.0088 | Loss_Critic: 0.0069 | Loss_Actor: 1.7887 | Pred_Reward_Mean: -0.5944
# Step 17000: Total Reward = -619.0
#   Loss_WM: 0.0086 | Loss_Critic: 0.0112 | Loss_Actor: 1.7788 | Pred_Reward_Mean: -0.5963
# Step 18000: Total Reward = -621.8
#   Loss_WM: 0.0073 | Loss_Critic: 0.0135 | Loss_Actor: 1.7994 | Pred_Reward_Mean: -0.5858
# Step 19000: Total Reward = -607.0
#   Loss_WM: 0.0074 | Loss_Critic: 0.0101 | Loss_Actor: 1.8666 | Pred_Reward_Mean: -0.5932
# Step 20000: Total Reward = -612.2
#   Loss_WM: 0.0057 | Loss_Critic: 0.0136 | Loss_Actor: 1.8401 | Pred_Reward_Mean: -0.5826

# %%
# DreamerV3-style RL agent for FetchReach-v3 with dense reward shaping

import os
import gymnasium as gym
import gymnasium_robotics
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import deque
import random

config = {
    "env_name": "FetchReach-v3",
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "steps": 20000,
    "hidden_dim": 256,
    "log_every": 1000,
    "imag_horizon": 15,
    "batch_size": 64,
    "buffer_size": 100000,
    "prefill_steps": 1000,
    "gamma": 0.99,
    "learning_rate": 2e-4,
    "action_scale": 0.05,
}

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, obs, action, reward, next_obs, done):
        self.buffer.append((obs, action, reward, next_obs, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        obs, act, rew, next_obs, done = map(np.stack, zip(*batch))
        return (
            torch.tensor(obs, dtype=torch.float32).to(config["device"]),
            torch.tensor(act, dtype=torch.float32).to(config["device"]),
            torch.tensor(rew, dtype=torch.float32).unsqueeze(1).to(config["device"]),
            torch.tensor(next_obs, dtype=torch.float32).to(config["device"]),
            torch.tensor(done, dtype=torch.float32).unsqueeze(1).to(config["device"])
        )

    def __len__(self):
        return len(self.buffer)

class WorldModel(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        self.encoder = nn.Sequential(nn.Linear(obs_dim, config["hidden_dim"]), nn.ReLU())
        self.dynamics = nn.GRUCell(config["hidden_dim"] + act_dim, config["hidden_dim"])
        self.reward_head = nn.Linear(config["hidden_dim"], 1)

    def forward(self, obs, action, hidden):
        emb = self.encoder(obs)
        return self.forward_through_dynamics(emb, action, hidden)

    def forward_through_dynamics(self, emb, action, hidden):
        hidden = self.dynamics(torch.cat([emb, action], dim=-1), hidden)
        reward = self.reward_head(hidden)
        return hidden, reward

class Actor(nn.Module):
    def __init__(self, feat_dim, act_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], act_dim),
            nn.Tanh()
        )
        self.action_scale = torch.tensor(config["action_scale"])

    def forward(self, feat):
        return self.action_scale.to(feat.device) * self.net(feat)

class Critic(nn.Module):
    def __init__(self, feat_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], 1)
        )

    def forward(self, feat):
        return self.net(feat)

def imagine_rollout(actor, world_model, start_hidden, horizon):
    imag_feats = []
    hidden = start_hidden
    for _ in range(horizon):
        action = actor(hidden)
        emb_dummy = torch.zeros_like(hidden)
        hidden, reward = world_model.forward_through_dynamics(emb_dummy, action, hidden)
        imag_feats.append((hidden, reward))
    return imag_feats

def make_env():
    env = gym.make(config["env_name"])
    env.reset(seed=42)
    return env

def train():
    env = make_env()
    obs_dim = env.observation_space["observation"].shape[0]
    act_dim = env.action_space.shape[0]

    buffer = ReplayBuffer(config["buffer_size"])
    wm = WorldModel(obs_dim, act_dim).to(config["device"])
    actor = Actor(config["hidden_dim"], act_dim).to(config["device"])
    critic = Critic(config["hidden_dim"]).to(config["device"])

    optim_wm = torch.optim.Adam(wm.parameters(), lr=config["learning_rate"])
    optim_actor = torch.optim.Adam(actor.parameters(), lr=config["learning_rate"])
    optim_critic = torch.optim.Adam(critic.parameters(), lr=config["learning_rate"])

    obs_dict, _ = env.reset()
    obs = obs_dict["observation"]
    total_reward = 0

    for _ in range(config["prefill_steps"]):
        action = env.action_space.sample()
        next_obs_dict, _, done, truncated, _ = env.step(action)
        next_obs = next_obs_dict["observation"]
        reward = -np.linalg.norm(next_obs_dict["achieved_goal"] - next_obs_dict["desired_goal"])
        buffer.push(obs, action, reward, next_obs, done or truncated)
        obs = next_obs if not done and not truncated else env.reset()[0]["observation"]

    obs_dict, _ = env.reset()
    obs = obs_dict["observation"]
    hidden = torch.zeros(config["batch_size"], config["hidden_dim"]).to(config["device"])

    for step in range(config["steps"]):
        obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0).to(config["device"])
        with torch.no_grad():
            emb = wm.encoder(obs_tensor)
            hidden = wm.dynamics(torch.cat([emb, torch.zeros((1, act_dim)).to(config["device"])], dim=-1), hidden[:1])
            action = actor(hidden).squeeze(0).cpu().numpy()

        next_obs_dict, _, done, truncated, _ = env.step(action)
        next_obs = next_obs_dict["observation"]
        reward = -np.linalg.norm(next_obs_dict["achieved_goal"] - next_obs_dict["desired_goal"])
        buffer.push(obs, action, reward, next_obs, done or truncated)
        total_reward += reward

        obs = next_obs if not done and not truncated else env.reset()[0]["observation"]

        if len(buffer) < config["batch_size"]:
            continue

        obs_b, act_b, rew_b, next_obs_b, done_b = buffer.sample(config["batch_size"])
        hidden = torch.zeros(config["batch_size"], config["hidden_dim"]).to(config["device"])
        next_hidden, pred_reward = wm(obs_b, act_b, hidden)
        loss_wm = F.mse_loss(pred_reward, rew_b)
        optim_wm.zero_grad()
        loss_wm.backward()
        optim_wm.step()

        rollout = imagine_rollout(actor, wm, next_hidden.detach(), config["imag_horizon"])
        feats, rewards = zip(*rollout)
        feats = torch.stack(feats)
        rewards = torch.stack(rewards)

        returns = torch.zeros_like(rewards)
        for t in reversed(range(len(rewards))):
            returns[t] = rewards[t] + config["gamma"] * (returns[t + 1] if t + 1 < len(rewards) else 0)

        val_preds = critic(feats.detach())
        loss_critic = F.mse_loss(val_preds.squeeze(-1), returns.detach().squeeze(-1))
        optim_critic.zero_grad()
        loss_critic.backward()
        optim_critic.step()

        val_preds = critic(feats)
        loss_actor = -val_preds.mean()
        optim_actor.zero_grad()
        loss_actor.backward()
        optim_actor.step()

        if (step + 1) % config["log_every"] == 0:
            avg_pred_reward = pred_reward.mean().item()
            print(f"Step {step+1}: Total Reward = {total_reward:.1f}")
            print(f"  Loss_WM: {loss_wm.item():.4f} | Loss_Critic: {loss_critic.item():.4f} | Loss_Actor: {loss_actor.item():.4f} | Pred_Reward_Mean: {avg_pred_reward:.4f}")
            total_reward = 0

    env.close()

if __name__ == "__main__":
    train()
# Out:
# Step 1000: Total Reward = -506.3
#   Loss_WM: 0.0078 | Loss_Critic: 0.0392 | Loss_Actor: 0.8847 | Pred_Reward_Mean: -0.5283
# Step 2000: Total Reward = -499.2
#   Loss_WM: 0.0089 | Loss_Critic: 0.0285 | Loss_Actor: 0.9284 | Pred_Reward_Mean: -0.5278
# Step 3000: Total Reward = -508.8
#   Loss_WM: 0.0102 | Loss_Critic: 0.0188 | Loss_Actor: 0.9448 | Pred_Reward_Mean: -0.5416
# Step 4000: Total Reward = -500.9
#   Loss_WM: 0.0095 | Loss_Critic: 0.0149 | Loss_Actor: 0.9642 | Pred_Reward_Mean: -0.4995
# Step 5000: Total Reward = -501.3
#   Loss_WM: 0.0083 | Loss_Critic: 0.0154 | Loss_Actor: 1.0388 | Pred_Reward_Mean: -0.5331
# Step 6000: Total Reward = -493.5
#   Loss_WM: 0.0073 | Loss_Critic: 0.0125 | Loss_Actor: 1.0401 | Pred_Reward_Mean: -0.5019
# Step 7000: Total Reward = -501.4
#   Loss_WM: 0.0064 | Loss_Critic: 0.0099 | Loss_Actor: 1.0578 | Pred_Reward_Mean: -0.5189
# Step 8000: Total Reward = -515.7
#   Loss_WM: 0.0079 | Loss_Critic: 0.0085 | Loss_Actor: 1.0878 | Pred_Reward_Mean: -0.5187
# Step 9000: Total Reward = -502.0
#   Loss_WM: 0.0077 | Loss_Critic: 0.0111 | Loss_Actor: 1.0821 | Pred_Reward_Mean: -0.5040
# Step 10000: Total Reward = -509.7
#   Loss_WM: 0.0079 | Loss_Critic: 0.0093 | Loss_Actor: 1.1372 | Pred_Reward_Mean: -0.5071
# Step 11000: Total Reward = -526.4
#   Loss_WM: 0.0079 | Loss_Critic: 0.0098 | Loss_Actor: 1.1765 | Pred_Reward_Mean: -0.4940
# Step 12000: Total Reward = -522.9
#   Loss_WM: 0.0074 | Loss_Critic: 0.0111 | Loss_Actor: 1.2079 | Pred_Reward_Mean: -0.5012
# Step 13000: Total Reward = -460.1
#   Loss_WM: 0.0077 | Loss_Critic: 0.0101 | Loss_Actor: 1.2469 | Pred_Reward_Mean: -0.4994
# Step 14000: Total Reward = -521.6
#   Loss_WM: 0.0072 | Loss_Critic: 0.0117 | Loss_Actor: 1.2524 | Pred_Reward_Mean: -0.5061
# Step 15000: Total Reward = -512.0
#   Loss_WM: 0.0064 | Loss_Critic: 0.0097 | Loss_Actor: 1.3038 | Pred_Reward_Mean: -0.5087
# Step 16000: Total Reward = -491.5
#   Loss_WM: 0.0063 | Loss_Critic: 0.0115 | Loss_Actor: 1.3212 | Pred_Reward_Mean: -0.5173
# Step 17000: Total Reward = -514.3
#   Loss_WM: 0.0068 | Loss_Critic: 0.0106 | Loss_Actor: 1.3303 | Pred_Reward_Mean: -0.5053
# Step 18000: Total Reward = -515.8
#   Loss_WM: 0.0106 | Loss_Critic: 0.0160 | Loss_Actor: 1.3358 | Pred_Reward_Mean: -0.4908
# Step 19000: Total Reward = -514.5
#   Loss_WM: 0.0078 | Loss_Critic: 0.0129 | Loss_Actor: 1.3577 | Pred_Reward_Mean: -0.4923
# Step 20000: Total Reward = -521.6
#   Loss_WM: 0.0062 | Loss_Critic: 0.0111 | Loss_Actor: 1.3862 | Pred_Reward_Mean: -0.5041

# %% [markdown]
# NEW FINE TUNED MODEL:

# %%
# [Same imports as before]
# Add these if needed
import os
import gymnasium as gym
import gymnasium_robotics
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import deque
import random
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime

config = {
    "env_name": "FetchReach-v3",
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "steps": 100000,
    "hidden_dim": 256,
    "log_every": 500,
    "imag_horizon": 5,
    "batch_size": 128,
    "buffer_size": 100000,
    "prefill_steps": 3000,
    "gamma": 0.95,
    "learning_rate": 1e-4,
    "action_scale": 0.1,
    "log_dir": "logs/dreamer_fetchreach_her_goalaware",
    "her_k": 4
}

class HERReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
        self.episode = []

    def push(self, obs, action, reward, next_obs, done, achieved_goal, desired_goal):
        self.episode.append((obs, action, reward, next_obs, done, achieved_goal, desired_goal))
        if done:
            self.add_episode(self.episode)
            self.episode = []

    def add_episode(self, episode):
        for i in range(len(episode)):
            obs, action, reward, next_obs, done, ag, dg = episode[i]
            self.buffer.append((obs, action, reward, next_obs, done, dg))
            future = episode[i:]
            for _ in range(config["her_k"]):
                _, _, _, _, _, f_ag, _ = random.choice(future)
                her_goal = f_ag
                her_reward = -np.linalg.norm(ag - her_goal)
                if her_reward > -0.05:
                    her_reward += 1.0
                self.buffer.append((obs, action, her_reward, next_obs, done, her_goal))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        obs, act, rew, next_obs, _, goal = map(np.stack, zip(*batch))
        relabeled_obs = np.concatenate([obs, goal], axis=-1)
        return (
            torch.tensor(relabeled_obs, dtype=torch.float32).to(config["device"]),
            torch.tensor(act, dtype=torch.float32).to(config["device"]),
            torch.tensor(rew, dtype=torch.float32).unsqueeze(1).to(config["device"]),
            torch.tensor(goal, dtype=torch.float32).to(config["device"])
        )

    def __len__(self):
        return len(self.buffer)

# Models — now accept goal
class WorldModel(nn.Module):
    def __init__(self, input_dim, act_dim):
        super().__init__()
        self.encoder = nn.Sequential(nn.Linear(input_dim, config["hidden_dim"]), nn.ReLU())
        self.dynamics = nn.GRUCell(config["hidden_dim"] + act_dim, config["hidden_dim"])
        self.reward_head = nn.Linear(config["hidden_dim"], 1)

    def forward(self, obs_goal, action, hidden):
        emb = self.encoder(obs_goal)
        return self.forward_through_dynamics(emb, action, hidden)

    def forward_through_dynamics(self, emb, action, hidden):
        hidden = self.dynamics(torch.cat([emb, action], dim=-1), hidden)
        reward = self.reward_head(hidden)
        return hidden, reward

class Actor(nn.Module):
    def __init__(self, feat_dim, act_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], act_dim),
            nn.Tanh()
        )
        self.action_scale = torch.tensor(config["action_scale"])

    def forward(self, feat):
        return self.action_scale.to(feat.device) * self.net(feat)

class Critic(nn.Module):
    def __init__(self, feat_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], 1)
        )

    def forward(self, feat):
        return self.net(feat)

def imagine_rollout(actor, wm, start_hidden, goal_tensor, horizon):
    imag_feats = []
    hidden = start_hidden
    goal_tiled = goal_tensor  # ✅ Fixed

    for _ in range(horizon):
        actor_input = torch.cat([hidden, goal_tiled], dim=-1)
        action = actor(actor_input)
        emb_dummy = torch.zeros_like(hidden)
        hidden, reward = wm.forward_through_dynamics(emb_dummy, action, hidden)
        imag_feats.append((actor_input, reward))  # ✅ Use actor_input for critic
    return imag_feats

def make_env():
    env = gym.make(config["env_name"])
    env.reset(seed=42)
    return env

def train():
    env = make_env()
    writer = SummaryWriter(log_dir=os.path.join(config["log_dir"], datetime.now().strftime("%Y%m%d-%H%M%S")))

    obs_dim = env.observation_space["observation"].shape[0]
    goal_dim = env.observation_space["desired_goal"].shape[0]
    act_dim = env.action_space.shape[0]
    input_dim = obs_dim + goal_dim

    buffer = HERReplayBuffer(config["buffer_size"])
    wm = WorldModel(input_dim, act_dim).to(config["device"])
    actor = Actor(config["hidden_dim"] + goal_dim, act_dim).to(config["device"])
    critic = Critic(config["hidden_dim"] + goal_dim).to(config["device"])

    optim_wm = torch.optim.Adam(wm.parameters(), lr=config["learning_rate"])
    optim_actor = torch.optim.Adam(actor.parameters(), lr=config["learning_rate"])
    optim_critic = torch.optim.Adam(critic.parameters(), lr=config["learning_rate"])

    obs_dict, _ = env.reset()
    obs = obs_dict["observation"]
    dg = obs_dict["desired_goal"]
    episode_reward = 0
    episode_success = 0

    for step in range(config["prefill_steps"]):
        action = env.action_space.sample()
        next_obs_dict, _, done, truncated, _ = env.step(action)
        next_obs = next_obs_dict["observation"]
        ag = next_obs_dict["achieved_goal"]
        reward = -np.linalg.norm(ag - dg)
        if reward > -0.05:
            reward += 1.0
        buffer.push(obs, action, reward, next_obs, done or truncated, ag, dg)
        obs = next_obs if not (done or truncated) else env.reset()[0]["observation"]
        dg = next_obs_dict["desired_goal"]

    obs_dict, _ = env.reset()
    obs = obs_dict["observation"]
    dg = obs_dict["desired_goal"]

    for step in range(config["steps"]):
        relabeled_obs = np.concatenate([obs, dg])
        obs_tensor = torch.tensor(relabeled_obs, dtype=torch.float32).unsqueeze(0).to(config["device"])
        goal_tensor = torch.tensor(dg, dtype=torch.float32).unsqueeze(0).to(config["device"])
        with torch.no_grad():
            emb = wm.encoder(obs_tensor)
            hidden = wm.dynamics(torch.cat([emb, torch.zeros((1, act_dim)).to(config["device"])], dim=-1),
                                 torch.zeros((1, config["hidden_dim"])).to(config["device"]))
            actor_input = torch.cat([hidden, goal_tensor], dim=-1)
            action = actor(actor_input).squeeze(0).cpu().numpy()

        next_obs_dict, _, done, truncated, _ = env.step(action)
        next_obs = next_obs_dict["observation"]
        ag = next_obs_dict["achieved_goal"]
        reward = -np.linalg.norm(ag - dg)
        success = reward > -0.05
        if success:
            reward += 1.0

        buffer.push(obs, action, reward, next_obs, done or truncated, ag, dg)
        episode_reward += reward
        episode_success += float(success)

        obs = next_obs if not (done or truncated) else env.reset()[0]["observation"]
        dg = next_obs_dict["desired_goal"]

        if done or truncated:
            writer.add_scalar("Episode/Reward", episode_reward, step)
            writer.add_scalar("Episode/Success", episode_success, step)
            episode_reward = 0
            episode_success = 0

        if len(buffer) < config["batch_size"]:
            continue

        obs_b, act_b, rew_b, goal_b = buffer.sample(config["batch_size"])
        hidden_b = torch.zeros(config["batch_size"], config["hidden_dim"]).to(config["device"])
        input_b = torch.cat([obs_b], dim=-1)
        next_hidden, pred_reward = wm(obs_b, act_b, hidden_b)
        loss_wm = F.mse_loss(pred_reward, rew_b)
        optim_wm.zero_grad()
        loss_wm.backward()
        optim_wm.step()

        rollout = imagine_rollout(actor, wm, next_hidden.detach(), goal_b, config["imag_horizon"])
        feats, rewards = zip(*rollout)
        feats = torch.stack(feats)
        rewards = torch.stack(rewards)

        returns = torch.zeros_like(rewards)
        for t in reversed(range(len(rewards))):
            returns[t] = rewards[t] + config["gamma"] * (returns[t + 1] if t + 1 < len(rewards) else 0)

        val_preds = critic(feats.detach()).squeeze(-1)
        loss_critic = F.mse_loss(val_preds, returns.detach().squeeze(-1))
        optim_critic.zero_grad()
        loss_critic.backward()
        optim_critic.step()

        val_preds = critic(feats).squeeze(-1)
        loss_actor = -val_preds.mean()
        optim_actor.zero_grad()
        loss_actor.backward()
        optim_actor.step()

        if (step + 1) % config["log_every"] == 0:
            writer.add_scalar("Loss/WorldModel", loss_wm.item(), step)
            writer.add_scalar("Loss/Critic", loss_critic.item(), step)
            writer.add_scalar("Loss/Actor", loss_actor.item(), step)
            print(f"[Step {step+1}] WM: {loss_wm.item():.4f}, Critic: {loss_critic.item():.4f}, Actor: {loss_actor.item():.4f}")

    env.close()
    writer.close()

if __name__ == "__main__":
    train()
# Out:
# [Step 500] WM: 0.1831, Critic: 0.0005, Actor: -0.5003
# [Step 1000] WM: 0.1298, Critic: 0.0003, Actor: -0.5673
# [Step 1500] WM: 0.1445, Critic: 0.0001, Actor: -0.5745
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 246
#     243     writer.close()
#     245 if __name__ == "__main__":
# --> 246     train()
#
# Cell In[18], line 234, in train()
#     232 optim_actor.zero_grad()
#     233 loss_actor.backward()
# --> 234 optim_actor.step()
#     236 if (step + 1) % config["log_every"] == 0:
#     237     writer.add_scalar("Loss/WorldModel", loss_wm.item(), step)
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/torch/optim/optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/torch/optim/optimizer.py:89, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      87     torch.set_grad_enabled(self.defaults["differentiable"])
#      88     torch._dynamo.graph_break()
# ---> 89     ret = func(self, *args, **kwargs)
#      90 finally:
#      91     torch._dynamo.graph_break()
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/torch/optim/adam.py:226, in Adam.step(self, closure)
#     214     beta1, beta2 = group["betas"]
#     216     has_complex = self._init_group(
#     217         group,
#     218         params_with_grad,
#    (...)
#     223         state_steps,
#     224     )
# --> 226     adam(
#     227         params_with_grad,
#     228         grads,
#     229         exp_avgs,
#     230         exp_avg_sqs,
#     231         max_exp_avg_sqs,
#     232         state_steps,
#     233         amsgrad=group["amsgrad"],
#     234         has_complex=has_complex,
#     235         beta1=beta1,
#     236         beta2=beta2,
#     237         lr=group["lr"],
#     238         weight_decay=group["weight_decay"],
#     239         eps=group["eps"],
#     240         maximize=group["maximize"],
#     241         foreach=group["foreach"],
#     242         capturable=group["capturable"],
#     243         differentiable=group["differentiable"],
#     244         fused=group["fused"],
#     245         grad_scale=getattr(self, "grad_scale", None),
#     246         found_inf=getattr(self, "found_inf", None),
#     247     )
#     249 return loss
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/torch/optim/optimizer.py:161, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     159     return disabled_func(*args, **kwargs)
#     160 else:
# --> 161     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/torch/optim/adam.py:766, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     763 else:
#     764     func = _single_tensor_adam
# --> 766 func(
#     767     params,
#     768     grads,
#     769     exp_avgs,
#     770     exp_avg_sqs,
#     771     max_exp_avg_sqs,
#     772     state_steps,
#     773     amsgrad=amsgrad,
#     774     has_complex=has_complex,
#     775     beta1=beta1,
#     776     beta2=beta2,
#     777     lr=lr,
#     778     weight_decay=weight_decay,
#     779     eps=eps,
#     780     maximize=maximize,
#     781     capturable=capturable,
#     782     differentiable=differentiable,
#     783     grad_scale=grad_scale,
#     784     found_inf=found_inf,
#     785 )
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/torch/optim/adam.py:591, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     584 bias_correction1 = [
#     585     1 - beta1 ** _get_value(step) for step in device_state_steps
#     586 ]
#     587 bias_correction2 = [
#     588     1 - beta2 ** _get_value(step) for step in device_state_steps
#     589 ]
# --> 591 step_size = _stack_if_compiling([(lr / bc) * -1 for bc in bias_correction1])
#     593 bias_correction2_sqrt = [_dispatch_sqrt(bc) for bc in bias_correction2]  # type: ignore[arg-type]
#     595 if amsgrad:
#     596     # Maintains the maximum of all 2nd moment running avg. till now
#
# File ~/miniconda3/envs/NLPproj/lib/python3.8/site-packages/torch/optim/adam.py:591, in <listcomp>(.0)
#     584 bias_correction1 = [
#     585     1 - beta1 ** _get_value(step) for step in device_state_steps
#     586 ]
#     587 bias_correction2 = [
#     588     1 - beta2 ** _get_value(step) for step in device_state_steps
#     589 ]
# --> 591 step_size = _stack_if_compiling([(lr / bc) * -1 for bc in bias_correction1])
#     593 bias_correction2_sqrt = [_dispatch_sqrt(bc) for bc in bias_correction2]  # type: ignore[arg-type]
#     595 if amsgrad:
#     596     # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %% [markdown]
# PICK AND PLACE IMPLEMENTATION DONW:

# %%
os.environ["MUJOCO_GL"] = "egl"

# %%
import os
import gymnasium as gym
import gymnasium_robotics
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import deque
import random
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime

config = {
    "env_name": "FetchReach-v3",
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "steps": 100_000,
    "hidden_dim": 256,
    "log_every": 250,
    "imag_horizon": 5,
    "batch_size": 128,
    "buffer_size": 100_000,
    "prefill_steps": 10_000,
    "gamma": 0.95,
    "learning_rate": 1e-4,
    "actor_lr": 1e-3,
    "critic_lr": 1e-3,
    "action_scale": 0.3,
    "log_dir": "logs/debug_dreamer_fetchreach",
    "her_k": 4
}

class HERReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
        self.episode = []

    def push(self, obs, action, reward, next_obs, done, achieved_goal, desired_goal):
        self.episode.append((obs, action, reward, next_obs, done, achieved_goal, desired_goal))
        if done:
            self.add_episode(self.episode)
            self.episode = []

    def add_episode(self, episode):
        for i in range(len(episode)):
            obs, action, reward, next_obs, done, ag, dg = episode[i]
            self.buffer.append((obs, action, reward, next_obs, done, dg))
            future = episode[i:]
            for _ in range(config["her_k"]):
                _, _, _, _, _, f_ag, _ = random.choice(future)
                her_goal = f_ag
                her_reward = -np.linalg.norm(ag - her_goal)
                if her_reward > -0.05:
                    her_reward += 1.0
                self.buffer.append((obs, action, her_reward, next_obs, done, her_goal))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        obs, act, rew, next_obs, _, goal = map(np.stack, zip(*batch))
        relabeled_obs = np.concatenate([obs, goal], axis=-1)
        if random.random() < 0.01:
            print(f"[HER Sample] Mean reward in batch: {rew.mean():.3f}")
        return (
            torch.tensor(relabeled_obs, dtype=torch.float32).to(config["device"]),
            torch.tensor(act, dtype=torch.float32).to(config["device"]),
            torch.tensor(rew, dtype=torch.float32).unsqueeze(1).to(config["device"]),
            torch.tensor(goal, dtype=torch.float32).to(config["device"])
        )

    def __len__(self):
        return len(self.buffer)

class WorldModel(nn.Module):
    def __init__(self, input_dim, act_dim):
        super().__init__()
        self.encoder = nn.Sequential(nn.Linear(input_dim, config["hidden_dim"]), nn.ReLU())
        self.dynamics = nn.GRUCell(config["hidden_dim"] + act_dim, config["hidden_dim"])
        self.reward_head = nn.Linear(config["hidden_dim"], 1)

    def forward(self, obs_goal, action, hidden):
        emb = self.encoder(obs_goal)
        return self.forward_through_dynamics(emb, action, hidden)

    def forward_through_dynamics(self, emb, action, hidden):
        hidden = self.dynamics(torch.cat([emb, action], dim=-1), hidden)
        reward = self.reward_head(hidden)
        return hidden, reward

class Actor(nn.Module):
    def __init__(self, feat_dim, act_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], act_dim),
            nn.Tanh()
        )
        self.action_scale = torch.tensor(config["action_scale"])

    def forward(self, feat):
        return self.action_scale.to(feat.device) * self.net(feat)

class Critic(nn.Module):
    def __init__(self, feat_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(feat_dim, config["hidden_dim"]),
            nn.ReLU(),
            nn.Linear(config["hidden_dim"], 1)
        )

    def forward(self, feat):
        return self.net(feat)

def imagine_rollout(actor, wm, start_hidden, goal_tensor, horizon):
    imag_feats = []
    hidden = start_hidden
    goal_tiled = goal_tensor
    for _ in range(horizon):
        actor_input = torch.cat([hidden, goal_tiled], dim=-1)
        action = actor(actor_input)
        action += 0.3 * torch.randn_like(action)
        emb_dummy = torch.zeros_like(hidden)
        hidden, reward = wm.forward_through_dynamics(emb_dummy, action, hidden)
        imag_feats.append((actor_input, reward))
    return imag_feats

def make_env():
    env = gym.make(config["env_name"])
    env.reset(seed=42)
    return env

def train():
    env = make_env()
    writer = SummaryWriter(log_dir=os.path.join(config["log_dir"], datetime.now().strftime("%Y%m%d-%H%M%S")))

    obs_dim = env.observation_space["observation"].shape[0]
    goal_dim = env.observation_space["desired_goal"].shape[0]
    act_dim = env.action_space.shape[0]
    input_dim = obs_dim + goal_dim

    buffer = HERReplayBuffer(config["buffer_size"])
    wm = WorldModel(input_dim, act_dim).to(config["device"])
    actor = Actor(config["hidden_dim"] + goal_dim, act_dim).to(config["device"])
    critic = Critic(config["hidden_dim"] + goal_dim).to(config["device"])

    optim_wm = torch.optim.Adam(wm.parameters(), lr=config["learning_rate"])
    optim_actor = torch.optim.Adam(actor.parameters(), lr=1e-3)
    optim_critic = torch.optim.Adam(critic.parameters(), lr=3e-3)

    obs_dict, _ = env.reset()
    obs = obs_dict["observation"]
    dg = obs_dict["desired_goal"]
    episode_reward, episode_success = 0, 0
    success_history = deque(maxlen=50)

    # Prefill
    for step in range(config["prefill_steps"]):
        action = env.action_space.sample()
        next_obs_dict, _, done, truncated, _ = env.step(action)
        next_obs = next_obs_dict["observation"]
        ag = next_obs_dict["achieved_goal"]
        reward = -np.linalg.norm(ag - dg)

        dist_to_goal = np.linalg.norm(ag - dg)
        print(f"[Step {step}] Distance to goal: {dist_to_goal:.4f}")

        if reward > -0.05:
            reward += 1.0
        buffer.push(obs, action, reward, next_obs, done or truncated, ag, dg)
        obs = next_obs if not (done or truncated) else env.reset()[0]["observation"]
        dg = next_obs_dict["desired_goal"]

    obs_dict, _ = env.reset()
    obs = obs_dict["observation"]
    dg = obs_dict["desired_goal"]

    for step in range(config["steps"]):
        relabeled_obs = np.concatenate([obs, dg])
        obs_tensor = torch.tensor(relabeled_obs, dtype=torch.float32).unsqueeze(0).to(config["device"])
        goal_tensor = torch.tensor(dg, dtype=torch.float32).unsqueeze(0).to(config["device"])
        with torch.no_grad():
            emb = wm.encoder(obs_tensor)
            hidden = wm.dynamics(
                torch.cat([emb, torch.zeros((1, act_dim)).to(config["device"])], dim=-1),
                torch.zeros((1, config["hidden_dim"])).to(config["device"])
            )
            actor_input = torch.cat([hidden, goal_tensor], dim=-1)
            action = actor(actor_input).squeeze(0).cpu().numpy()
            # Add Gaussian noise for exploration
            noise = np.random.normal(0, 0.1, size=action.shape)
            action = np.clip(action + noise, -1.0, 1.0)

        next_obs_dict, _, done, truncated, _ = env.step(action)
        next_obs = next_obs_dict["observation"]
        ag = next_obs_dict["achieved_goal"]

        # Distance to goal logging
        dist_to_goal = np.linalg.norm(ag - dg)
        reward = -dist_to_goal
        if reward > -0.05:
            reward += 1.0
        else:
            reward += 0.2 * np.exp(-10 * abs(reward))  # shaped reward bonus

        success = reward > 0.9
        buffer.push(obs, action, reward, next_obs, done or truncated, ag, dg)
        episode_reward += reward
        episode_success += float(success)

        obs = next_obs if not (done or truncated) else env.reset()[0]["observation"]
        dg = next_obs_dict["desired_goal"]

        if done or truncated:
            success_history.append(episode_success)
            writer.add_scalar("Episode/Reward", episode_reward, step)
            writer.add_scalar("Episode/Success", episode_success, step)
            print(f"[Episode Done @ Step {step}] Reward: {episode_reward:.3f}, Success: {episode_success:.1f}, MA(50): {np.mean(success_history):.2f}")
            episode_reward, episode_success = 0, 0

        if len(buffer) < config["batch_size"]:
            continue

        obs_b, act_b, rew_b, goal_b = buffer.sample(config["batch_size"])
        hidden_b = torch.zeros(config["batch_size"], config["hidden_dim"]).to(config["device"])
        next_hidden, pred_reward = wm(obs_b, act_b, hidden_b)
        loss_wm = F.mse_loss(pred_reward, rew_b)
        optim_wm.zero_grad()
        loss_wm.backward()
        optim_wm.step()

        rollout = imagine_rollout(actor, wm, next_hidden.detach(), goal_b, config["imag_horizon"])
        feats, rewards = zip(*rollout)
        feats = torch.stack(feats)
        rewards = torch.stack(rewards)

        returns = torch.zeros_like(rewards)
        for t in reversed(range(len(rewards))):
            returns[t] = rewards[t] + config["gamma"] * (returns[t + 1] if t + 1 < len(rewards) else 0)

        feats_flat = feats.view(-1, feats.shape[-1])
        returns_flat = returns.view(-1).detach()  # Only detach returns here

        # --- Critic Update ---
        val_preds = critic(feats_flat).squeeze(-1)  # No .detach() — critic needs grads
        loss_critic = F.mse_loss(val_preds, returns_flat)
        optim_critic.zero_grad()
        loss_critic.backward()
        optim_critic.step()

        # --- Actor Update ---
        val_preds_actor = critic(feats_flat.detach()).squeeze(-1)
        loss_actor = -val_preds_actor.mean()
        optim_actor.zero_grad()
        loss_actor.backward()
        optim_actor.step()

        if step % config["log_every"] == 0:
            print(f"[Step {step}] WM: {loss_wm.item():.4f}, Critic: {loss_critic.item():.4f}, Actor: {loss_actor.item():.4f}")
            print(f"Returns mean: {returns.mean().item():.4f}, ValPreds mean: {val_preds.mean().item():.4f}")
            writer.add_scalar("Loss/WorldModel", loss_wm.item(), step)
            writer.add_scalar("Loss/Critic", loss_critic.item(), step)
            writer.add_scalar("Loss/Actor", loss_actor.item(), step)
            writer.add_scalar("Debug/GoalDistance", dist_to_goal, step)

    env.close()
    writer.close()


if __name__ == "__main__":
    train()
# Out:
# [Step 0] Distance to goal: 0.3889
# [Step 1] Distance to goal: 0.4234
# [Step 2] Distance to goal: 0.4516
# [Step 3] Distance to goal: 0.4573
# [Step 4] Distance to goal: 0.4541
# [Step 5] Distance to goal: 0.4800
# [Step 6] Distance to goal: 0.5031
# [Step 7] Distance to goal: 0.4895
# [Step 8] Distance to goal: 0.4827
# [Step 9] Distance to goal: 0.4750
# [Step 10] Distance to goal: 0.4733
# [Step 11] Distance to goal: 0.4862
# [Step 12] Distance to goal: 0.4965
# [Step 13] Distance to goal: 0.5062
# [Step 14] Distance to goal: 0.5110
# [Step 15] Distance to goal: 0.5301
# [Step 16] Distance to goal: 0.5558
# [Step 17] Distance to goal: 0.5611
# [Step 18] Distance to goal: 0.5445
# [Step 19] Distance to goal: 0.5750
# [Step 20] Distance to goal: 0.5823
# [Step 21] Distance to goal: 0.5858
# [Step 22] Distance to goal: 0.5887
# [Step 23] Distance to goal: 0.5938
# [Step 24] Distance to goal: 0.6322
# [Step 25] Distance to goal: 0.6091
# [Step 26] Distance to goal: 0.6060
# [Step 27] Distance to goal: 0.6343
# [Step 28] Distance to goal: 0.6335
# [Step 29] Distance to goal: 0.6533
# [Step 30] Distance to goal: 0.6859
# [Step 31] Distance to goal: 0.6841
# [Step 32] Distance to goal: 0.6890
# [Step 33] Distance to goal: 0.6699
# [Step 34] Distance to goal: 0.6473
# [Step 35] Distance to goal: 0.6523
# [Step 36] Distance to goal: 0.6542
# [Step 37] Distance to goal: 0.6689
# [Step 38] Distance to goal: 0.6339
# [Step 39] Distance to goal: 0.6119
# [Step 40] Distance to goal: 0.5865
# [Step 41] Distance to goal: 0.5817
# [Step 42] Distance to goal: 0.5790
# [Step 43] Distance to goal: 0.5814
# [Step 44] Distance to goal: 0.5886
# [Step 45] Distance to goal: 0.5557
# [Step 46] Distance to goal: 0.5247
# [Step 47] Distance to goal: 0.5296
# [Step 48] Distance to goal: 0.5406
# [Step 49] Distance to goal: 0.5650
# [Step 50] Distance to goal: 0.3803
# [Step 51] Distance to goal: 0.6777
# [Step 52] Distance to goal: 0.6780
# [Step 53] Distance to goal: 0.7013
# [Step 54] Distance to goal: 0.6908
# [Step 55] Distance to goal: 0.6747
# [Step 56] Distance to goal: 0.6885
# [Step 57] Distance to goal: 0.7131
# [Step 58] Distance to goal: 0.7166
# [Step 59] Distance to goal: 0.7344
# [Step 60] Distance to goal: 0.7506
# [Step 61] Distance to goal: 0.7349
# [Step 62] Distance to goal: 0.7343
# [Step 63] Distance to goal: 0.7470
# [Step 64] Distance to goal: 0.7753
# [Step 65] Distance to goal: 0.7981
# [Step 66] Distance to goal: 0.8072
# [Step 67] Distance to goal: 0.7759
# [Step 68] Distance to goal: 0.7791
# [Step 69] Distance to goal: 0.7831
# [Step 70] Distance to goal: 0.8165
# [Step 71] Distance to goal: 0.8262
# [Step 72] Distance to goal: 0.8492
# [Step 73] Distance to goal: 0.8590
# [Step 74] Distance to goal: 0.8791
# [Step 75] Distance to goal: 0.9064
# [Step 76] Distance to goal: 0.9414
# [Step 77] Distance to goal: 0.9442
# [Step 78] Distance to goal: 0.9315
# [Step 79] Distance to goal: 0.9192
# [Step 80] Distance to goal: 0.8957
# [Step 81] Distance to goal: 0.8743
# [Step 82] Distance to goal: 0.8736
# [Step 83] Distance to goal: 0.8703
# [Step 84] Distance to goal: 0.8627
# [Step 85] Distance to goal: 0.8640
# [Step 86] Distance to goal: 0.8804
# [Step 87] Distance to goal: 0.8987
# [Step 88] Distance to goal: 0.9157
# [Step 89] Distance to goal: 0.9263
# [Step 90] Distance to goal: 0.9434
# [Step 91] Distance to goal: 0.9778
# [Step 92] Distance to goal: 0.9846
# [Step 93] Distance to goal: 0.9745
# [Step 94] Distance to goal: 0.9719
# [Step 95] Distance to goal: 1.0093
# [Step 96] Distance to goal: 0.9917
# [Step 97] Distance to goal: 0.9992
# [Step 98] Distance to goal: 0.9775
# [Step 99] Distance to goal: 0.9801
# [Step 100] Distance to goal: 0.6698
# [Step 101] Distance to goal: 0.4671
# [Step 102] Distance to goal: 0.4580
# [Step 103] Distance to goal: 0.4495
# [Step 104] Distance to goal: 0.4579
# [Step 105] Distance to goal: 0.4565
# [Step 106] Distance to goal: 0.4541
# [Step 107] Distance to goal: 0.4305
# [Step 108] Distance to goal: 0.4526
# [Step 109] Distance to goal: 0.4614
# [Step 110] Distance to goal: 0.4651
# [Step 111] Distance to goal: 0.4879
# [Step 112] Distance to goal: 0.4713
# [Step 113] Distance to goal: 0.5047
# [Step 114] Distance to goal: 0.4990
# [Step 115] Distance to goal: 0.5006
# [Step 116] Distance to goal: 0.4923
# [Step 117] Distance to goal: 0.4769
# [Step 118] Distance to goal: 0.4835
# [Step 119] Distance to goal: 0.5072
# [Step 120] Distance to goal: 0.5319
# [Step 121] Distance to goal: 0.5302
# [Step 122] Distance to goal: 0.5334
# [Step 123] Distance to goal: 0.5413
# [Step 124] Distance to goal: 0.5611
# [Step 125] Distance to goal: 0.5926
# [Step 126] Distance to goal: 0.5907
# [Step 127] Distance to goal: 0.6300
# [Step 128] Distance to goal: 0.6299
# [Step 129] Distance to goal: 0.6487
# [Step 130] Distance to goal: 0.6720
# [Step 131] Distance to goal: 0.6719
# [Step 132] Distance to goal: 0.6583
# [Step 133] Distance to goal: 0.6616
# [Step 134] Distance to goal: 0.6936
# [Step 135] Distance to goal: 0.7049
# [Step 136] Distance to goal: 0.6738
# [Step 137] Distance to goal: 0.6683
# [Step 138] Distance to goal: 0.6847
# [Step 139] Distance to goal: 0.7026
# [Step 140] Distance to goal: 0.7102
# [Step 141] Distance to goal: 0.7363
# [Step 142] Distance to goal: 0.7109
# [Step 143] Distance to goal: 0.7191
# [Step 144] Distance to goal: 0.7055
# [Step 145] Distance to goal: 0.7200
# [Step 146] Distance to goal: 0.7001
# [Step 147] Distance to goal: 0.7034
# [Step 148] Distance to goal: 0.7161
# [Step 149] Distance to goal: 0.7281
# [Step 150] Distance to goal: 0.4404
# [Step 151] Distance to goal: 0.6084
# [Step 152] Distance to goal: 0.5893
# [Step 153] Distance to goal: 0.6102
# [Step 154] Distance to goal: 0.5919
# [Step 155] Distance to goal: 0.5717
# [Step 156] Distance to goal: 0.5747
# [Step 157] Distance to goal: 0.5656
# [Step 158] Distance to goal: 0.5624
# [Step 159] Distance to goal: 0.5422
# [Step 160] Distance to goal: 0.5448
# [Step 161] Distance to goal: 0.5126
# [Step 162] Distance to goal: 0.5220
# [Step 163] Distance to goal: 0.5402
# [Step 164] Distance to goal: 0.5531
# [Step 165] Distance to goal: 0.5501
# [Step 166] Distance to goal: 0.5240
# [Step 167] Distance to goal: 0.5539
# [Step 168] Distance to goal: 0.5634
# [Step 169] Distance to goal: 0.5367
# [Step 170] Distance to goal: 0.5457
# [Step 171] Distance to goal: 0.5362
# [Step 172] Distance to goal: 0.5661
# [Step 173] Distance to goal: 0.5599
# [Step 174] Distance to goal: 0.5339
# [Step 175] Distance to goal: 0.5494
# [Step 176] Distance to goal: 0.5575
# [Step 177] Distance to goal: 0.5720
# [Step 178] Distance to goal: 0.5611
# [Step 179] Distance to goal: 0.5481
# [Step 180] Distance to goal: 0.5278
# [Step 181] Distance to goal: 0.4998
# [Step 182] Distance to goal: 0.4890
# [Step 183] Distance to goal: 0.4670
# [Step 184] Distance to goal: 0.4710
# [Step 185] Distance to goal: 0.4507
# [Step 186] Distance to goal: 0.4143
# [Step 187] Distance to goal: 0.4292
# [Step 188] Distance to goal: 0.4152
# [Step 189] Distance to goal: 0.4269
# [Step 190] Distance to goal: 0.4399
# [Step 191] Distance to goal: 0.4711
# [Step 192] Distance to goal: 0.4679
# [Step 193] Distance to goal: 0.4642
# [Step 194] Distance to goal: 0.4490
# [Step 195] Distance to goal: 0.4511
# [Step 196] Distance to goal: 0.4514
# [Step 197] Distance to goal: 0.4700
# [Step 198] Distance to goal: 0.4411
# [Step 199] Distance to goal: 0.4417
# [Step 200] Distance to goal: 0.6136
# [Step 201] Distance to goal: 0.6069
# [Step 202] Distance to goal: 0.6122
# [Step 203] Distance to goal: 0.6158
# [Step 204] Distance to goal: 0.6003
# [Step 205] Distance to goal: 0.5864
# [Step 206] Distance to goal: 0.6116
# [Step 207] Distance to goal: 0.5964
# [Step 208] Distance to goal: 0.6004
# [Step 209] Distance to goal: 0.5995
# [Step 210] Distance to goal: 0.6127
# [Step 211] Distance to goal: 0.6435
# [Step 212] Distance to goal: 0.6487
# [Step 213] Distance to goal: 0.6203
# [Step 214] Distance to goal: 0.6125
# [Step 215] Distance to goal: 0.6106
# [Step 216] Distance to goal: 0.6125
# [Step 217] Distance to goal: 0.6028
# [Step 218] Distance to goal: 0.5883
# [Step 219] Distance to goal: 0.5995
# [Step 220] Distance to goal: 0.5869
# [Step 221] Distance to goal: 0.5727
# [Step 222] Distance to goal: 0.5727
# [Step 223] Distance to goal: 0.5802
# [Step 224] Distance to goal: 0.5724
# [Step 225] Distance to goal: 0.5820
# [Step 226] Distance to goal: 0.5926
# [Step 227] Distance to goal: 0.6134
# [Step 228] Distance to goal: 0.6471
# [Step 229] Distance to goal: 0.6178
# [Step 230] Distance to goal: 0.6161
# [Step 231] Distance to goal: 0.6368
# [Step 232] Distance to goal: 0.6649
# [Step 233] Distance to goal: 0.6397
# [Step 234] Distance to goal: 0.6465
# [Step 235] Distance to goal: 0.6369
# [Step 236] Distance to goal: 0.6483
# [Step 237] Distance to goal: 0.6628
# [Step 238] Distance to goal: 0.6359
# [Step 239] Distance to goal: 0.6576
# [Step 240] Distance to goal: 0.6426
# [Step 241] Distance to goal: 0.6149
# [Step 242] Distance to goal: 0.6117
# [Step 243] Distance to goal: 0.6172
# [Step 244] Distance to goal: 0.6155
# [Step 245] Distance to goal: 0.6263
# [Step 246] Distance to goal: 0.6167
# [Step 247] Distance to goal: 0.6288
# [Step 248] Distance to goal: 0.6090
# [Step 249] Distance to goal: 0.6112
# [Step 250] Distance to goal: 0.6408
# [Step 251] Distance to goal: 0.5335
# [Step 252] Distance to goal: 0.5545
# [Step 253] Distance to goal: 0.5535
# [Step 254] Distance to goal: 0.5625
# [Step 255] Distance to goal: 0.5412
# [Step 256] Distance to goal: 0.5561
# [Step 257] Distance to goal: 0.5418
# [Step 258] Distance to goal: 0.5443
# [Step 259] Distance to goal: 0.5373
# [Step 260] Distance to goal: 0.5367
# [Step 261] Distance to goal: 0.5049
# [Step 262] Distance to goal: 0.5241
# [Step 263] Distance to goal: 0.5450
# [Step 264] Distance to goal: 0.5245
# [Step 265] Distance to goal: 0.5447
# [Step 266] Distance to goal: 0.5552
# [Step 267] Distance to goal: 0.5627
# [Step 268] Distance to goal: 0.5458
# [Step 269] Distance to goal: 0.5267
# [Step 270] Distance to goal: 0.5429
# [Step 271] Distance to goal: 0.5354
# [Step 272] Distance to goal: 0.5724
# [Step 273] Distance to goal: 0.5718
# [Step 274] Distance to goal: 0.5882
# [Step 275] Distance to goal: 0.6039
# [Step 276] Distance to goal: 0.6162
# [Step 277] Distance to goal: 0.6052
# [Step 278] Distance to goal: 0.6008
# [Step 279] Distance to goal: 0.6177
# [Step 280] Distance to goal: 0.6293
# [Step 281] Distance to goal: 0.6144
# [Step 282] Distance to goal: 0.6356
# [Step 283] Distance to goal: 0.6468
# [Step 284] Distance to goal: 0.6560
# [Step 285] Distance to goal: 0.6347
# [Step 286] Distance to goal: 0.6224
# [Step 287] Distance to goal: 0.6063
# [Step 288] Distance to goal: 0.5880
# [Step 289] Distance to goal: 0.5990
# [Step 290] Distance to goal: 0.6082
# [Step 291] Distance to goal: 0.6244
# [Step 292] Distance to goal: 0.6137
# [Step 293] Distance to goal: 0.6160
# [Step 294] Distance to goal: 0.6334
# [Step 295] Distance to goal: 0.6633
# [Step 296] Distance to goal: 0.6533
# [Step 297] Distance to goal: 0.6720
# [Step 298] Distance to goal: 0.6888
# [Step 299] Distance to goal: 0.6720
# [Step 300] Distance to goal: 0.5531
# [Step 301] Distance to goal: 0.6538
# [Step 302] Distance to goal: 0.6350
# [Step 303] Distance to goal: 0.6557
# [Step 304] Distance to goal: 0.6817
# [Step 305] Distance to goal: 0.7012
# [Step 306] Distance to goal: 0.7054
# [Step 307] Distance to goal: 0.7342
# [Step 308] Distance to goal: 0.7457
# [Step 309] Distance to goal: 0.7260
# [Step 310] Distance to goal: 0.7227
# [Step 311] Distance to goal: 0.7496
# [Step 312] Distance to goal: 0.7414
# [Step 313] Distance to goal: 0.7566
# [Step 314] Distance to goal: 0.7732
# [Step 315] Distance to goal: 0.7842
# [Step 316] Distance to goal: 0.7745
# [Step 317] Distance to goal: 0.7706
# [Step 318] Distance to goal: 0.7738
# [Step 319] Distance to goal: 0.7866
# [Step 320] Distance to goal: 0.7961
# [Step 321] Distance to goal: 0.7718
# [Step 322] Distance to goal: 0.7843
# [Step 323] Distance to goal: 0.7881
# [Step 324] Distance to goal: 0.7720
# [Step 325] Distance to goal: 0.7960
# [Step 326] Distance to goal: 0.8196
# [Step 327] Distance to goal: 0.8084
# [Step 328] Distance to goal: 0.8333
# [Step 329] Distance to goal: 0.8200
# [Step 330] Distance to goal: 0.8105
# [Step 331] Distance to goal: 0.8054
# [Step 332] Distance to goal: 0.8227
# [Step 333] Distance to goal: 0.8166
# [Step 334] Distance to goal: 0.8024
# [Step 335] Distance to goal: 0.7852
# [Step 336] Distance to goal: 0.7831
# [Step 337] Distance to goal: 0.7610
# [Step 338] Distance to goal: 0.7570
# [Step 339] Distance to goal: 0.7358
# [Step 340] Distance to goal: 0.7695
# [Step 341] Distance to goal: 0.7834
# [Step 342] Distance to goal: 0.7907
# [Step 343] Distance to goal: 0.7658
# [Step 344] Distance to goal: 0.7859
# [Step 345] Distance to goal: 0.7733
# [Step 346] Distance to goal: 0.7579
# [Step 347] Distance to goal: 0.7450
# [Step 348] Distance to goal: 0.7551
# [Step 349] Distance to goal: 0.7709
# [Step 350] Distance to goal: 0.6662
# [Step 351] Distance to goal: 0.5108
# [Step 352] Distance to goal: 0.5092
# [Step 353] Distance to goal: 0.5082
# [Step 354] Distance to goal: 0.5061
# [Step 355] Distance to goal: 0.5246
# [Step 356] Distance to goal: 0.5288
# [Step 357] Distance to goal: 0.5692
# [Step 358] Distance to goal: 0.5785
# [Step 359] Distance to goal: 0.5843
# [Step 360] Distance to goal: 0.5980
# [Step 361] Distance to goal: 0.6007
# [Step 362] Distance to goal: 0.5837
# [Step 363] Distance to goal: 0.5995
# [Step 364] Distance to goal: 0.6153
# [Step 365] Distance to goal: 0.6356
# [Step 366] Distance to goal: 0.6449
# [Step 367] Distance to goal: 0.6631
# [Step 368] Distance to goal: 0.6805
# [Step 369] Distance to goal: 0.6941
# [Step 370] Distance to goal: 0.6883
# [Step 371] Distance to goal: 0.7096
# [Step 372] Distance to goal: 0.7319
# [Step 373] Distance to goal: 0.7588
# [Step 374] Distance to goal: 0.7846
# [Step 375] Distance to goal: 0.8061
# [Step 376] Distance to goal: 0.8136
# [Step 377] Distance to goal: 0.8280
# [Step 378] Distance to goal: 0.8441
# [Step 379] Distance to goal: 0.8331
# [Step 380] Distance to goal: 0.8428
# [Step 381] Distance to goal: 0.8629
# [Step 382] Distance to goal: 0.8535
# [Step 383] Distance to goal: 0.8656
# [Step 384] Distance to goal: 0.8442
# [Step 385] Distance to goal: 0.8552
# [Step 386] Distance to goal: 0.8477
# [Step 387] Distance to goal: 0.8421
# [Step 388] Distance to goal: 0.8673
# [Step 389] Distance to goal: 0.8420
# [Step 390] Distance to goal: 0.8716
# [Step 391] Distance to goal: 0.8705
# [Step 392] Distance to goal: 0.8957
# [Step 393] Distance to goal: 0.8950
# [Step 394] Distance to goal: 0.9089
# [Step 395] Distance to goal: 0.8902
# [Step 396] Distance to goal: 0.8962
# [Step 397] Distance to goal: 0.8916
# [Step 398] Distance to goal: 0.8946
# [Step 399] Distance to goal: 0.8879
# [Step 400] Distance to goal: 0.4701
# [Step 401] Distance to goal: 0.4183
# [Step 402] Distance to goal: 0.4133
# [Step 403] Distance to goal: 0.4064
# [Step 404] Distance to goal: 0.4177
# [Step 405] Distance to goal: 0.4222
# [Step 406] Distance to goal: 0.4394
# [Step 407] Distance to goal: 0.4644
# [Step 408] Distance to goal: 0.4874
# [Step 409] Distance to goal: 0.4888
# [Step 410] Distance to goal: 0.4893
# [Step 411] Distance to goal: 0.4825
# [Step 412] Distance to goal: 0.4870
# [Step 413] Distance to goal: 0.4828
# [Step 414] Distance to goal: 0.5033
# [Step 415] Distance to goal: 0.4836
# [Step 416] Distance to goal: 0.4756
# [Step 417] Distance to goal: 0.4598
# [Step 418] Distance to goal: 0.4455
# [Step 419] Distance to goal: 0.4665
# [Step 420] Distance to goal: 0.4445
# [Step 421] Distance to goal: 0.4615
# [Step 422] Distance to goal: 0.4357
# [Step 423] Distance to goal: 0.4553
# [Step 424] Distance to goal: 0.4864
# [Step 425] Distance to goal: 0.5070
# [Step 426] Distance to goal: 0.4961
# [Step 427] Distance to goal: 0.4896
# [Step 428] Distance to goal: 0.5130
# [Step 429] Distance to goal: 0.5377
# [Step 430] Distance to goal: 0.5640
# [Step 431] Distance to goal: 0.5391
# [Step 432] Distance to goal: 0.5376
# [Step 433] Distance to goal: 0.5439
# [Step 434] Distance to goal: 0.5580
# [Step 435] Distance to goal: 0.5800
# [Step 436] Distance to goal: 0.5927
# [Step 437] Distance to goal: 0.5786
# [Step 438] Distance to goal: 0.5377
# [Step 439] Distance to goal: 0.5342
# [Step 440] Distance to goal: 0.5318
# [Step 441] Distance to goal: 0.5339
# [Step 442] Distance to goal: 0.5397
# [Step 443] Distance to goal: 0.5197
# [Step 444] Distance to goal: 0.5163
# [Step 445] Distance to goal: 0.5406
# [Step 446] Distance to goal: 0.5600
# [Step 447] Distance to goal: 0.5370
# [Step 448] Distance to goal: 0.5208
# [Step 449] Distance to goal: 0.5184
# [Step 450] Distance to goal: 0.4690
# [Step 451] Distance to goal: 0.6898
# [Step 452] Distance to goal: 0.7077
# [Step 453] Distance to goal: 0.6947
# [Step 454] Distance to goal: 0.6889
# [Step 455] Distance to goal: 0.6617
# [Step 456] Distance to goal: 0.6754
# [Step 457] Distance to goal: 0.6813
# [Step 458] Distance to goal: 0.6783
# [Step 459] Distance to goal: 0.7026
# [Step 460] Distance to goal: 0.6985
# [Step 461] Distance to goal: 0.6886
# [Step 462] Distance to goal: 0.6657
# [Step 463] Distance to goal: 0.6383
# [Step 464] Distance to goal: 0.6443
# [Step 465] Distance to goal: 0.6155
# [Step 466] Distance to goal: 0.6242
# [Step 467] Distance to goal: 0.6305
# [Step 468] Distance to goal: 0.6295
# [Step 469] Distance to goal: 0.6295
# [Step 470] Distance to goal: 0.6508
# [Step 471] Distance to goal: 0.6381
# [Step 472] Distance to goal: 0.6529
# [Step 473] Distance to goal: 0.6269
# [Step 474] Distance to goal: 0.6180
# [Step 475] Distance to goal: 0.6193
# [Step 476] Distance to goal: 0.6227
# [Step 477] Distance to goal: 0.5975
# [Step 478] Distance to goal: 0.6040
# [Step 479] Distance to goal: 0.5837
# [Step 480] Distance to goal: 0.5726
# [Step 481] Distance to goal: 0.6058
# [Step 482] Distance to goal: 0.6325
# [Step 483] Distance to goal: 0.6659
# [Step 484] Distance to goal: 0.6656
# [Step 485] Distance to goal: 0.6732
# [Step 486] Distance to goal: 0.6732
# [Step 487] Distance to goal: 0.6755
# [Step 488] Distance to goal: 0.6774
# [Step 489] Distance to goal: 0.6851
# [Step 490] Distance to goal: 0.6983
# [Step 491] Distance to goal: 0.7354
# [Step 492] Distance to goal: 0.7362
# [Step 493] Distance to goal: 0.7634
# [Step 494] Distance to goal: 0.7586
# [Step 495] Distance to goal: 0.7713
# [Step 496] Distance to goal: 0.7584
# [Step 497] Distance to goal: 0.7502
# [Step 498] Distance to goal: 0.7564
# [Step 499] Distance to goal: 0.7665
# [Step 500] Distance to goal: 0.6817
# [Step 501] Distance to goal: 0.5456
# [Step 502] Distance to goal: 0.5408
# [Step 503] Distance to goal: 0.5428
# [Step 504] Distance to goal: 0.5415
# [Step 505] Distance to goal: 0.5608
# [Step 506] Distance to goal: 0.5881
# [Step 507] Distance to goal: 0.5760
# [Step 508] Distance to goal: 0.5841
# [Step 509] Distance to goal: 0.5990
# [Step 510] Distance to goal: 0.5929
# [Step 511] Distance to goal: 0.5932
# [Step 512] Distance to goal: 0.5887
# [Step 513] Distance to goal: 0.5552
# [Step 514] Distance to goal: 0.5446
# [Step 515] Distance to goal: 0.5572
# [Step 516] Distance to goal: 0.5528
# [Step 517] Distance to goal: 0.5784
# [Step 518] Distance to goal: 0.5771
# [Step 519] Distance to goal: 0.6030
# [Step 520] Distance to goal: 0.5891
# [Step 521] Distance to goal: 0.5900
# [Step 522] Distance to goal: 0.5864
# [Step 523] Distance to goal: 0.6103
# [Step 524] Distance to goal: 0.6213
# [Step 525] Distance to goal: 0.6015
# [Step 526] Distance to goal: 0.5802
# [Step 527] Distance to goal: 0.5914
# [Step 528] Distance to goal: 0.5931
# [Step 529] Distance to goal: 0.6127
# [Step 530] Distance to goal: 0.6067
# [Step 531] Distance to goal: 0.5879
# [Step 532] Distance to goal: 0.5943
# [Step 533] Distance to goal: 0.6217
# [Step 534] Distance to goal: 0.6222
# [Step 535] Distance to goal: 0.6394
# [Step 536] Distance to goal: 0.6472
# [Step 537] Distance to goal: 0.6757
# [Step 538] Distance to goal: 0.6600
# [Step 539] Distance to goal: 0.6726
# [Step 540] Distance to goal: 0.7090
# [Step 541] Distance to goal: 0.6961
# [Step 542] Distance to goal: 0.7140
# [Step 543] Distance to goal: 0.7169
# [Step 544] Distance to goal: 0.7298
# [Step 545] Distance to goal: 0.7406
# [Step 546] Distance to goal: 0.7565
# [Step 547] Distance to goal: 0.7415
# [Step 548] Distance to goal: 0.7336
# [Step 549] Distance to goal: 0.7470
# [Step 550] Distance to goal: 0.5902
# [Step 551] Distance to goal: 0.5670
# [Step 552] Distance to goal: 0.5511
# [Step 553] Distance to goal: 0.5407
# [Step 554] Distance to goal: 0.5542
# [Step 555] Distance to goal: 0.5618
# [Step 556] Distance to goal: 0.5859
# [Step 557] Distance to goal: 0.5801
# [Step 558] Distance to goal: 0.6018
# [Step 559] Distance to goal: 0.5806
# [Step 560] Distance to goal: 0.5611
# [Step 561] Distance to goal: 0.5486
# [Step 562] Distance to goal: 0.5644
# [Step 563] Distance to goal: 0.5789
# [Step 564] Distance to goal: 0.6188
# [Step 565] Distance to goal: 0.6368
# [Step 566] Distance to goal: 0.6099
# [Step 567] Distance to goal: 0.6092
# [Step 568] Distance to goal: 0.6219
# [Step 569] Distance to goal: 0.6421
# [Step 570] Distance to goal: 0.6082
# [Step 571] Distance to goal: 0.6187
# [Step 572] Distance to goal: 0.6322
# [Step 573] Distance to goal: 0.6483
# [Step 574] Distance to goal: 0.6372
# [Step 575] Distance to goal: 0.6417
# [Step 576] Distance to goal: 0.6104
# [Step 577] Distance to goal: 0.6067
# [Step 578] Distance to goal: 0.5901
# [Step 579] Distance to goal: 0.5798
# [Step 580] Distance to goal: 0.5620
# [Step 581] Distance to goal: 0.5473
# [Step 582] Distance to goal: 0.5354
# [Step 583] Distance to goal: 0.5489
# [Step 584] Distance to goal: 0.5465
# [Step 585] Distance to goal: 0.5533
# [Step 586] Distance to goal: 0.5546
# [Step 587] Distance to goal: 0.5417
# [Step 588] Distance to goal: 0.5126
# [Step 589] Distance to goal: 0.5312
# [Step 590] Distance to goal: 0.5439
# [Step 591] Distance to goal: 0.5339
# [Step 592] Distance to goal: 0.5264
# [Step 593] Distance to goal: 0.5230
# [Step 594] Distance to goal: 0.5176
# [Step 595] Distance to goal: 0.5237
# [Step 596] Distance to goal: 0.5018
# [Step 597] Distance to goal: 0.4994
# [Step 598] Distance to goal: 0.4951
# [Step 599] Distance to goal: 0.5001
# [Step 600] Distance to goal: 0.6127
# [Step 601] Distance to goal: 0.5176
# [Step 602] Distance to goal: 0.5358
# [Step 603] Distance to goal: 0.5420
# [Step 604] Distance to goal: 0.5530
# [Step 605] Distance to goal: 0.5498
# [Step 606] Distance to goal: 0.5625
# [Step 607] Distance to goal: 0.5439
# [Step 608] Distance to goal: 0.5270
# [Step 609] Distance to goal: 0.5306
# [Step 610] Distance to goal: 0.5431
# [Step 611] Distance to goal: 0.5632
# [Step 612] Distance to goal: 0.5914
# [Step 613] Distance to goal: 0.5789
# [Step 614] Distance to goal: 0.5733
# [Step 615] Distance to goal: 0.5894
# [Step 616] Distance to goal: 0.6020
# [Step 617] Distance to goal: 0.6332
# [Step 618] Distance to goal: 0.6037
# [Step 619] Distance to goal: 0.5930
# [Step 620] Distance to goal: 0.6188
# [Step 621] Distance to goal: 0.6237
# [Step 622] Distance to goal: 0.6382
# [Step 623] Distance to goal: 0.6508
# [Step 624] Distance to goal: 0.6233
# [Step 625] Distance to goal: 0.6392
# [Step 626] Distance to goal: 0.6281
# [Step 627] Distance to goal: 0.6393
# [Step 628] Distance to goal: 0.6375
# [Step 629] Distance to goal: 0.6197
# [Step 630] Distance to goal: 0.6202
# [Step 631] Distance to goal: 0.6033
# [Step 632] Distance to goal: 0.6215
# [Step 633] Distance to goal: 0.6247
# [Step 634] Distance to goal: 0.6418
# [Step 635] Distance to goal: 0.6474
# [Step 636] Distance to goal: 0.6196
# [Step 637] Distance to goal: 0.5838
# [Step 638] Distance to goal: 0.5626
# [Step 639] Distance to goal: 0.5851
# [Step 640] Distance to goal: 0.6201
# [Step 641] Distance to goal: 0.6062
# [Step 642] Distance to goal: 0.6014
# [Step 643] Distance to goal: 0.5860
# [Step 644] Distance to goal: 0.6079
# [Step 645] Distance to goal: 0.6098
# [Step 646] Distance to goal: 0.5824
# [Step 647] Distance to goal: 0.5572
# [Step 648] Distance to goal: 0.5344
# [Step 649] Distance to goal: 0.5448
# [Step 650] Distance to goal: 0.4618
# [Step 651] Distance to goal: 0.4085
# [Step 652] Distance to goal: 0.4257
# [Step 653] Distance to goal: 0.4326
# [Step 654] Distance to goal: 0.4187
# [Step 655] Distance to goal: 0.3915
# [Step 656] Distance to goal: 0.3747
# [Step 657] Distance to goal: 0.3511
# [Step 658] Distance to goal: 0.3729
# [Step 659] Distance to goal: 0.3573
# [Step 660] Distance to goal: 0.3786
# [Step 661] Distance to goal: 0.4092
# [Step 662] Distance to goal: 0.4218
# [Step 663] Distance to goal: 0.4128
# [Step 664] Distance to goal: 0.3969
# [Step 665] Distance to goal: 0.4258
# [Step 666] Distance to goal: 0.4504
# [Step 667] Distance to goal: 0.4567
# [Step 668] Distance to goal: 0.4391
# [Step 669] Distance to goal: 0.4379
# [Step 670] Distance to goal: 0.4410
# [Step 671] Distance to goal: 0.4500
# [Step 672] Distance to goal: 0.4326
# [Step 673] Distance to goal: 0.4472
# [Step 674] Distance to goal: 0.4193
# [Step 675] Distance to goal: 0.4043
# [Step 676] Distance to goal: 0.4160
# [Step 677] Distance to goal: 0.4586
# [Step 678] Distance to goal: 0.4832
# [Step 679] Distance to goal: 0.4958
# [Step 680] Distance to goal: 0.4795
# [Step 681] Distance to goal: 0.4595
# [Step 682] Distance to goal: 0.4581
# [Step 683] Distance to goal: 0.4672
# [Step 684] Distance to goal: 0.4617
# [Step 685] Distance to goal: 0.4565
# [Step 686] Distance to goal: 0.4324
# [Step 687] Distance to goal: 0.4368
# [Step 688] Distance to goal: 0.4273
# [Step 689] Distance to goal: 0.4147
# [Step 690] Distance to goal: 0.4271
# [Step 691] Distance to goal: 0.4568
# [Step 692] Distance to goal: 0.4757
# [Step 693] Distance to goal: 0.4868
# [Step 694] Distance to goal: 0.5117
# [Step 695] Distance to goal: 0.5338
# [Step 696] Distance to goal: 0.5423
# [Step 697] Distance to goal: 0.5391
# [Step 698] Distance to goal: 0.5428
# [Step 699] Distance to goal: 0.5450
# [Step 700] Distance to goal: 0.4544
# [Step 701] Distance to goal: 0.5167
# [Step 702] Distance to goal: 0.4935
# [Step 703] Distance to goal: 0.4716
# [Step 704] Distance to goal: 0.4423
# [Step 705] Distance to goal: 0.4490
# [Step 706] Distance to goal: 0.4465
# [Step 707] Distance to goal: 0.4389
# [Step 708] Distance to goal: 0.4089
# [Step 709] Distance to goal: 0.4213
# [Step 710] Distance to goal: 0.4150
# [Step 711] Distance to goal: 0.4544
# [Step 712] Distance to goal: 0.4199
# [Step 713] Distance to goal: 0.4197
# [Step 714] Distance to goal: 0.4457
# [Step 715] Distance to goal: 0.4674
# [Step 716] Distance to goal: 0.4545
# [Step 717] Distance to goal: 0.4287
# [Step 718] Distance to goal: 0.4090
# [Step 719] Distance to goal: 0.4064
# [Step 720] Distance to goal: 0.4277
# [Step 721] Distance to goal: 0.4394
# [Step 722] Distance to goal: 0.4184
# [Step 723] Distance to goal: 0.4356
# [Step 724] Distance to goal: 0.4123
# [Step 725] Distance to goal: 0.3819
# [Step 726] Distance to goal: 0.3686
# [Step 727] Distance to goal: 0.3604
# [Step 728] Distance to goal: 0.3605
# [Step 729] Distance to goal: 0.3539
# [Step 730] Distance to goal: 0.3669
# [Step 731] Distance to goal: 0.3702
# [Step 732] Distance to goal: 0.3731
# [Step 733] Distance to goal: 0.3823
# [Step 734] Distance to goal: 0.3764
# [Step 735] Distance to goal: 0.3812
# [Step 736] Distance to goal: 0.3924
# [Step 737] Distance to goal: 0.3786
# [Step 738] Distance to goal: 0.3919
# [Step 739] Distance to goal: 0.4086
# [Step 740] Distance to goal: 0.4194
# [Step 741] Distance to goal: 0.4207
# [Step 742] Distance to goal: 0.4344
# [Step 743] Distance to goal: 0.4484
# [Step 744] Distance to goal: 0.4703
# [Step 745] Distance to goal: 0.4782
# [Step 746] Distance to goal: 0.4736
# [Step 747] Distance to goal: 0.4664
# [Step 748] Distance to goal: 0.4333
# [Step 749] Distance to goal: 0.3977
# [Step 750] Distance to goal: 0.5741
# [Step 751] Distance to goal: 0.5362
# [Step 752] Distance to goal: 0.5458
# [Step 753] Distance to goal: 0.5611
# [Step 754] Distance to goal: 0.5517
# [Step 755] Distance to goal: 0.5491
# [Step 756] Distance to goal: 0.5727
# [Step 757] Distance to goal: 0.5555
# [Step 758] Distance to goal: 0.5212
# [Step 759] Distance to goal: 0.5306
# [Step 760] Distance to goal: 0.5328
# [Step 761] Distance to goal: 0.5216
# [Step 762] Distance to goal: 0.5493
# [Step 763] Distance to goal: 0.5520
# [Step 764] Distance to goal: 0.5715
# [Step 765] Distance to goal: 0.5445
# [Step 766] Distance to goal: 0.5291
# [Step 767] Distance to goal: 0.5159
# [Step 768] Distance to goal: 0.5128
# [Step 769] Distance to goal: 0.5109
# [Step 770] Distance to goal: 0.5126
# [Step 771] Distance to goal: 0.5164
# [Step 772] Distance to goal: 0.5005
# [Step 773] Distance to goal: 0.4659
# [Step 774] Distance to goal: 0.4795
# [Step 775] Distance to goal: 0.4916
# [Step 776] Distance to goal: 0.4906
# [Step 777] Distance to goal: 0.4915
# [Step 778] Distance to goal: 0.4649
# [Step 779] Distance to goal: 0.4773
# [Step 780] Distance to goal: 0.4694
# [Step 781] Distance to goal: 0.5013
# [Step 782] Distance to goal: 0.5324
# [Step 783] Distance to goal: 0.5299
# [Step 784] Distance to goal: 0.5020
# [Step 785] Distance to goal: 0.4873
# [Step 786] Distance to goal: 0.4922
# [Step 787] Distance to goal: 0.5030
# [Step 788] Distance to goal: 0.5228
# [Step 789] Distance to goal: 0.5187
# [Step 790] Distance to goal: 0.5262
# [Step 791] Distance to goal: 0.5167
# [Step 792] Distance to goal: 0.5239
# [Step 793] Distance to goal: 0.5408
# [Step 794] Distance to goal: 0.5759
# [Step 795] Distance to goal: 0.6153
# [Step 796] Distance to goal: 0.6152
# [Step 797] Distance to goal: 0.6249
# [Step 798] Distance to goal: 0.6112
# [Step 799] Distance to goal: 0.6128
# [Step 800] Distance to goal: 0.5038
# [Step 801] Distance to goal: 0.6567
# [Step 802] Distance to goal: 0.6417
# [Step 803] Distance to goal: 0.6632
# [Step 804] Distance to goal: 0.6619
# [Step 805] Distance to goal: 0.6475
# [Step 806] Distance to goal: 0.6316
# [Step 807] Distance to goal: 0.6268
# [Step 808] Distance to goal: 0.6183
# [Step 809] Distance to goal: 0.6400
# [Step 810] Distance to goal: 0.6710
# [Step 811] Distance to goal: 0.6615
# [Step 812] Distance to goal: 0.6661
# [Step 813] Distance to goal: 0.6872
# [Step 814] Distance to goal: 0.7065
# [Step 815] Distance to goal: 0.7265
# [Step 816] Distance to goal: 0.7424
# [Step 817] Distance to goal: 0.7134
# [Step 818] Distance to goal: 0.7403
# [Step 819] Distance to goal: 0.7295
# [Step 820] Distance to goal: 0.7495
# [Step 821] Distance to goal: 0.7542
# [Step 822] Distance to goal: 0.7234
# [Step 823] Distance to goal: 0.7444
# [Step 824] Distance to goal: 0.7533
# [Step 825] Distance to goal: 0.7438
# [Step 826] Distance to goal: 0.7122
# [Step 827] Distance to goal: 0.6877
# [Step 828] Distance to goal: 0.6888
# [Step 829] Distance to goal: 0.7166
# [Step 830] Distance to goal: 0.7037
# [Step 831] Distance to goal: 0.6852
# [Step 832] Distance to goal: 0.6824
# [Step 833] Distance to goal: 0.6960
# [Step 834] Distance to goal: 0.7135
# [Step 835] Distance to goal: 0.7280
# [Step 836] Distance to goal: 0.7311
# [Step 837] Distance to goal: 0.7475
# [Step 838] Distance to goal: 0.7700
# [Step 839] Distance to goal: 0.7849
# [Step 840] Distance to goal: 0.8077
# [Step 841] Distance to goal: 0.8060
# [Step 842] Distance to goal: 0.8133
# [Step 843] Distance to goal: 0.8277
# [Step 844] Distance to goal: 0.8454
# [Step 845] Distance to goal: 0.8637
# [Step 846] Distance to goal: 0.8745
# [Step 847] Distance to goal: 0.8958
# [Step 848] Distance to goal: 0.9086
# [Step 849] Distance to goal: 0.9033
# [Step 850] Distance to goal: 0.6480
# [Step 851] Distance to goal: 0.6523
# [Step 852] Distance to goal: 0.6333
# [Step 853] Distance to goal: 0.6393
# [Step 854] Distance to goal: 0.6424
# [Step 855] Distance to goal: 0.6173
# [Step 856] Distance to goal: 0.6373
# [Step 857] Distance to goal: 0.6284
# [Step 858] Distance to goal: 0.6349
# [Step 859] Distance to goal: 0.6640
# [Step 860] Distance to goal: 0.6628
# [Step 861] Distance to goal: 0.6725
# [Step 862] Distance to goal: 0.6945
# [Step 863] Distance to goal: 0.7014
# [Step 864] Distance to goal: 0.7078
# [Step 865] Distance to goal: 0.6934
# [Step 866] Distance to goal: 0.7215
# [Step 867] Distance to goal: 0.7037
# [Step 868] Distance to goal: 0.7301
# [Step 869] Distance to goal: 0.7122
# [Step 870] Distance to goal: 0.7167
# [Step 871] Distance to goal: 0.6988
# [Step 872] Distance to goal: 0.6938
# [Step 873] Distance to goal: 0.6969
# [Step 874] Distance to goal: 0.7190
# [Step 875] Distance to goal: 0.6827
# [Step 876] Distance to goal: 0.6720
# [Step 877] Distance to goal: 0.6766
# [Step 878] Distance to goal: 0.6549
# [Step 879] Distance to goal: 0.6367
# [Step 880] Distance to goal: 0.6238
# [Step 881] Distance to goal: 0.6203
# [Step 882] Distance to goal: 0.6204
# [Step 883] Distance to goal: 0.6425
# [Step 884] Distance to goal: 0.6731
# [Step 885] Distance to goal: 0.7093
# [Step 886] Distance to goal: 0.7218
# [Step 887] Distance to goal: 0.7108
# [Step 888] Distance to goal: 0.7289
# [Step 889] Distance to goal: 0.7362
# [Step 890] Distance to goal: 0.7103
# [Step 891] Distance to goal: 0.7276
# [Step 892] Distance to goal: 0.7304
# [Step 893] Distance to goal: 0.7130
# [Step 894] Distance to goal: 0.7304
# [Step 895] Distance to goal: 0.7489
# [Step 896] Distance to goal: 0.7806
# [Step 897] Distance to goal: 0.7800
# [Step 898] Distance to goal: 0.7578
# [Step 899] Distance to goal: 0.7500
# [Step 900] Distance to goal: 0.6211
# [Step 901] Distance to goal: 0.5152
# [Step 902] Distance to goal: 0.5478
# [Step 903] Distance to goal: 0.5605
# [Step 904] Distance to goal: 0.5645
# [Step 905] Distance to goal: 0.5646
# [Step 906] Distance to goal: 0.5540
# [Step 907] Distance to goal: 0.5405
# [Step 908] Distance to goal: 0.5286
# [Step 909] Distance to goal: 0.5507
# [Step 910] Distance to goal: 0.5294
# [Step 911] Distance to goal: 0.5069
# [Step 912] Distance to goal: 0.4860
# [Step 913] Distance to goal: 0.5065
# [Step 914] Distance to goal: 0.5239
# [Step 915] Distance to goal: 0.5070
# [Step 916] Distance to goal: 0.5011
# [Step 917] Distance to goal: 0.4745
# [Step 918] Distance to goal: 0.4852
# [Step 919] Distance to goal: 0.5051
# [Step 920] Distance to goal: 0.5310
# [Step 921] Distance to goal: 0.5707
# [Step 922] Distance to goal: 0.5884
# [Step 923] Distance to goal: 0.5887
# [Step 924] Distance to goal: 0.5782
# [Step 925] Distance to goal: 0.5549
# [Step 926] Distance to goal: 0.5502
# [Step 927] Distance to goal: 0.5708
# [Step 928] Distance to goal: 0.5707
# [Step 929] Distance to goal: 0.5910
# [Step 930] Distance to goal: 0.6194
# [Step 931] Distance to goal: 0.6465
# [Step 932] Distance to goal: 0.6238
# [Step 933] Distance to goal: 0.6103
# [Step 934] Distance to goal: 0.6374
# [Step 935] Distance to goal: 0.6422
# [Step 936] Distance to goal: 0.6584
# [Step 937] Distance to goal: 0.6611
# [Step 938] Distance to goal: 0.6717
# [Step 939] Distance to goal: 0.6733
# [Step 940] Distance to goal: 0.6922
# [Step 941] Distance to goal: 0.6626
# [Step 942] Distance to goal: 0.6826
# [Step 943] Distance to goal: 0.6853
# [Step 944] Distance to goal: 0.7033
# [Step 945] Distance to goal: 0.7075
# [Step 946] Distance to goal: 0.7325
# [Step 947] Distance to goal: 0.7389
# [Step 948] Distance to goal: 0.7816
# [Step 949] Distance to goal: 0.7973
# [Step 950] Distance to goal: 0.5118
# [Step 951] Distance to goal: 0.5090
# [Step 952] Distance to goal: 0.5056
# [Step 953] Distance to goal: 0.5366
# [Step 954] Distance to goal: 0.5243
# [Step 955] Distance to goal: 0.5099
# [Step 956] Distance to goal: 0.5364
# [Step 957] Distance to goal: 0.5212
# [Step 958] Distance to goal: 0.4950
# [Step 959] Distance to goal: 0.5246
# [Step 960] Distance to goal: 0.5237
# [Step 961] Distance to goal: 0.5480
# [Step 962] Distance to goal: 0.5173
# [Step 963] Distance to goal: 0.5372
# [Step 964] Distance to goal: 0.5439
# [Step 965] Distance to goal: 0.5528
# [Step 966] Distance to goal: 0.5628
# [Step 967] Distance to goal: 0.5903
# [Step 968] Distance to goal: 0.5960
# [Step 969] Distance to goal: 0.5689
# [Step 970] Distance to goal: 0.5572
# [Step 971] Distance to goal: 0.5669
# [Step 972] Distance to goal: 0.5701
# [Step 973] Distance to goal: 0.5788
# [Step 974] Distance to goal: 0.6170
# [Step 975] Distance to goal: 0.6344
# [Step 976] Distance to goal: 0.6529
# [Step 977] Distance to goal: 0.6335
# [Step 978] Distance to goal: 0.6052
# [Step 979] Distance to goal: 0.6004
# [Step 980] Distance to goal: 0.6016
# [Step 981] Distance to goal: 0.6035
# [Step 982] Distance to goal: 0.6019
# [Step 983] Distance to goal: 0.5771
# [Step 984] Distance to goal: 0.5409
# [Step 985] Distance to goal: 0.5276
# [Step 986] Distance to goal: 0.5376
# [Step 987] Distance to goal: 0.5367
# [Step 988] Distance to goal: 0.5512
# [Step 989] Distance to goal: 0.5478
# [Step 990] Distance to goal: 0.5820
# [Step 991] Distance to goal: 0.6018
# [Step 992] Distance to goal: 0.6121
# [Step 993] Distance to goal: 0.6453
# [Step 994] Distance to goal: 0.6629
# [Step 995] Distance to goal: 0.6692
# [Step 996] Distance to goal: 0.6817
# [Step 997] Distance to goal: 0.7103
# [Step 998] Distance to goal: 0.7246
# [Step 999] Distance to goal: 0.7278
# [Step 1000] Distance to goal: 0.5399
# [Step 1001] Distance to goal: 0.5818
# [Step 1002] Distance to goal: 0.6112
# [Step 1003] Distance to goal: 0.6246
# [Step 1004] Distance to goal: 0.6250
# [Step 1005] Distance to goal: 0.6176
# [Step 1006] Distance to goal: 0.6193
# [Step 1007] Distance to goal: 0.6402
# [Step 1008] Distance to goal: 0.6496
# [Step 1009] Distance to goal: 0.6461
# [Step 1010] Distance to goal: 0.6510
# [Step 1011] Distance to goal: 0.6823
# [Step 1012] Distance to goal: 0.6549
# [Step 1013] Distance to goal: 0.6608
# [Step 1014] Distance to goal: 0.6567
# [Step 1015] Distance to goal: 0.6520
# [Step 1016] Distance to goal: 0.6549
# [Step 1017] Distance to goal: 0.6809
# [Step 1018] Distance to goal: 0.7052
# [Step 1019] Distance to goal: 0.7366
# [Step 1020] Distance to goal: 0.7332
# [Step 1021] Distance to goal: 0.7409
# [Step 1022] Distance to goal: 0.7583
# [Step 1023] Distance to goal: 0.7692
# [Step 1024] Distance to goal: 0.7770
# [Step 1025] Distance to goal: 0.7897
# [Step 1026] Distance to goal: 0.7877
# [Step 1027] Distance to goal: 0.7865
# [Step 1028] Distance to goal: 0.7828
# [Step 1029] Distance to goal: 0.7950
# [Step 1030] Distance to goal: 0.8048
# [Step 1031] Distance to goal: 0.7925
# [Step 1032] Distance to goal: 0.7956
# [Step 1033] Distance to goal: 0.8106
# [Step 1034] Distance to goal: 0.8275
# [Step 1035] Distance to goal: 0.8649
# [Step 1036] Distance to goal: 0.8974
# [Step 1037] Distance to goal: 0.8659
# [Step 1038] Distance to goal: 0.8612
# [Step 1039] Distance to goal: 0.8566
# [Step 1040] Distance to goal: 0.8482
# [Step 1041] Distance to goal: 0.8540
# [Step 1042] Distance to goal: 0.8640
# [Step 1043] Distance to goal: 0.8471
# [Step 1044] Distance to goal: 0.8398
# [Step 1045] Distance to goal: 0.8257
# [Step 1046] Distance to goal: 0.8298
# [Step 1047] Distance to goal: 0.8089
# [Step 1048] Distance to goal: 0.8016
# [Step 1049] Distance to goal: 0.7858
# [Step 1050] Distance to goal: 0.5769
# [Step 1051] Distance to goal: 0.5811
# [Step 1052] Distance to goal: 0.5791
# [Step 1053] Distance to goal: 0.5474
# [Step 1054] Distance to goal: 0.5353
# [Step 1055] Distance to goal: 0.5185
# [Step 1056] Distance to goal: 0.5330
# [Step 1057] Distance to goal: 0.5703
# [Step 1058] Distance to goal: 0.5822
# [Step 1059] Distance to goal: 0.6040
# [Step 1060] Distance to goal: 0.6200
# [Step 1061] Distance to goal: 0.6000
# [Step 1062] Distance to goal: 0.5807
# [Step 1063] Distance to goal: 0.6068
# [Step 1064] Distance to goal: 0.5803
# [Step 1065] Distance to goal: 0.5632
# [Step 1066] Distance to goal: 0.5358
# [Step 1067] Distance to goal: 0.5309
# [Step 1068] Distance to goal: 0.5552
# [Step 1069] Distance to goal: 0.5996
# [Step 1070] Distance to goal: 0.6044
# [Step 1071] Distance to goal: 0.5901
# [Step 1072] Distance to goal: 0.6056
# [Step 1073] Distance to goal: 0.5931
# [Step 1074] Distance to goal: 0.6005
# [Step 1075] Distance to goal: 0.6273
# [Step 1076] Distance to goal: 0.6269
# [Step 1077] Distance to goal: 0.6186
# [Step 1078] Distance to goal: 0.6104
# [Step 1079] Distance to goal: 0.6150
# [Step 1080] Distance to goal: 0.5956
# [Step 1081] Distance to goal: 0.5714
# [Step 1082] Distance to goal: 0.5517
# [Step 1083] Distance to goal: 0.5531
# [Step 1084] Distance to goal: 0.5356
# [Step 1085] Distance to goal: 0.5291
# [Step 1086] Distance to goal: 0.5199
# [Step 1087] Distance to goal: 0.5209
# [Step 1088] Distance to goal: 0.5215
# [Step 1089] Distance to goal: 0.4968
# [Step 1090] Distance to goal: 0.5016
# [Step 1091] Distance to goal: 0.4921
# [Step 1092] Distance to goal: 0.5036
# [Step 1093] Distance to goal: 0.4814
# [Step 1094] Distance to goal: 0.4820
# [Step 1095] Distance to goal: 0.5128
# [Step 1096] Distance to goal: 0.5233
# [Step 1097] Distance to goal: 0.5242
# [Step 1098] Distance to goal: 0.4955
# [Step 1099] Distance to goal: 0.4783
# [Step 1100] Distance to goal: 0.5900
# [Step 1101] Distance to goal: 0.5130
# [Step 1102] Distance to goal: 0.4975
# [Step 1103] Distance to goal: 0.5088
# [Step 1104] Distance to goal: 0.4977
# [Step 1105] Distance to goal: 0.5124
# [Step 1106] Distance to goal: 0.4900
# [Step 1107] Distance to goal: 0.5078
# [Step 1108] Distance to goal: 0.4938
# [Step 1109] Distance to goal: 0.4793
# [Step 1110] Distance to goal: 0.4652
# [Step 1111] Distance to goal: 0.4698
# [Step 1112] Distance to goal: 0.4594
# [Step 1113] Distance to goal: 0.4400
# [Step 1114] Distance to goal: 0.4168
# [Step 1115] Distance to goal: 0.4275
# [Step 1116] Distance to goal: 0.4525
# [Step 1117] Distance to goal: 0.4731
# [Step 1118] Distance to goal: 0.4515
# [Step 1119] Distance to goal: 0.4716
# [Step 1120] Distance to goal: 0.4927
# [Step 1121] Distance to goal: 0.4674
# [Step 1122] Distance to goal: 0.4690
# [Step 1123] Distance to goal: 0.4666
# [Step 1124] Distance to goal: 0.4972
# [Step 1125] Distance to goal: 0.4986
# [Step 1126] Distance to goal: 0.5024
# [Step 1127] Distance to goal: 0.4690
# [Step 1128] Distance to goal: 0.4376
# [Step 1129] Distance to goal: 0.4307
# [Step 1130] Distance to goal: 0.4435
# [Step 1131] Distance to goal: 0.4609
# [Step 1132] Distance to goal: 0.4428
# [Step 1133] Distance to goal: 0.4332
# [Step 1134] Distance to goal: 0.4568
# [Step 1135] Distance to goal: 0.4443
# [Step 1136] Distance to goal: 0.4301
# [Step 1137] Distance to goal: 0.4306
# [Step 1138] Distance to goal: 0.4173
# [Step 1139] Distance to goal: 0.4363
# [Step 1140] Distance to goal: 0.4596
# [Step 1141] Distance to goal: 0.4703
# [Step 1142] Distance to goal: 0.4757
# [Step 1143] Distance to goal: 0.4764
# [Step 1144] Distance to goal: 0.4835
# [Step 1145] Distance to goal: 0.4774
# [Step 1146] Distance to goal: 0.5016
# [Step 1147] Distance to goal: 0.4831
# [Step 1148] Distance to goal: 0.5062
# [Step 1149] Distance to goal: 0.5400
# [Step 1150] Distance to goal: 0.4695
# [Step 1151] Distance to goal: 0.5269
# [Step 1152] Distance to goal: 0.5277
# [Step 1153] Distance to goal: 0.5213
# [Step 1154] Distance to goal: 0.5028
# [Step 1155] Distance to goal: 0.5062
# [Step 1156] Distance to goal: 0.5021
# [Step 1157] Distance to goal: 0.4891
# [Step 1158] Distance to goal: 0.4847
# [Step 1159] Distance to goal: 0.4965
# [Step 1160] Distance to goal: 0.5380
# [Step 1161] Distance to goal: 0.5313
# [Step 1162] Distance to goal: 0.5408
# [Step 1163] Distance to goal: 0.5725
# [Step 1164] Distance to goal: 0.5701
# [Step 1165] Distance to goal: 0.6128
# [Step 1166] Distance to goal: 0.6189
# [Step 1167] Distance to goal: 0.6192
# [Step 1168] Distance to goal: 0.6415
# [Step 1169] Distance to goal: 0.6823
# [Step 1170] Distance to goal: 0.6740
# [Step 1171] Distance to goal: 0.6987
# [Step 1172] Distance to goal: 0.7032
# [Step 1173] Distance to goal: 0.7228
# [Step 1174] Distance to goal: 0.7108
# [Step 1175] Distance to goal: 0.7213
# [Step 1176] Distance to goal: 0.7292
# [Step 1177] Distance to goal: 0.7344
# [Step 1178] Distance to goal: 0.7556
# [Step 1179] Distance to goal: 0.7648
# [Step 1180] Distance to goal: 0.7686
# [Step 1181] Distance to goal: 0.7705
# [Step 1182] Distance to goal: 0.7737
# [Step 1183] Distance to goal: 0.7998
# [Step 1184] Distance to goal: 0.8160
# [Step 1185] Distance to goal: 0.8235
# [Step 1186] Distance to goal: 0.8158
# [Step 1187] Distance to goal: 0.8183
# [Step 1188] Distance to goal: 0.8011
# [Step 1189] Distance to goal: 0.8020
# [Step 1190] Distance to goal: 0.8296
# [Step 1191] Distance to goal: 0.7903
# [Step 1192] Distance to goal: 0.7708
# [Step 1193] Distance to goal: 0.7458
# [Step 1194] Distance to goal: 0.7547
# [Step 1195] Distance to goal: 0.7523
# [Step 1196] Distance to goal: 0.7701
# [Step 1197] Distance to goal: 0.7449
# [Step 1198] Distance to goal: 0.7724
# [Step 1199] Distance to goal: 0.7618
# [Step 1200] Distance to goal: 0.5553
# [Step 1201] Distance to goal: 0.4555
# [Step 1202] Distance to goal: 0.4277
# [Step 1203] Distance to goal: 0.3979
# [Step 1204] Distance to goal: 0.3839
# [Step 1205] Distance to goal: 0.3465
# [Step 1206] Distance to goal: 0.3321
# [Step 1207] Distance to goal: 0.3526
# [Step 1208] Distance to goal: 0.3471
# [Step 1209] Distance to goal: 0.3417
# [Step 1210] Distance to goal: 0.3232
# [Step 1211] Distance to goal: 0.3439
# [Step 1212] Distance to goal: 0.3313
# [Step 1213] Distance to goal: 0.3492
# [Step 1214] Distance to goal: 0.3289
# [Step 1215] Distance to goal: 0.3231
# [Step 1216] Distance to goal: 0.3526
# [Step 1217] Distance to goal: 0.3561
# [Step 1218] Distance to goal: 0.3293
# [Step 1219] Distance to goal: 0.3444
# [Step 1220] Distance to goal: 0.3354
# [Step 1221] Distance to goal: 0.3265
# [Step 1222] Distance to goal: 0.3384
# [Step 1223] Distance to goal: 0.3055
# [Step 1224] Distance to goal: 0.2808
# [Step 1225] Distance to goal: 0.3095
# [Step 1226] Distance to goal: 0.3050
# [Step 1227] Distance to goal: 0.2698
# [Step 1228] Distance to goal: 0.2815
# [Step 1229] Distance to goal: 0.2952
# [Step 1230] Distance to goal: 0.2998
# [Step 1231] Distance to goal: 0.2712
# [Step 1232] Distance to goal: 0.2698
# [Step 1233] Distance to goal: 0.2950
# [Step 1234] Distance to goal: 0.3199
# [Step 1235] Distance to goal: 0.3199
# [Step 1236] Distance to goal: 0.2959
# [Step 1237] Distance to goal: 0.3242
# [Step 1238] Distance to goal: 0.3121
# [Step 1239] Distance to goal: 0.3199
# [Step 1240] Distance to goal: 0.3341
# [Step 1241] Distance to goal: 0.3331
# [Step 1242] Distance to goal: 0.3455
# [Step 1243] Distance to goal: 0.3359
# [Step 1244] Distance to goal: 0.3634
# [Step 1245] Distance to goal: 0.3895
# [Step 1246] Distance to goal: 0.3748
# [Step 1247] Distance to goal: 0.3505
# [Step 1248] Distance to goal: 0.3590
# [Step 1249] Distance to goal: 0.3555
# [Step 1250] Distance to goal: 0.5005
# [Step 1251] Distance to goal: 0.6186
# [Step 1252] Distance to goal: 0.5959
# [Step 1253] Distance to goal: 0.6058
# [Step 1254] Distance to goal: 0.6009
# [Step 1255] Distance to goal: 0.5943
# [Step 1256] Distance to goal: 0.6117
# [Step 1257] Distance to goal: 0.6085
# [Step 1258] Distance to goal: 0.5753
# [Step 1259] Distance to goal: 0.5725
# [Step 1260] Distance to goal: 0.5504
# [Step 1261] Distance to goal: 0.5551
# [Step 1262] Distance to goal: 0.5385
# [Step 1263] Distance to goal: 0.5425
# [Step 1264] Distance to goal: 0.5403
# [Step 1265] Distance to goal: 0.5539
# [Step 1266] Distance to goal: 0.5461
# [Step 1267] Distance to goal: 0.5241
# [Step 1268] Distance to goal: 0.5110
# [Step 1269] Distance to goal: 0.5342
# [Step 1270] Distance to goal: 0.5295
# [Step 1271] Distance to goal: 0.5426
# [Step 1272] Distance to goal: 0.5611
# [Step 1273] Distance to goal: 0.5920
# [Step 1274] Distance to goal: 0.6136
# [Step 1275] Distance to goal: 0.5999
# [Step 1276] Distance to goal: 0.6035
# [Step 1277] Distance to goal: 0.6022
# [Step 1278] Distance to goal: 0.5817
# [Step 1279] Distance to goal: 0.5898
# [Step 1280] Distance to goal: 0.5797
# [Step 1281] Distance to goal: 0.5627
# [Step 1282] Distance to goal: 0.5491
# [Step 1283] Distance to goal: 0.5503
# [Step 1284] Distance to goal: 0.5646
# [Step 1285] Distance to goal: 0.5846
# [Step 1286] Distance to goal: 0.6001
# [Step 1287] Distance to goal: 0.5788
# [Step 1288] Distance to goal: 0.5745
# [Step 1289] Distance to goal: 0.5656
# [Step 1290] Distance to goal: 0.5541
# [Step 1291] Distance to goal: 0.5553
# [Step 1292] Distance to goal: 0.5666
# [Step 1293] Distance to goal: 0.5643
# [Step 1294] Distance to goal: 0.5735
# [Step 1295] Distance to goal: 0.6055
# [Step 1296] Distance to goal: 0.5995
# [Step 1297] Distance to goal: 0.5744
# [Step 1298] Distance to goal: 0.5867
# [Step 1299] Distance to goal: 0.5879
# [Step 1300] Distance to goal: 0.6138
# [Step 1301] Distance to goal: 0.7018
# [Step 1302] Distance to goal: 0.6956
# [Step 1303] Distance to goal: 0.6618
# [Step 1304] Distance to goal: 0.6639
# [Step 1305] Distance to goal: 0.6715
# [Step 1306] Distance to goal: 0.6862
# [Step 1307] Distance to goal: 0.6950
# [Step 1308] Distance to goal: 0.6799
# [Step 1309] Distance to goal: 0.6844
# [Step 1310] Distance to goal: 0.6587
# [Step 1311] Distance to goal: 0.6846
# [Step 1312] Distance to goal: 0.7020
# [Step 1313] Distance to goal: 0.6847
# [Step 1314] Distance to goal: 0.6845
# [Step 1315] Distance to goal: 0.6639
# [Step 1316] Distance to goal: 0.6403
# [Step 1317] Distance to goal: 0.6437
# [Step 1318] Distance to goal: 0.6332
# [Step 1319] Distance to goal: 0.6087
# [Step 1320] Distance to goal: 0.6216
# [Step 1321] Distance to goal: 0.6055
# [Step 1322] Distance to goal: 0.5939
# [Step 1323] Distance to goal: 0.5766
# [Step 1324] Distance to goal: 0.6084
# [Step 1325] Distance to goal: 0.6008
# [Step 1326] Distance to goal: 0.6182
# ...
# [HER Sample] Mean reward in batch: 0.357
# [Episode Done @ Step 92999] Reward: -23.582, Success: 0.0, MA(50): 0.00
# [Step 93000] WM: 0.0099, Critic: 0.0199, Actor: -0.6689
# Returns mean: 0.6515, ValPreds mean: 0.6698
# [Episode Done @ Step 93049] Reward: -24.064, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93099] Reward: -33.947, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.210
# [Episode Done @ Step 93149] Reward: -28.867, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93199] Reward: -33.325, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.309
# [HER Sample] Mean reward in batch: 0.299
# [HER Sample] Mean reward in batch: 0.393
# [Episode Done @ Step 93249] Reward: -32.951, Success: 0.0, MA(50): 0.00
# [Step 93250] WM: 0.0072, Critic: 0.0187, Actor: -0.6519
# Returns mean: 0.6486, ValPreds mean: 0.6549
# [Episode Done @ Step 93299] Reward: -28.810, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93349] Reward: -27.659, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93399] Reward: -17.888, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93449] Reward: -27.643, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93499] Reward: -26.199, Success: 0.0, MA(50): 0.00
# [Step 93500] WM: 0.0124, Critic: 0.0187, Actor: -0.6139
# Returns mean: 0.6155, ValPreds mean: 0.6135
# [Episode Done @ Step 93549] Reward: -30.982, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.318
# [HER Sample] Mean reward in batch: 0.174
# [HER Sample] Mean reward in batch: 0.178
# [Episode Done @ Step 93599] Reward: -26.467, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.318
# [Episode Done @ Step 93649] Reward: -22.190, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93699] Reward: -26.352, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93749] Reward: -25.674, Success: 0.0, MA(50): 0.00
# [Step 93750] WM: 0.0110, Critic: 0.0187, Actor: -0.6730
# Returns mean: 0.6794, ValPreds mean: 0.6730
# [Episode Done @ Step 93799] Reward: -32.600, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93849] Reward: -20.687, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93899] Reward: -31.031, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93949] Reward: -27.015, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 93999] Reward: -26.979, Success: 0.0, MA(50): 0.00
# [Step 94000] WM: 0.0149, Critic: 0.0181, Actor: -0.6576
# Returns mean: 0.6486, ValPreds mean: 0.6540
# [Episode Done @ Step 94049] Reward: -34.843, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.294
# [HER Sample] Mean reward in batch: 0.335
# [Episode Done @ Step 94099] Reward: -31.993, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.341
# [Episode Done @ Step 94149] Reward: -23.804, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 94199] Reward: -33.724, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.412
# [HER Sample] Mean reward in batch: 0.283
# [Episode Done @ Step 94249] Reward: -22.875, Success: 0.0, MA(50): 0.00
# [Step 94250] WM: 0.0131, Critic: 0.0270, Actor: -0.6709
# Returns mean: 0.6671, ValPreds mean: 0.6665
# [Episode Done @ Step 94299] Reward: -18.660, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 94349] Reward: -33.512, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.306
# [HER Sample] Mean reward in batch: 0.349
# [Episode Done @ Step 94399] Reward: -26.096, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 94449] Reward: -22.647, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.306
# [HER Sample] Mean reward in batch: 0.275
# [Episode Done @ Step 94499] Reward: -17.421, Success: 0.0, MA(50): 0.00
# [Step 94500] WM: 0.0179, Critic: 0.0175, Actor: -0.6611
# Returns mean: 0.6511, ValPreds mean: 0.6602
# [HER Sample] Mean reward in batch: 0.281
# [Episode Done @ Step 94549] Reward: -26.975, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.233
# [HER Sample] Mean reward in batch: 0.296
# [Episode Done @ Step 94599] Reward: -28.743, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.208
# [HER Sample] Mean reward in batch: 0.332
# [Episode Done @ Step 94649] Reward: -20.123, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 94699] Reward: -27.587, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 94749] Reward: -29.602, Success: 0.0, MA(50): 0.00
# [Step 94750] WM: 0.0239, Critic: 0.0196, Actor: -0.6676
# Returns mean: 0.6599, ValPreds mean: 0.6719
# [Episode Done @ Step 94799] Reward: -33.432, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 94849] Reward: -28.667, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.362
# [Episode Done @ Step 94899] Reward: -22.706, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 94949] Reward: -25.722, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 94999] Reward: -30.537, Success: 0.0, MA(50): 0.00
# [Step 95000] WM: 0.0134, Critic: 0.0142, Actor: -0.6731
# Returns mean: 0.6721, ValPreds mean: 0.6817
# [Episode Done @ Step 95049] Reward: -34.282, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.415
# [HER Sample] Mean reward in batch: 0.319
# [Episode Done @ Step 95099] Reward: -23.868, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.351
# [HER Sample] Mean reward in batch: 0.347
# [Episode Done @ Step 95149] Reward: -24.939, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95199] Reward: -27.376, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95249] Reward: -30.429, Success: 0.0, MA(50): 0.00
# [Step 95250] WM: 0.0131, Critic: 0.0188, Actor: -0.6706
# Returns mean: 0.6603, ValPreds mean: 0.6739
# [Episode Done @ Step 95299] Reward: -33.268, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.342
# [Episode Done @ Step 95349] Reward: -22.232, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95399] Reward: -26.981, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95449] Reward: -33.445, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95499] Reward: -29.747, Success: 0.0, MA(50): 0.00
# [Step 95500] WM: 0.0137, Critic: 0.0211, Actor: -0.6616
# Returns mean: 0.6728, ValPreds mean: 0.6660
# [HER Sample] Mean reward in batch: 0.328
# [Episode Done @ Step 95549] Reward: -26.594, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.222
# [HER Sample] Mean reward in batch: 0.277
# [Episode Done @ Step 95599] Reward: -32.216, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95649] Reward: -30.049, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95699] Reward: -33.213, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95749] Reward: -29.211, Success: 0.0, MA(50): 0.00
# [Step 95750] WM: 0.0146, Critic: 0.0179, Actor: -0.6818
# Returns mean: 0.6831, ValPreds mean: 0.6811
# [Episode Done @ Step 95799] Reward: -32.290, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95849] Reward: -26.956, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.301
# [Episode Done @ Step 95899] Reward: -29.820, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.365
# [Episode Done @ Step 95949] Reward: -27.519, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 95999] Reward: -32.316, Success: 0.0, MA(50): 0.00
# [Step 96000] WM: 0.0216, Critic: 0.0196, Actor: -0.6763
# Returns mean: 0.6820, ValPreds mean: 0.6701
# [Episode Done @ Step 96049] Reward: -22.304, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.235
# [Episode Done @ Step 96099] Reward: -33.802, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96149] Reward: -33.021, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.309
# [Episode Done @ Step 96199] Reward: -20.323, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.237
# [Episode Done @ Step 96249] Reward: -24.631, Success: 0.0, MA(50): 0.00
# [Step 96250] WM: 0.0073, Critic: 0.0239, Actor: -0.6852
# Returns mean: 0.6962, ValPreds mean: 0.6837
# [HER Sample] Mean reward in batch: 0.292
# [HER Sample] Mean reward in batch: 0.270
# [Episode Done @ Step 96299] Reward: -29.548, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.293
# [Episode Done @ Step 96349] Reward: -31.626, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96399] Reward: -33.359, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96449] Reward: -28.223, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96499] Reward: -26.649, Success: 0.0, MA(50): 0.00
# [Step 96500] WM: 0.0127, Critic: 0.0147, Actor: -0.6624
# Returns mean: 0.6513, ValPreds mean: 0.6624
# [Episode Done @ Step 96549] Reward: -24.026, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96599] Reward: -26.657, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96649] Reward: -28.365, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.293
# [HER Sample] Mean reward in batch: 0.369
# [Episode Done @ Step 96699] Reward: -35.254, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96749] Reward: -26.827, Success: 0.0, MA(50): 0.00
# [Step 96750] WM: 0.0200, Critic: 0.0191, Actor: -0.6486
# Returns mean: 0.6505, ValPreds mean: 0.6437
# [Episode Done @ Step 96799] Reward: -26.831, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96849] Reward: -22.815, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96899] Reward: -29.637, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96949] Reward: -26.504, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 96999] Reward: -26.677, Success: 0.0, MA(50): 0.00
# [Step 97000] WM: 0.0209, Critic: 0.0209, Actor: -0.6942
# Returns mean: 0.6781, ValPreds mean: 0.6893
# [HER Sample] Mean reward in batch: 0.370
# [Episode Done @ Step 97049] Reward: -24.482, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97099] Reward: -23.966, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.238
# [Episode Done @ Step 97149] Reward: -30.782, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97199] Reward: -28.180, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.322
# [Episode Done @ Step 97249] Reward: -29.877, Success: 0.0, MA(50): 0.00
# [Step 97250] WM: 0.0122, Critic: 0.0213, Actor: -0.6745
# Returns mean: 0.6934, ValPreds mean: 0.6748
# [Episode Done @ Step 97299] Reward: -33.926, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.313
# [HER Sample] Mean reward in batch: 0.364
# [Episode Done @ Step 97349] Reward: -20.072, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97399] Reward: -28.898, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.234
# [Episode Done @ Step 97449] Reward: -23.843, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97499] Reward: -27.333, Success: 0.0, MA(50): 0.00
# [Step 97500] WM: 0.0164, Critic: 0.0158, Actor: -0.6791
# Returns mean: 0.6639, ValPreds mean: 0.6844
# [Episode Done @ Step 97549] Reward: -29.754, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.303
# [Episode Done @ Step 97599] Reward: -23.365, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97649] Reward: -24.107, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.334
# [HER Sample] Mean reward in batch: 0.314
# [HER Sample] Mean reward in batch: 0.307
# [Episode Done @ Step 97699] Reward: -24.804, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97749] Reward: -34.078, Success: 0.0, MA(50): 0.00
# [Step 97750] WM: 0.0124, Critic: 0.0260, Actor: -0.6820
# Returns mean: 0.6896, ValPreds mean: 0.6838
# [Episode Done @ Step 97799] Reward: -33.289, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97849] Reward: -18.164, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97899] Reward: -24.722, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 97949] Reward: -28.021, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.260
# [Episode Done @ Step 97999] Reward: -33.479, Success: 0.0, MA(50): 0.00
# [Step 98000] WM: 0.0126, Critic: 0.0175, Actor: -0.7032
# Returns mean: 0.6917, ValPreds mean: 0.7078
# [Episode Done @ Step 98049] Reward: -30.622, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.365
# [HER Sample] Mean reward in batch: 0.253
# [HER Sample] Mean reward in batch: 0.288
# [Episode Done @ Step 98099] Reward: -26.373, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98149] Reward: -24.623, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98199] Reward: -24.632, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98249] Reward: -28.019, Success: 0.0, MA(50): 0.00
# [Step 98250] WM: 0.0173, Critic: 0.0145, Actor: -0.6358
# Returns mean: 0.6431, ValPreds mean: 0.6368
# [Episode Done @ Step 98299] Reward: -25.904, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98349] Reward: -22.003, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.240
# [Episode Done @ Step 98399] Reward: -27.183, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98449] Reward: -25.156, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98499] Reward: -24.142, Success: 0.0, MA(50): 0.00
# [Step 98500] WM: 0.0120, Critic: 0.0169, Actor: -0.6803
# Returns mean: 0.6664, ValPreds mean: 0.6749
# [Episode Done @ Step 98549] Reward: -30.640, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.270
# [Episode Done @ Step 98599] Reward: -33.520, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98649] Reward: -22.710, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98699] Reward: -31.350, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.314
# [Episode Done @ Step 98749] Reward: -23.757, Success: 0.0, MA(50): 0.00
# [Step 98750] WM: 0.0156, Critic: 0.0153, Actor: -0.7232
# Returns mean: 0.7148, ValPreds mean: 0.7242
# [HER Sample] Mean reward in batch: 0.224
# [HER Sample] Mean reward in batch: 0.206
# [Episode Done @ Step 98799] Reward: -34.809, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98849] Reward: -25.132, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.285
# [HER Sample] Mean reward in batch: 0.250
# [Episode Done @ Step 98899] Reward: -27.421, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 98949] Reward: -23.980, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.320
# [Episode Done @ Step 98999] Reward: -21.972, Success: 0.0, MA(50): 0.00
# [Step 99000] WM: 0.0152, Critic: 0.0228, Actor: -0.6885
# Returns mean: 0.6890, ValPreds mean: 0.6822
# [HER Sample] Mean reward in batch: 0.332
# [Episode Done @ Step 99049] Reward: -25.461, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99099] Reward: -31.103, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99149] Reward: -25.282, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99199] Reward: -31.943, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99249] Reward: -26.472, Success: 0.0, MA(50): 0.00
# [Step 99250] WM: 0.0117, Critic: 0.0159, Actor: -0.6612
# Returns mean: 0.6770, ValPreds mean: 0.6621
# [Episode Done @ Step 99299] Reward: -19.823, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.285
# [Episode Done @ Step 99349] Reward: -28.679, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99399] Reward: -27.297, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.324
# [HER Sample] Mean reward in batch: 0.377
# [Episode Done @ Step 99449] Reward: -28.022, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.280
# [Episode Done @ Step 99499] Reward: -25.863, Success: 0.0, MA(50): 0.00
# [Step 99500] WM: 0.0119, Critic: 0.0176, Actor: -0.7062
# Returns mean: 0.7138, ValPreds mean: 0.7051
# [Episode Done @ Step 99549] Reward: -29.106, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99599] Reward: -33.664, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.270
# [Episode Done @ Step 99649] Reward: -25.589, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.311
# [Episode Done @ Step 99699] Reward: -17.340, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99749] Reward: -30.035, Success: 0.0, MA(50): 0.00
# [Step 99750] WM: 0.0153, Critic: 0.0227, Actor: -0.6735
# Returns mean: 0.6864, ValPreds mean: 0.6716
# [HER Sample] Mean reward in batch: 0.279
# [Episode Done @ Step 99799] Reward: -26.764, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99849] Reward: -29.930, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99899] Reward: -20.456, Success: 0.0, MA(50): 0.00
# [HER Sample] Mean reward in batch: 0.441
# [Episode Done @ Step 99949] Reward: -20.449, Success: 0.0, MA(50): 0.00
# [Episode Done @ Step 99999] Reward: -29.611, Success: 0.0, MA(50): 0.00
